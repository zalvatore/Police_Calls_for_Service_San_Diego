# %%
#Libraries
import mysql.connector
import pandas as pd
from datetime import datetime
from tqdm import tqdm
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()
import requests

# %% [markdown]
# ## DB Coonnect

# %%
database = "SanDiego_PD_Calls"
user = 'Salvador'
password = 'XXXXXXXX'
host = 'localhost'
GOOGLE_API_KEY = 'XXXXXX'
user_agent_name = 'Sal-App'

# %%
#Initial Connection
cnx = mysql.connector.connect(user=user,
                              password=password,
                              host=host,
                              database=database
                              )
cursor = cnx.cursor()

# %% [markdown]
# ##  Find if Row exists

# %%
def Find_Data(row,cursor,table, key):
    try:
        #print(f"SELECT * from {table} where {key} = '{row[key]}'")
        cursor.execute(f"SELECT * from {table} where {key} = '{row[key]}'")
        # Fetch a record
        result = cursor.fetchone()
    except:
        result = 0
    
    return result

# %% [markdown]
# ## Load Variables

# %%
#Calls
url = f"http://seshat.datasd.org/pd/pd_cfs_calltypes_datasd.csv"
call_type = pd.read_csv(url).dropna(axis=1)

# %%
#Dispos
url = f"http://seshat.datasd.org/pd/pd_dispo_codes_datasd.csv"
disposition = pd.read_csv(url).dropna(axis=1)
disposition.loc[len(disposition.index)] = ['DEF', 'DEF'] 
disposition.loc[len(disposition.index)] = ['SS-', 'SS-']

# %%
#Beats
beat = pd.read_csv('beat-neighborhood.csv').dropna(axis=1)
beat_split = beat['beat,neighborhood'].str.split(pat=",",
                                                 expand=True)
beat_split = beat_split.rename(columns={0: "beat",
                                        1: "neighborhood"})
beat_split.loc[len(beat_split.index)] = [-1, 'No Beat']
beat_split.loc[len(beat_split.index)] = [700, '700'] 
beat_split.loc[len(beat_split.index)] = [63, '63']
beat_split.loc[len(beat_split.index)] = [64, '64'] 
beat_split.loc[len(beat_split.index)] = [0, '0'] 
beat_split.loc[len(beat_split.index)] = [300, '300']
beat_split.loc[len(beat_split.index)] = [9, '9']

# %%
# Create dataframe
days = pd.DataFrame({
    'day_of_week':list(range(1,8)),
    'day':['Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday'],
})

# %%
# df to dict
call_type_dict = call_type.to_dict('records')
disposition_dict = disposition.to_dict('records')
beat_dict = beat_split.to_dict('records')
days_dict = days.to_dict('records')

# %%
# SQL Variable Tables
SQL_Tables = pd.DataFrame({
    'Table':['Call_types','Dispositions','Beats'],
    'Key':['call_type','dispo_code','beat'],
    'Col2':['description','description','neighborhood'],
    'dict':[call_type_dict,disposition_dict,beat_dict]
})
SQL_Tables_dict = SQL_Tables.to_dict('records')

# %%
#Load Data
def Load_Data(row,cursor,table,Col1,Col2):
    # Create a new record
    sql = f"""INSERT INTO {table} ({Col1},
                                    {Col2}
                                    ) VALUES (%s, %s)"""

    # Execute the query
    cursor.execute(sql, (row[Col1],row[Col2]))
    cnx.commit()

# %%
for upper_row in tqdm(SQL_Tables_dict):
    for row in upper_row['dict']:
        Data_Found = Find_Data(row,cursor,
                               upper_row['Table'],
                               upper_row['Key'])
        if Data_Found is None:
            #If no data found load 
            Load_Data(row,
                      cursor,
                      upper_row['Table'],
                      upper_row['Key'],
                      upper_row['Col2'])
        else:
            pass
# Out:
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 10.05it/s]

# %% [markdown]
# # Load Historical Calls

# %%
#function to download yearly data
def Get_Data(year):
    url = f"https://seshat.datasd.org/pd/pd_calls_for_service_{year}_datasd.csv"
    df = pd.read_csv(url)
    return df

# %%
Years = list(range(2020,datetime.now().year +1))
Years
# Out:
# [2020, 2021, 2022, 2023]

# %% [markdown]
# ### Load Calls

# %%
#Calls
def Load_Calls(row,cursor,table,year):
    # Create a new record
    sql = f"""INSERT INTO {table} ( incident_num,
                                    incident_date_time,
                                    call_type,
                                    dispo_code,
                                    beat,
                                    priority,
                                    incident_year
                                    ) VALUES (%s,%s,%s,%s,%s,%s,%s)"""

    # Execute the query
    cursor.execute(sql, (row['incident_num'],
                         row['date_time'],
                         row['call_type'],
                         row['disposition'],
                         row['beat'],
                         row['priority'],
                         year,
                        )
                  )
    cnx.commit()

# %%
for year in Years:
    yearly_data = Get_Data(year)
    yearly_data_dict = yearly_data.to_dict('records')
    for row in tqdm(yearly_data_dict):
        
        #Load Service Calls
        Table = 'Service_calls'
        Key = 'incident_num'
        #Verify if Data is in table
        Data_Found = Find_Data(row,cursor,Table,Key)
        if Data_Found is None:
            #If no data found load
            try:
                Load_Calls(row,cursor,Table,year)
            except:
                print(row)
                
        else:
            pass
# Out:
#  71%|███████████████████████▌         | 404359/567290 [00:58<00:23, 6803.69it/s]
# {'incident_num': 'E20090025884', 'date_time': '2020-09-16 02:34:54', 'day_of_week': 4, 'address_number_primary': 5300, 'address_dir_primary': nan, 'address_road_primary': 'TOSCANA', 'address_sfx_primary': 'WAY', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '530', 'disposition': 'K', 'beat': 69, 'priority': 9}
# {'incident_num': 'E20090026453', 'date_time': '2020-09-16 10:50:36', 'day_of_week': 4, 'address_number_primary': 13300, 'address_dir_primary': nan, 'address_road_primary': 'CAMINITO CIERA', 'address_sfx_primary': nan, 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '530', 'disposition': 'K', 'beat': 38, 'priority': 9}
#  72%|███████████████████████▋         | 406381/567290 [00:58<00:24, 6560.98it/s]
# {'incident_num': 'E20090028292', 'date_time': '2020-09-17 11:29:34', 'day_of_week': 5, 'address_number_primary': 9100, 'address_dir_primary': nan, 'address_road_primary': 'BITTERCREEK', 'address_sfx_primary': 'LN', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '653M', 'disposition': 'K', 'beat': 44, 'priority': 9}
# {'incident_num': 'E20090028381', 'date_time': '2020-09-17 12:28:05', 'day_of_week': 5, 'address_number_primary': 4000, 'address_dir_primary': nan, 'address_road_primary': 'MAHAILA', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '487R', 'disposition': 'R', 'beat': 69, 'priority': 9}
# {'incident_num': 'E20090029138', 'date_time': '2020-09-17 20:59:13', 'day_of_week': 5, 'address_number_primary': 15800, 'address_dir_primary': nan, 'address_road_primary': 'CAMINO SAN BERNARDO', 'address_sfx_primary': nan, 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '415PP', 'disposition': 'O', 'beat': 27, 'priority': 2}
# {'incident_num': 'E20090029149', 'date_time': '2020-09-17 21:05:54', 'day_of_week': 5, 'address_number_primary': 10800, 'address_dir_primary': nan, 'address_road_primary': 'VIA CASCABEL', 'address_sfx_primary': nan, 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '653M', 'disposition': 'R', 'beat': 84, 'priority': 9}
# {'incident_num': 'E20090029166', 'date_time': '2020-09-17 21:17:33', 'day_of_week': 5, 'address_number_primary': 300, 'address_dir_primary': nan, 'address_road_primary': 'PROSPECT', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '415N', 'disposition': 'K', 'beat': 72, 'priority': 3}
# {'incident_num': 'E20090029187', 'date_time': '2020-09-17 21:32:06', 'day_of_week': 5, 'address_number_primary': 3500, 'address_dir_primary': nan, 'address_road_primary': 'WEST CANYON', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'T', 'disposition': 'K', 'beat': 95, 'priority': 2}
# {'incident_num': 'E20090029191', 'date_time': '2020-09-17 21:33:02', 'day_of_week': 5, 'address_number_primary': 9300, 'address_dir_primary': nan, 'address_road_primary': 'GOLD COAST', 'address_sfx_primary': 'DR', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'MPSSTP', 'disposition': 'O', 'beat': 39, 'priority': 2}
# {'incident_num': 'E20090029197', 'date_time': '2020-09-17 21:37:05', 'day_of_week': 5, 'address_number_primary': 400, 'address_dir_primary': nan, 'address_road_primary': 'DENNERY', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '415W', 'disposition': 'K', 'beat': 330, 'priority': 1}
# {'incident_num': 'E20090029205', 'date_time': '2020-09-17 21:42:52', 'day_of_week': 5, 'address_number_primary': 10200, 'address_dir_primary': nan, 'address_road_primary': 'BLACK MOUNTAIN', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'MPSSTP', 'disposition': 'O', 'beat': 39, 'priority': 2}
# {'incident_num': 'E20090029219', 'date_time': '2020-09-17 21:49:25', 'day_of_week': 5, 'address_number_primary': 3900, 'address_dir_primary': nan, 'address_road_primary': '09TH', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '459A', 'disposition': 'K', 'beat': 157, 'priority': 3}
# {'incident_num': 'E20090029220', 'date_time': '2020-09-17 21:49:46', 'day_of_week': 5, 'address_number_primary': 10200, 'address_dir_primary': nan, 'address_road_primary': 'BORDELON', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '459HP', 'disposition': 'K', 'beat': 117, 'priority': 0}
# {'incident_num': 'E20090029222', 'date_time': '2020-09-17 21:50:49', 'day_of_week': 5, 'address_number_primary': 1400, 'address_dir_primary': nan, 'address_road_primary': 'IMPERIAL', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '1186', 'disposition': 'K', 'beat': 599, 'priority': 3}
# {'incident_num': 'E20090029226', 'date_time': '2020-09-17 21:55:04', 'day_of_week': 5, 'address_number_primary': 300, 'address_dir_primary': 'W', 'address_road_primary': 'HARBOR', 'address_sfx_primary': 'DR', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '1186', 'disposition': 'K', 'beat': 390, 'priority': 3}
# {'incident_num': 'E20090029232', 'date_time': '2020-09-17 22:00:06', 'day_of_week': 5, 'address_number_primary': 17900, 'address_dir_primary': nan, 'address_road_primary': 'CABELA', 'address_sfx_primary': 'DR', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'CC', 'disposition': 'K', 'beat': 28, 'priority': 3}
# {'incident_num': 'E20090029244', 'date_time': '2020-09-17 22:08:51', 'day_of_week': 5, 'address_number_primary': 10900, 'address_dir_primary': nan, 'address_road_primary': 'JASMINE CREST', 'address_sfx_primary': 'LN', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'AU2', 'disposition': 'W', 'beat': 46, 'priority': 2}
# {'incident_num': 'E20090029245', 'date_time': '2020-09-17 22:08:52', 'day_of_week': 5, 'address_number_primary': 2900, 'address_dir_primary': nan, 'address_road_primary': 'EL CAJON', 'address_sfx_primary': 'BLV', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '602', 'disposition': 'O', 'beat': 18, 'priority': 2}
# {'incident_num': 'E20090029254', 'date_time': '2020-09-17 22:15:34', 'day_of_week': 5, 'address_number_primary': 0, 'address_dir_primary': nan, 'address_road_primary': 'OLD MILKY', 'address_sfx_primary': 'WAY', 'address_dir_intersecting': nan, 'address_road_intersecting': 'SAN PASQUAL', 'address_sfx_intersecting': nan, 'call_type': 'HZRD', 'disposition': 'K', 'beat': 19, 'priority': 1}
# {'incident_num': 'E20090029255', 'date_time': '2020-09-17 22:15:54', 'day_of_week': 5, 'address_number_primary': 400, 'address_dir_primary': nan, 'address_road_primary': 'BEAR VALLEY', 'address_sfx_primary': 'PKY', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'HZRD', 'disposition': 'K', 'beat': 150, 'priority': 1}
# {'incident_num': 'E20090029266', 'date_time': '2020-09-17 22:23:45', 'day_of_week': 5, 'address_number_primary': 3200, 'address_dir_primary': nan, 'address_road_primary': 'ACACIA', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'AU2', 'disposition': 'W', 'beat': 70, 'priority': 2}
# {'incident_num': 'E20090029276', 'date_time': '2020-09-17 22:29:47', 'day_of_week': 5, 'address_number_primary': 10400, 'address_dir_primary': nan, 'address_road_primary': 'BLACK MOUNTAIN', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'MPSSTP', 'disposition': 'O', 'beat': 183, 'priority': 2}
# {'incident_num': 'E20090029284', 'date_time': '2020-09-17 22:37:01', 'day_of_week': 5, 'address_number_primary': 2700, 'address_dir_primary': nan, 'address_road_primary': 'TORREY PINES', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '1186', 'disposition': 'K', 'beat': 173, 'priority': 3}
# {'incident_num': 'E20090029293', 'date_time': '2020-09-17 22:42:27', 'day_of_week': 5, 'address_number_primary': 200, 'address_dir_primary': nan, 'address_road_primary': 'WILLOW', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '911', 'disposition': 'CAN', 'beat': 3, 'priority': 1}
# {'incident_num': 'E20090029294', 'date_time': '2020-09-17 22:44:40', 'day_of_week': 5, 'address_number_primary': 0, 'address_dir_primary': nan, 'address_road_primary': 'DEVON', 'address_sfx_primary': 'CT', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'PARTY', 'disposition': 'DUP', 'beat': 17, 'priority': 3}
# {'incident_num': 'E20090029300', 'date_time': '2020-09-17 22:52:21', 'day_of_week': 5, 'address_number_primary': 8400, 'address_dir_primary': nan, 'address_road_primary': 'DONAKER', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '459A', 'disposition': 'U', 'beat': 44, 'priority': 2}
# {'incident_num': 'E20090029302', 'date_time': '2020-09-17 22:52:38', 'day_of_week': 5, 'address_number_primary': 2200, 'address_dir_primary': nan, 'address_road_primary': 'COMMERCIAL', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '415N', 'disposition': 'K', 'beat': 143, 'priority': 3}
# {'incident_num': 'E20090029311', 'date_time': '2020-09-17 22:58:47', 'day_of_week': 5, 'address_number_primary': 4500, 'address_dir_primary': nan, 'address_road_primary': 'GOVERNOR', 'address_sfx_primary': 'DR', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '415', 'disposition': 'O', 'beat': 69, 'priority': 2}
# {'incident_num': 'E20090029312', 'date_time': '2020-09-17 23:00:16', 'day_of_week': 5, 'address_number_primary': 8200, 'address_dir_primary': nan, 'address_road_primary': 'FLANDERS', 'address_sfx_primary': 'DR', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'PARTY', 'disposition': 'CAN', 'beat': 585, 'priority': 3}
# {'incident_num': 'E20090029325', 'date_time': '2020-09-17 23:09:03', 'day_of_week': 5, 'address_number_primary': 4200, 'address_dir_primary': nan, 'address_road_primary': '48TH', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '602', 'disposition': 'K', 'beat': 47, 'priority': 2}
# {'incident_num': 'E20090029332', 'date_time': '2020-09-17 23:16:16', 'day_of_week': 5, 'address_number_primary': 8700, 'address_dir_primary': nan, 'address_road_primary': 'DUNAWAY', 'address_sfx_primary': 'DR', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'DC', 'disposition': 'K', 'beat': 73, 'priority': 2}
# {'incident_num': 'E20090029347', 'date_time': '2020-09-17 23:28:05', 'day_of_week': 5, 'address_number_primary': 10400, 'address_dir_primary': nan, 'address_road_primary': 'TIERRASANTA', 'address_sfx_primary': 'BLV', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '459A', 'disposition': 'CAN', 'beat': 84, 'priority': 2}
# {'incident_num': 'E20090029349', 'date_time': '2020-09-17 23:29:34', 'day_of_week': 5, 'address_number_primary': 11900, 'address_dir_primary': nan, 'address_road_primary': 'CARMEL CREEK', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '1171', 'disposition': 'K', 'beat': 46, 'priority': 1}
# {'incident_num': 'E20090029351', 'date_time': '2020-09-17 23:30:12', 'day_of_week': 5, 'address_number_primary': 300, 'address_dir_primary': nan, 'address_road_primary': 'PROSPECT', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '415N', 'disposition': 'K', 'beat': 72, 'priority': 3}
# {'incident_num': 'E20090029356', 'date_time': '2020-09-17 23:33:17', 'day_of_week': 5, 'address_number_primary': 700, 'address_dir_primary': 'W', 'address_road_primary': 'SAN YSIDRO', 'address_sfx_primary': 'BLV', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'T', 'disposition': 'K', 'beat': 148, 'priority': 2}
# {'incident_num': 'E20090029358', 'date_time': '2020-09-17 23:34:22', 'day_of_week': 5, 'address_number_primary': 2100, 'address_dir_primary': nan, 'address_road_primary': 'SPRAY', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'SLEEPER', 'disposition': 'K', 'beat': 34, 'priority': 3}
# {'incident_num': 'E20090029364', 'date_time': '2020-09-17 23:41:09', 'day_of_week': 5, 'address_number_primary': 13100, 'address_dir_primary': nan, 'address_road_primary': 'SUNDANCE', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'MPSSTP', 'disposition': 'O', 'beat': 182, 'priority': 2}
# {'incident_num': 'E20090029377', 'date_time': '2020-09-17 23:49:30', 'day_of_week': 5, 'address_number_primary': 13100, 'address_dir_primary': nan, 'address_road_primary': 'SUNDANCE', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'MPSSTP', 'disposition': 'O', 'beat': 55, 'priority': 2}
# {'incident_num': 'E20090029385', 'date_time': '2020-09-17 23:52:44', 'day_of_week': 5, 'address_number_primary': 5300, 'address_dir_primary': nan, 'address_road_primary': 'CAMINO SANTANDER', 'address_sfx_primary': nan, 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'AU2', 'disposition': 'W', 'beat': 46, 'priority': 2}
# {'incident_num': 'E20090029392', 'date_time': '2020-09-18 00:01:09', 'day_of_week': 6, 'address_number_primary': 11800, 'address_dir_primary': nan, 'address_road_primary': 'CAMINITO DE LAS MISSIONES', 'address_sfx_primary': nan, 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '1146', 'disposition': 'R', 'beat': 148, 'priority': 0}
# {'incident_num': 'E20090029394', 'date_time': '2020-09-18 00:02:12', 'day_of_week': 6, 'address_number_primary': 3800, 'address_dir_primary': nan, 'address_road_primary': 'CAMINITO AGUILAR', 'address_sfx_primary': nan, 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'PARTY', 'disposition': 'K', 'beat': 81, 'priority': 3}
# {'incident_num': 'E20090029396', 'date_time': '2020-09-18 00:03:38', 'day_of_week': 6, 'address_number_primary': 1200, 'address_dir_primary': nan, 'address_road_primary': 'HOTEL CIRCLE NORTH', 'address_sfx_primary': nan, 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '11-8', 'disposition': 'K', 'beat': 208, 'priority': 0}
# {'incident_num': 'E20090029397', 'date_time': '2020-09-18 00:03:40', 'day_of_week': 6, 'address_number_primary': 8800, 'address_dir_primary': nan, 'address_road_primary': 'RIO SAN DIEGO', 'address_sfx_primary': 'DR', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'MPSSTP', 'disposition': 'K', 'beat': 7, 'priority': 2}
# {'incident_num': 'E20090029400', 'date_time': '2020-09-18 00:04:34', 'day_of_week': 6, 'address_number_primary': 0, 'address_dir_primary': nan, 'address_road_primary': 'GENESEE', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': 'GOVERNOR', 'address_sfx_intersecting': nan, 'call_type': 'T', 'disposition': 'K', 'beat': 69, 'priority': 2}
# {'incident_num': 'E20090029404', 'date_time': '2020-09-18 00:05:27', 'day_of_week': 6, 'address_number_primary': 3400, 'address_dir_primary': nan, 'address_road_primary': 'SPORTS ARENA', 'address_sfx_primary': 'BLV', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '1171', 'disposition': 'O', 'beat': 143, 'priority': 1}
# {'incident_num': 'E20090029408', 'date_time': '2020-09-18 00:10:40', 'day_of_week': 6, 'address_number_primary': 5400, 'address_dir_primary': nan, 'address_road_primary': 'GENESEE', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '1188', 'disposition': 'O', 'beat': 354, 'priority': 2}
# {'incident_num': 'E20090029409', 'date_time': '2020-09-18 00:10:58', 'day_of_week': 6, 'address_number_primary': 7100, 'address_dir_primary': nan, 'address_road_primary': 'OTAY MESA', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'SELENF', 'disposition': 'K', 'beat': 146, 'priority': 3}
# {'incident_num': 'E20090029425', 'date_time': '2020-09-18 00:17:51', 'day_of_week': 6, 'address_number_primary': 5100, 'address_dir_primary': nan, 'address_road_primary': 'MISSION CENTER', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'MPSSTP', 'disposition': 'O', 'beat': 225, 'priority': 2}
# {'incident_num': 'E20090029434', 'date_time': '2020-09-18 00:26:17', 'day_of_week': 6, 'address_number_primary': 17200, 'address_dir_primary': nan, 'address_road_primary': 'BERNARDO CENTER', 'address_sfx_primary': 'DR', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '11-8', 'disposition': 'K', 'beat': 28, 'priority': 0}
# {'incident_num': 'E20090029435', 'date_time': '2020-09-18 00:26:32', 'day_of_week': 6, 'address_number_primary': 1900, 'address_dir_primary': nan, 'address_road_primary': 'GRAND', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'MPSSTP', 'disposition': 'K', 'beat': 472, 'priority': 2}
# {'incident_num': 'E20090029439', 'date_time': '2020-09-18 00:30:27', 'day_of_week': 6, 'address_number_primary': 1700, 'address_dir_primary': nan, 'address_road_primary': 'QUIVIRA', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '415', 'disposition': 'K', 'beat': 172, 'priority': 2}
# {'incident_num': 'E20090029446', 'date_time': '2020-09-18 00:36:52', 'day_of_week': 6, 'address_number_primary': 4400, 'address_dir_primary': nan, 'address_road_primary': 'WEST POINT LOMA', 'address_sfx_primary': 'BLV', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '1185', 'disposition': 'O', 'beat': 29, 'priority': 3}
# {'incident_num': 'E20090029460', 'date_time': '2020-09-18 00:52:42', 'day_of_week': 6, 'address_number_primary': 2000, 'address_dir_primary': nan, 'address_road_primary': 'PALM', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'T', 'disposition': 'K', 'beat': 390, 'priority': 2}
# {'incident_num': 'E20090029474', 'date_time': '2020-09-18 01:13:43', 'day_of_week': 6, 'address_number_primary': 5900, 'address_dir_primary': nan, 'address_road_primary': 'RANCHO MISSION', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '415PP', 'disposition': 'O', 'beat': 62, 'priority': 2}
# {'incident_num': 'E20090029475', 'date_time': '2020-09-18 01:16:54', 'day_of_week': 6, 'address_number_primary': 11400, 'address_dir_primary': nan, 'address_road_primary': 'BOOTES', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '415V', 'disposition': 'K', 'beat': 55, 'priority': 1}
# {'incident_num': 'E20090029503', 'date_time': '2020-09-18 01:44:15', 'day_of_week': 6, 'address_number_primary': 1400, 'address_dir_primary': nan, 'address_road_primary': 'IMPERIAL', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '1186', 'disposition': 'K', 'beat': 599, 'priority': 3}
# {'incident_num': 'E20090029504', 'date_time': '2020-09-18 01:48:37', 'day_of_week': 6, 'address_number_primary': 0, 'address_dir_primary': nan, 'address_road_primary': 'INTERSTATE 5 NB', 'address_sfx_primary': nan, 'address_dir_intersecting': nan, 'address_road_intersecting': 'L', 'address_sfx_intersecting': nan, 'call_type': 'T', 'disposition': 'O', 'beat': 120, 'priority': 2}
# {'incident_num': 'E20090029512', 'date_time': '2020-09-18 02:00:48', 'day_of_week': 6, 'address_number_primary': 3000, 'address_dir_primary': nan, 'address_road_primary': 'J', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'CW', 'disposition': 'O', 'beat': 34, 'priority': 1}
# {'incident_num': 'E20090029522', 'date_time': '2020-09-18 02:18:13', 'day_of_week': 6, 'address_number_primary': 1100, 'address_dir_primary': nan, 'address_road_primary': 'CAMINO COPETE', 'address_sfx_primary': nan, 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '1021', 'disposition': 'K', 'beat': 598, 'priority': 3}
# {'incident_num': 'E20090029523', 'date_time': '2020-09-18 02:18:40', 'day_of_week': 6, 'address_number_primary': 200, 'address_dir_primary': nan, 'address_road_primary': 'ISLAND', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'PARTY', 'disposition': 'K', 'beat': 143, 'priority': 3}
# {'incident_num': 'E20090029535', 'date_time': '2020-09-18 02:33:05', 'day_of_week': 6, 'address_number_primary': 1000, 'address_dir_primary': nan, 'address_road_primary': 'F', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '1149', 'disposition': 'K', 'beat': 73, 'priority': 2}
# {'incident_num': 'E20090029537', 'date_time': '2020-09-18 02:38:35', 'day_of_week': 6, 'address_number_primary': 5000, 'address_dir_primary': nan, 'address_road_primary': 'CAMPANILE', 'address_sfx_primary': 'DR', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '459', 'disposition': 'K', 'beat': 76, 'priority': 1}
# {'incident_num': 'E20090029542', 'date_time': '2020-09-18 02:44:33', 'day_of_week': 6, 'address_number_primary': 7300, 'address_dir_primary': nan, 'address_road_primary': 'GIRARD', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '459C', 'disposition': 'K', 'beat': 72, 'priority': 2}
# {'incident_num': 'E20090029543', 'date_time': '2020-09-18 02:45:34', 'day_of_week': 6, 'address_number_primary': 1000, 'address_dir_primary': nan, 'address_road_primary': 'CUDAHY', 'address_sfx_primary': 'PL', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'SELENF', 'disposition': 'O', 'beat': 62, 'priority': 3}
# {'incident_num': 'E20090029545', 'date_time': '2020-09-18 02:49:46', 'day_of_week': 6, 'address_number_primary': 15900, 'address_dir_primary': nan, 'address_road_primary': 'PASEO DEL SUR', 'address_sfx_primary': nan, 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'SELENF', 'disposition': 'K', 'beat': 71, 'priority': 3}
# {'incident_num': 'E20090029567', 'date_time': '2020-09-18 03:27:50', 'day_of_week': 6, 'address_number_primary': 300, 'address_dir_primary': nan, 'address_road_primary': 'WASHINGTON', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'CW', 'disposition': 'O', 'beat': 24, 'priority': 1}
# {'incident_num': 'E20090029568', 'date_time': '2020-09-18 03:28:27', 'day_of_week': 6, 'address_number_primary': 5400, 'address_dir_primary': nan, 'address_road_primary': 'LAURETTA', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '602', 'disposition': 'K', 'beat': 152, 'priority': 2}
# {'incident_num': 'E20090029572', 'date_time': '2020-09-18 03:30:45', 'day_of_week': 6, 'address_number_primary': 16200, 'address_dir_primary': nan, 'address_road_primary': 'VERIDIAN', 'address_sfx_primary': 'CIR', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '1160', 'disposition': 'K', 'beat': 15, 'priority': 2}
# {'incident_num': 'E20090029587', 'date_time': '2020-09-18 04:00:39', 'day_of_week': 6, 'address_number_primary': 0, 'address_dir_primary': 'NB', 'address_road_primary': '15', 'address_sfx_primary': nan, 'address_dir_intersecting': nan, 'address_road_intersecting': 'AERO', 'address_sfx_intersecting': nan, 'call_type': 'T', 'disposition': 'O', 'beat': 59, 'priority': 2}
# {'incident_num': 'E20090029595', 'date_time': '2020-09-18 04:15:45', 'day_of_week': 6, 'address_number_primary': 100, 'address_dir_primary': nan, 'address_road_primary': 'PARK', 'address_sfx_primary': 'PLZ', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '415', 'disposition': 'CAN', 'beat': 100, 'priority': 2}
# {'incident_num': 'E20090029597', 'date_time': '2020-09-18 04:18:29', 'day_of_week': 6, 'address_number_primary': 2800, 'address_dir_primary': nan, 'address_road_primary': 'CAMINO DEL RIO SOUTH', 'address_sfx_primary': nan, 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '459A', 'disposition': 'U', 'beat': 80, 'priority': 3}
# {'incident_num': 'E20090029598', 'date_time': '2020-09-18 04:18:32', 'day_of_week': 6, 'address_number_primary': 9400, 'address_dir_primary': nan, 'address_road_primary': 'MIRA MESA', 'address_sfx_primary': 'BLV', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '211R', 'disposition': 'K', 'beat': 55, 'priority': 2}
# {'incident_num': 'E20090029602', 'date_time': '2020-09-18 04:21:37', 'day_of_week': 6, 'address_number_primary': 2500, 'address_dir_primary': nan, 'address_road_primary': 'CORONADO', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'T', 'disposition': 'K', 'beat': 62, 'priority': 2}
# {'incident_num': 'E20090029616', 'date_time': '2020-09-18 04:39:51', 'day_of_week': 6, 'address_number_primary': 12700, 'address_dir_primary': nan, 'address_road_primary': 'EL CAMINO REAL', 'address_sfx_primary': nan, 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '1151', 'disposition': 'K', 'beat': 104, 'priority': 2}
# {'incident_num': 'E20090029620', 'date_time': '2020-09-18 04:45:25', 'day_of_week': 6, 'address_number_primary': 1400, 'address_dir_primary': nan, 'address_road_primary': 'IMPERIAL', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '1186', 'disposition': 'K', 'beat': 599, 'priority': 3}
# {'incident_num': 'E20090029641', 'date_time': '2020-09-18 05:35:48', 'day_of_week': 6, 'address_number_primary': 12500, 'address_dir_primary': nan, 'address_road_primary': 'EL CAMINO REAL', 'address_sfx_primary': nan, 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'SELENF', 'disposition': 'K', 'beat': 54, 'priority': 3}
# {'incident_num': 'E20090029657', 'date_time': '2020-09-18 05:58:02', 'day_of_week': 6, 'address_number_primary': 2000, 'address_dir_primary': nan, 'address_road_primary': 'ROSECRANS', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '1186', 'disposition': 'O', 'beat': 102, 'priority': 3}
#  72%|███████████████████████▋         | 407651/567290 [00:59<00:27, 5818.66it/s]
# {'incident_num': 'E20090029669', 'date_time': '2020-09-18 06:12:12', 'day_of_week': 6, 'address_number_primary': 10900, 'address_dir_primary': nan, 'address_road_primary': 'CARMEL MOUNTAIN', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '459R', 'disposition': 'CAN', 'beat': 38, 'priority': 3}
# {'incident_num': 'E20090029673', 'date_time': '2020-09-18 06:17:09', 'day_of_week': 6, 'address_number_primary': 9300, 'address_dir_primary': nan, 'address_road_primary': 'MIRA MESA', 'address_sfx_primary': 'BLV', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '242', 'disposition': 'A', 'beat': 55, 'priority': 0}
# {'incident_num': 'E20090029677', 'date_time': '2020-09-18 06:24:50', 'day_of_week': 6, 'address_number_primary': 7600, 'address_dir_primary': nan, 'address_road_primary': 'SAINT ANDREWS', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '459A', 'disposition': 'K', 'beat': 130, 'priority': 3}
# {'incident_num': 'E20090029689', 'date_time': '2020-09-18 06:35:18', 'day_of_week': 6, 'address_number_primary': 1900, 'address_dir_primary': nan, 'address_road_primary': 'BACON', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'CITE', 'disposition': 'O', 'beat': 146, 'priority': 2}
# {'incident_num': 'E20090029692', 'date_time': '2020-09-18 06:37:50', 'day_of_week': 6, 'address_number_primary': 1700, 'address_dir_primary': nan, 'address_road_primary': 'MISSOURI', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '586', 'disposition': 'O', 'beat': 164, 'priority': 4}
# {'incident_num': 'E20090029694', 'date_time': '2020-09-18 06:38:19', 'day_of_week': 6, 'address_number_primary': 600, 'address_dir_primary': nan, 'address_road_primary': 'CONVENTION', 'address_sfx_primary': 'WAY', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '1186', 'disposition': 'O', 'beat': 100, 'priority': 3}
# {'incident_num': 'E20090029696', 'date_time': '2020-09-18 06:41:02', 'day_of_week': 6, 'address_number_primary': 2000, 'address_dir_primary': nan, 'address_road_primary': 'LOGAN', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'SELENF', 'disposition': 'O', 'beat': 475, 'priority': 3}
# {'incident_num': 'E20090029700', 'date_time': '2020-09-18 06:47:14', 'day_of_week': 6, 'address_number_primary': 0, 'address_dir_primary': nan, 'address_road_primary': 'PASEO DORADO', 'address_sfx_primary': nan, 'address_dir_intersecting': nan, 'address_road_intersecting': 'LA JOLLA SHORES', 'address_sfx_intersecting': nan, 'call_type': 'INFO', 'disposition': 'W', 'beat': 73, 'priority': 2}
# {'incident_num': 'E20090029708', 'date_time': '2020-09-18 06:53:50', 'day_of_week': 6, 'address_number_primary': 1900, 'address_dir_primary': nan, 'address_road_primary': 'NEWTON', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'SELENF', 'disposition': 'O', 'beat': 148, 'priority': 3}
# {'incident_num': 'E20090029709', 'date_time': '2020-09-18 06:55:51', 'day_of_week': 6, 'address_number_primary': 3000, 'address_dir_primary': nan, 'address_road_primary': 'CEDAR', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'HATEINV', 'disposition': 'CAN', 'beat': 39, 'priority': 3}
# {'incident_num': 'E20090029714', 'date_time': '2020-09-18 06:59:15', 'day_of_week': 6, 'address_number_primary': 5100, 'address_dir_primary': nan, 'address_road_primary': 'FRIARS', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '1186', 'disposition': 'O', 'beat': 101, 'priority': 3}
# {'incident_num': 'E20090029716', 'date_time': '2020-09-18 07:00:24', 'day_of_week': 6, 'address_number_primary': 4700, 'address_dir_primary': nan, 'address_road_primary': 'PACIFIC', 'address_sfx_primary': 'HWY', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '1186', 'disposition': 'O', 'beat': 261, 'priority': 3}
# {'incident_num': 'E20090029719', 'date_time': '2020-09-18 07:01:41', 'day_of_week': 6, 'address_number_primary': 800, 'address_dir_primary': nan, 'address_road_primary': 'SAN JUAN', 'address_sfx_primary': 'PL', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '586', 'disposition': 'O', 'beat': 110, 'priority': 4}
# {'incident_num': 'E20090029725', 'date_time': '2020-09-18 07:07:08', 'day_of_week': 6, 'address_number_primary': 3100, 'address_dir_primary': nan, 'address_road_primary': 'SPORTS ARENA', 'address_sfx_primary': 'BLV', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'SELENF', 'disposition': 'O', 'beat': 15, 'priority': 3}
# {'incident_num': 'E20090029728', 'date_time': '2020-09-18 07:07:53', 'day_of_week': 6, 'address_number_primary': 2000, 'address_dir_primary': nan, 'address_road_primary': 'COMMERCIAL', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'SELENF', 'disposition': 'O', 'beat': 86, 'priority': 3}
# {'incident_num': 'E20090029732', 'date_time': '2020-09-18 07:09:59', 'day_of_week': 6, 'address_number_primary': 800, 'address_dir_primary': nan, 'address_road_primary': 'CESAR E CHAVEZ', 'address_sfx_primary': 'PKY', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'SELENF', 'disposition': 'O', 'beat': 94, 'priority': 3}
# {'incident_num': 'E20090029735', 'date_time': '2020-09-18 07:11:38', 'day_of_week': 6, 'address_number_primary': 1100, 'address_dir_primary': nan, 'address_road_primary': '03RD', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '1186', 'disposition': 'O', 'beat': 143, 'priority': 3}
# {'incident_num': 'E20090029743', 'date_time': '2020-09-18 07:17:49', 'day_of_week': 6, 'address_number_primary': 13100, 'address_dir_primary': nan, 'address_road_primary': 'TRAIL DUST', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '1146', 'disposition': 'R', 'beat': 55, 'priority': 0}
# {'incident_num': 'E20090029748', 'date_time': '2020-09-18 07:20:49', 'day_of_week': 6, 'address_number_primary': 5100, 'address_dir_primary': nan, 'address_road_primary': 'LA JOLLA', 'address_sfx_primary': 'BLV', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'FU', 'disposition': 'O', 'beat': 82, 'priority': 2}
# {'incident_num': 'E20090029750', 'date_time': '2020-09-18 07:22:23', 'day_of_week': 6, 'address_number_primary': 200, 'address_dir_primary': nan, 'address_road_primary': '05TH', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '415', 'disposition': 'CAN', 'beat': 4, 'priority': 2}
# {'incident_num': 'E20090029751', 'date_time': '2020-09-18 07:22:44', 'day_of_week': 6, 'address_number_primary': 2700, 'address_dir_primary': nan, 'address_road_primary': 'PRESIDIO', 'address_sfx_primary': 'DR', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '1186', 'disposition': 'O', 'beat': 195, 'priority': 3}
# {'incident_num': 'E20090029755', 'date_time': '2020-09-18 07:26:48', 'day_of_week': 6, 'address_number_primary': 2100, 'address_dir_primary': nan, 'address_road_primary': 'LAS LOMAS', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '586', 'disposition': 'K', 'beat': 573, 'priority': 2}
# {'incident_num': 'E20090029768', 'date_time': '2020-09-18 07:39:23', 'day_of_week': 6, 'address_number_primary': 10900, 'address_dir_primary': nan, 'address_road_primary': 'TYLER', 'address_sfx_primary': 'WAY', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '459A', 'disposition': 'K', 'beat': 38, 'priority': 3}
# {'incident_num': 'E20090029774', 'date_time': '2020-09-18 07:46:00', 'day_of_week': 6, 'address_number_primary': 5600, 'address_dir_primary': nan, 'address_road_primary': 'WAVERLY', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'CC', 'disposition': 'O', 'beat': 673, 'priority': 3}
# {'incident_num': 'E20090029776', 'date_time': '2020-09-18 07:46:37', 'day_of_week': 6, 'address_number_primary': 7900, 'address_dir_primary': nan, 'address_road_primary': 'LA JOLLA SCENIC', 'address_sfx_primary': 'DR', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '459A', 'disposition': 'CAN', 'beat': 73, 'priority': 2}
# {'incident_num': 'E20090029783', 'date_time': '2020-09-18 07:52:25', 'day_of_week': 6, 'address_number_primary': 10800, 'address_dir_primary': nan, 'address_road_primary': 'TIERRASANTA', 'address_sfx_primary': 'BLV', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '10852R', 'disposition': 'K', 'beat': 84, 'priority': 3}
# {'incident_num': 'E20090029787', 'date_time': '2020-09-18 07:56:06', 'day_of_week': 6, 'address_number_primary': 2000, 'address_dir_primary': nan, 'address_road_primary': 'COMMERCIAL', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'SELENF', 'disposition': 'O', 'beat': 70, 'priority': 3}
# {'incident_num': 'E20090029794', 'date_time': '2020-09-18 08:06:20', 'day_of_week': 6, 'address_number_primary': 9400, 'address_dir_primary': nan, 'address_road_primary': 'CARROLL CANYON', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'SELENF', 'disposition': 'O', 'beat': 90, 'priority': 3}
# {'incident_num': 'E20090029799', 'date_time': '2020-09-18 08:10:53', 'day_of_week': 6, 'address_number_primary': 12500, 'address_dir_primary': nan, 'address_road_primary': 'EL CAMINO REAL', 'address_sfx_primary': nan, 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'MTG', 'disposition': 'K', 'beat': 49, 'priority': 4}
# {'incident_num': 'E20090029807', 'date_time': '2020-09-18 08:15:31', 'day_of_week': 6, 'address_number_primary': 9800, 'address_dir_primary': nan, 'address_road_primary': 'SASKATCHEWAN', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '459A', 'disposition': 'CAN', 'beat': 193, 'priority': 2}
# {'incident_num': 'E20090029809', 'date_time': '2020-09-18 08:15:54', 'day_of_week': 6, 'address_number_primary': 10900, 'address_dir_primary': nan, 'address_road_primary': 'SCRIPPS RANCH', 'address_sfx_primary': 'BLV', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'RJ', 'disposition': 'K', 'beat': 55, 'priority': 2}
# {'incident_num': 'E20090029813', 'date_time': '2020-09-18 08:20:04', 'day_of_week': 6, 'address_number_primary': 3700, 'address_dir_primary': nan, 'address_road_primary': 'MURPHY CANYON', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'SELENF', 'disposition': 'O', 'beat': 90, 'priority': 3}
# {'incident_num': 'E20090029819', 'date_time': '2020-09-18 08:22:58', 'day_of_week': 6, 'address_number_primary': 4200, 'address_dir_primary': nan, 'address_road_primary': 'EASTGATE', 'address_sfx_primary': 'MAL', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '1021', 'disposition': 'K', 'beat': 62, 'priority': 3}
# {'incident_num': 'E20090029827', 'date_time': '2020-09-18 08:29:21', 'day_of_week': 6, 'address_number_primary': 1600, 'address_dir_primary': nan, 'address_road_primary': 'LOGAN', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '415', 'disposition': 'K', 'beat': 73, 'priority': 2}
# {'incident_num': 'E20090029830', 'date_time': '2020-09-18 08:31:40', 'day_of_week': 6, 'address_number_primary': 5600, 'address_dir_primary': nan, 'address_road_primary': 'WAVERLY', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '1146', 'disposition': 'R', 'beat': 673, 'priority': 0}
# {'incident_num': 'E20090029838', 'date_time': '2020-09-18 08:37:42', 'day_of_week': 6, 'address_number_primary': 12500, 'address_dir_primary': nan, 'address_road_primary': 'EL CAMINO REAL', 'address_sfx_primary': nan, 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'MTG', 'disposition': 'K', 'beat': 54, 'priority': 4}
# {'incident_num': 'E20090029841', 'date_time': '2020-09-18 08:40:21', 'day_of_week': 6, 'address_number_primary': 2200, 'address_dir_primary': nan, 'address_road_primary': 'DENVER', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '1185', 'disposition': 'R', 'beat': 95, 'priority': 3}
# {'incident_num': 'E20090029849', 'date_time': '2020-09-18 08:46:01', 'day_of_week': 6, 'address_number_primary': 5400, 'address_dir_primary': nan, 'address_road_primary': 'FRIARS', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'SELENF', 'disposition': 'K', 'beat': 330, 'priority': 3}
# {'incident_num': 'E20090029859', 'date_time': '2020-09-18 08:55:03', 'day_of_week': 6, 'address_number_primary': 15800, 'address_dir_primary': nan, 'address_road_primary': 'BERNARDO CENTER', 'address_sfx_primary': 'DR', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '245', 'disposition': 'K', 'beat': 28, 'priority': 1}
# {'incident_num': 'E20090029862', 'date_time': '2020-09-18 08:59:12', 'day_of_week': 6, 'address_number_primary': 600, 'address_dir_primary': nan, 'address_road_primary': '03RD', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'CW', 'disposition': 'K', 'beat': 149, 'priority': 1}
# {'incident_num': 'E20090029863', 'date_time': '2020-09-18 09:00:13', 'day_of_week': 6, 'address_number_primary': 5400, 'address_dir_primary': nan, 'address_road_primary': 'ADOBE FALLS', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '10852R', 'disposition': 'K', 'beat': 144, 'priority': 9}
# {'incident_num': 'E20090029864', 'date_time': '2020-09-18 09:02:49', 'day_of_week': 6, 'address_number_primary': 6600, 'address_dir_primary': nan, 'address_road_primary': 'AMHERST', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '530', 'disposition': 'R', 'beat': 149, 'priority': 9}
# {'incident_num': 'E20090029870', 'date_time': '2020-09-18 09:07:51', 'day_of_week': 6, 'address_number_primary': 12500, 'address_dir_primary': nan, 'address_road_primary': 'EL CAMINO REAL', 'address_sfx_primary': nan, 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'FD', 'disposition': 'K', 'beat': 54, 'priority': 2}
# {'incident_num': 'E20090029877', 'date_time': '2020-09-18 09:12:03', 'day_of_week': 6, 'address_number_primary': 9500, 'address_dir_primary': nan, 'address_road_primary': 'CARMEL MOUNTAIN', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '459R', 'disposition': 'K', 'beat': 44, 'priority': 3}
# {'incident_num': 'E20090029879', 'date_time': '2020-09-18 09:13:54', 'day_of_week': 6, 'address_number_primary': 0, 'address_dir_primary': nan, 'address_road_primary': 'AVIARY', 'address_sfx_primary': 'CT', 'address_dir_intersecting': nan, 'address_road_intersecting': 'AVIARY', 'address_sfx_intersecting': nan, 'call_type': '586', 'disposition': 'K', 'beat': 65, 'priority': 4}
# {'incident_num': 'E20090029882', 'date_time': '2020-09-18 09:14:57', 'day_of_week': 6, 'address_number_primary': 4200, 'address_dir_primary': nan, 'address_road_primary': '42ND', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '10851R', 'disposition': 'R', 'beat': 90, 'priority': 2}
# {'incident_num': 'E20090029884', 'date_time': '2020-09-18 09:16:23', 'day_of_week': 6, 'address_number_primary': 0, 'address_dir_primary': nan, 'address_road_primary': 'LA JOLLA SHORES', 'address_sfx_primary': 'DR', 'address_dir_intersecting': nan, 'address_road_intersecting': 'CALLE FRESCOTA', 'address_sfx_intersecting': nan, 'call_type': '10851R', 'disposition': 'R', 'beat': 73, 'priority': 2}
# ...
# {'incident_num': 'E20090035094', 'date_time': '2020-09-21 12:46:42', 'day_of_week': 2, 'address_number_primary': 6500, 'address_dir_primary': nan, 'address_road_primary': 'VISTA DEL MAR', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '487', 'disposition': 'R', 'beat': 673, 'priority': 1}
# {'incident_num': 'E20090035175', 'date_time': '2020-09-21 13:39:27', 'day_of_week': 2, 'address_number_primary': 11300, 'address_dir_primary': nan, 'address_road_primary': 'CARMEL COUNTRY', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'MPSSTP', 'disposition': 'K', 'beat': 46, 'priority': 2}
# {'incident_num': 'E20090035205', 'date_time': '2020-09-21 14:07:45', 'day_of_week': 2, 'address_number_primary': 7400, 'address_dir_primary': nan, 'address_road_primary': 'GIRARD', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'HZRD', 'disposition': 'K', 'beat': 72, 'priority': 1}
# {'incident_num': 'E20090035206', 'date_time': '2020-09-21 14:07:58', 'day_of_week': 2, 'address_number_primary': 7800, 'address_dir_primary': nan, 'address_road_primary': 'GIRARD', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '487', 'disposition': 'R', 'beat': 72, 'priority': 1}
# {'incident_num': 'E20090035221', 'date_time': '2020-09-21 14:18:08', 'day_of_week': 2, 'address_number_primary': 4500, 'address_dir_primary': nan, 'address_road_primary': 'LA JOLLA VILLAGE', 'address_sfx_primary': 'DR', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '415', 'disposition': 'K', 'beat': 69, 'priority': 2}
# {'incident_num': 'E20090035224', 'date_time': '2020-09-21 14:19:00', 'day_of_week': 2, 'address_number_primary': 1900, 'address_dir_primary': nan, 'address_road_primary': 'PARKVIEW', 'address_sfx_primary': 'TER', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'HZRD', 'disposition': 'CAN', 'beat': 82, 'priority': 1}
# {'incident_num': 'E20090035243', 'date_time': '2020-09-21 14:27:27', 'day_of_week': 2, 'address_number_primary': 10900, 'address_dir_primary': nan, 'address_road_primary': 'SORRENTO VALLEY', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'MPSSTP', 'disposition': 'O', 'beat': 62, 'priority': 2}
# {'incident_num': 'E20090035263', 'date_time': '2020-09-21 14:42:29', 'day_of_week': 2, 'address_number_primary': 8500, 'address_dir_primary': nan, 'address_road_primary': 'ANDROMEDA', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '586', 'disposition': 'K', 'beat': 55, 'priority': 4}
# {'incident_num': 'E20090035422', 'date_time': '2020-09-21 16:42:02', 'day_of_week': 2, 'address_number_primary': 5400, 'address_dir_primary': nan, 'address_road_primary': 'BAHIA', 'address_sfx_primary': 'LN', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '415', 'disposition': 'DUP', 'beat': 82, 'priority': 2}
# {'incident_num': 'E20090035464', 'date_time': '2020-09-21 17:17:20', 'day_of_week': 2, 'address_number_primary': 12800, 'address_dir_primary': nan, 'address_road_primary': 'EL CAMINO REAL', 'address_sfx_primary': nan, 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'MPSSTP', 'disposition': 'K', 'beat': 54, 'priority': 2}
# {'incident_num': 'E20090036022', 'date_time': '2020-09-22 02:16:07', 'day_of_week': 3, 'address_number_primary': 4500, 'address_dir_primary': nan, 'address_road_primary': 'LA JOLLA VILLAGE', 'address_sfx_primary': 'DR', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '415', 'disposition': 'K', 'beat': 69, 'priority': 2}
# {'incident_num': 'E20090036036', 'date_time': '2020-09-22 02:29:15', 'day_of_week': 3, 'address_number_primary': 8800, 'address_dir_primary': nan, 'address_road_primary': 'VILLA LA JOLLA', 'address_sfx_primary': 'DR', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '415', 'disposition': 'CAN', 'beat': 73, 'priority': 2}
#  73%|████████████████████████         | 413945/567290 [01:00<00:23, 6585.74it/s]
# {'incident_num': 'E20090036100', 'date_time': '2020-09-22 04:12:13', 'day_of_week': 3, 'address_number_primary': 1500, 'address_dir_primary': nan, 'address_road_primary': 'OLIVELLA', 'address_sfx_primary': 'WAY', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '459A', 'disposition': 'CAN', 'beat': 130, 'priority': 3}
# {'incident_num': 'E20090036282', 'date_time': '2020-09-22 07:20:03', 'day_of_week': 3, 'address_number_primary': 0, 'address_dir_primary': nan, 'address_road_primary': 'BERNARDO CENTER', 'address_sfx_primary': 'DR', 'address_dir_intersecting': nan, 'address_road_intersecting': 'AVENIDA ABEJA', 'address_sfx_intersecting': nan, 'call_type': 'HZRD', 'disposition': 'K', 'beat': 28, 'priority': 1}
# {'incident_num': 'E20090036463', 'date_time': '2020-09-22 09:03:19', 'day_of_week': 3, 'address_number_primary': 8600, 'address_dir_primary': nan, 'address_road_primary': 'VIA MALLORCA', 'address_sfx_primary': nan, 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '530', 'disposition': 'R', 'beat': 73, 'priority': 9}
# {'incident_num': 'E20090036559', 'date_time': '2020-09-22 09:56:13', 'day_of_week': 3, 'address_number_primary': 5300, 'address_dir_primary': nan, 'address_road_primary': 'TOSCANA', 'address_sfx_primary': 'WAY', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '530', 'disposition': 'K', 'beat': 69, 'priority': 9}
# {'incident_num': 'E20090036710', 'date_time': '2020-09-22 11:17:35', 'day_of_week': 3, 'address_number_primary': 4600, 'address_dir_primary': nan, 'address_road_primary': 'TORREY', 'address_sfx_primary': 'CIR', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '530', 'disposition': 'K', 'beat': 46, 'priority': 9}
# {'incident_num': 'E20090036761', 'date_time': '2020-09-22 11:53:38', 'day_of_week': 3, 'address_number_primary': 11300, 'address_dir_primary': nan, 'address_road_primary': 'CALENDA', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '5150', 'disposition': 'A', 'beat': 28, 'priority': 2}
# {'incident_num': 'E20090037027', 'date_time': '2020-09-22 14:40:59', 'day_of_week': 3, 'address_number_primary': 12600, 'address_dir_primary': nan, 'address_road_primary': 'CAMINITO RADIANTE', 'address_sfx_primary': nan, 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '653M', 'disposition': 'O', 'beat': 46, 'priority': 9}
# {'incident_num': 'E20090037032', 'date_time': '2020-09-22 14:45:28', 'day_of_week': 3, 'address_number_primary': 3000, 'address_dir_primary': nan, 'address_road_primary': 'DEL MAR HEIGHTS', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'MPSSTP', 'disposition': 'K', 'beat': 54, 'priority': 2}
# {'incident_num': 'E20090037334', 'date_time': '2020-09-22 18:22:54', 'day_of_week': 3, 'address_number_primary': 16800, 'address_dir_primary': nan, 'address_road_primary': 'SAINTSBURY GLEN', 'address_sfx_primary': nan, 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '417', 'disposition': 'K', 'beat': 27, 'priority': 1}
# {'incident_num': 'E20090037476', 'date_time': '2020-09-22 20:06:46', 'day_of_week': 3, 'address_number_primary': 4300, 'address_dir_primary': nan, 'address_road_primary': 'MAIN', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'MPSSTP', 'disposition': 'O', 'beat': 129, 'priority': 2}
# {'incident_num': 'E20090037566', 'date_time': '2020-09-22 21:11:18', 'day_of_week': 3, 'address_number_primary': 1800, 'address_dir_primary': nan, 'address_road_primary': 'BRITANNIA', 'address_sfx_primary': 'BLV', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'MPSSTP', 'disposition': 'O', 'beat': 655, 'priority': 2}
#  73%|████████████████████████▏        | 415292/567290 [01:00<00:22, 6657.21it/s]
# {'incident_num': 'E20090037604', 'date_time': '2020-09-22 21:34:33', 'day_of_week': 3, 'address_number_primary': 1800, 'address_dir_primary': nan, 'address_road_primary': 'BRITANNIA', 'address_sfx_primary': 'BLV', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'MPSSTP', 'disposition': 'O', 'beat': 655, 'priority': 2}
# {'incident_num': 'E20090037635', 'date_time': '2020-09-22 22:05:47', 'day_of_week': 3, 'address_number_primary': 2100, 'address_dir_primary': nan, 'address_road_primary': 'PLAZA', 'address_sfx_primary': 'BLV', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'MPSSTP', 'disposition': 'O', 'beat': 110, 'priority': 2}
# {'incident_num': 'E20090037993', 'date_time': '2020-09-23 06:36:45', 'day_of_week': 4, 'address_number_primary': 5800, 'address_dir_primary': nan, 'address_road_primary': 'MIRA MESA', 'address_sfx_primary': 'BLV', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'MPSSTP', 'disposition': 'O', 'beat': 62, 'priority': 2}
# {'incident_num': 'E20090038015', 'date_time': '2020-09-23 06:57:12', 'day_of_week': 4, 'address_number_primary': 0, 'address_dir_primary': nan, 'address_road_primary': 'BONAIR', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': 'NEPTUNE PL', 'address_sfx_intersecting': nan, 'call_type': '417', 'disposition': 'R', 'beat': 72, 'priority': 0}
# {'incident_num': 'E20090038506', 'date_time': '2020-09-23 11:51:18', 'day_of_week': 4, 'address_number_primary': 11100, 'address_dir_primary': nan, 'address_road_primary': 'BIRDS VIEW', 'address_sfx_primary': 'CT', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '530', 'disposition': 'R', 'beat': 47, 'priority': 9}
# {'incident_num': 'E20090038872', 'date_time': '2020-09-23 16:05:02', 'day_of_week': 4, 'address_number_primary': 4100, 'address_dir_primary': nan, 'address_road_primary': 'NOBEL', 'address_sfx_primary': 'DR', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '470R', 'disposition': 'R', 'beat': 69, 'priority': 9}
#  74%|████████████████████████▎        | 417310/567290 [01:00<00:22, 6711.64it/s]
# {'incident_num': 'E20090039988', 'date_time': '2020-09-24 11:33:51', 'day_of_week': 5, 'address_number_primary': 9100, 'address_dir_primary': nan, 'address_road_primary': 'JUDICIAL', 'address_sfx_primary': 'DR', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '530', 'disposition': 'K', 'beat': 62, 'priority': 9}
# 100%|█████████████████████████████████| 567290/567290 [01:23<00:00, 6784.07it/s]
#  87%|████████████████████████████▌    | 492280/568947 [01:13<00:11, 6789.17it/s]
# {'incident_num': 'E21110008154', 'date_time': '2021-11-06 01:00:11', 'day_of_week': 7, 'address_number_primary': 2100, 'address_dir_primary': nan, 'address_road_primary': 'WUESTE', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'CC', 'disposition': 'W', 'beat': 9, 'priority': 1}
#  98%|████████████████████████████████▌| 560359/568947 [01:23<00:01, 6750.74it/s]
# {'incident_num': 'E21120034745', 'date_time': '2021-12-24 07:39:01', 'day_of_week': 6, 'address_number_primary': 2200, 'address_dir_primary': nan, 'address_road_primary': 'WUESTE', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '10851', 'disposition': 'O', 'beat': 9, 'priority': 0}
# 100%|█████████████████████████████████| 568947/568947 [01:24<00:00, 6709.39it/s]
#   8%|██▌                               | 38045/499256 [00:05<01:08, 6751.96it/s]
# {'incident_num': 'E22010039639', 'date_time': '2022-01-28 15:56:00', 'day_of_week': 6, 'address_number_primary': 2200, 'address_dir_primary': nan, 'address_road_primary': 'WUESTE', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'INFO', 'disposition': 'W', 'beat': 9, 'priority': 2}
#  29%|█████████▋                       | 147098/499256 [00:22<00:54, 6447.73it/s]
# {'incident_num': 'E22040020057', 'date_time': '2022-04-14 10:26:07', 'day_of_week': 5, 'address_number_primary': 2100, 'address_dir_primary': nan, 'address_road_primary': 'WUESTE', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '1153', 'disposition': 'O', 'beat': 9, 'priority': 2}
#  55%|██████████████████               | 272793/499256 [00:42<00:33, 6731.26it/s]
# {'incident_num': 'E22070021780', 'date_time': '2022-07-15 19:14:28', 'day_of_week': 6, 'address_number_primary': 2100, 'address_dir_primary': nan, 'address_road_primary': 'WUESTE', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '415', 'disposition': 'K', 'beat': 9, 'priority': 2}
#  65%|█████████████████████▎           | 322731/499256 [00:49<00:27, 6428.68it/s]
# {'incident_num': 'E22080030527', 'date_time': '2022-08-21 13:25:19', 'day_of_week': 1, 'address_number_primary': 2200, 'address_dir_primary': nan, 'address_road_primary': 'WUESTE', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'CW', 'disposition': 'K', 'beat': 9, 'priority': 1}
#  70%|███████████████████████          | 348156/499256 [00:54<00:27, 5567.21it/s]
# {'incident_num': 'E22090011185', 'date_time': '2022-09-08 07:12:54', 'day_of_week': 5, 'address_number_primary': 2200, 'address_dir_primary': nan, 'address_road_primary': 'WUESTE', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'DC', 'disposition': 'O', 'beat': 9, 'priority': 2}
#  92%|██████████████████████████████▍  | 459995/499256 [01:11<00:05, 6755.47it/s]
# {'incident_num': 'E22110041394', 'date_time': '2022-11-30 14:40:08', 'day_of_week': 4, 'address_number_primary': 2200, 'address_dir_primary': nan, 'address_road_primary': 'WUESTE', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '11-6', 'disposition': 'K', 'beat': 9, 'priority': 1}
# 100%|█████████████████████████████████| 499256/499256 [01:17<00:00, 6440.22it/s]
# 100%|███████████████████████████████████| 44927/44927 [00:06<00:00, 6562.49it/s]

# %% [markdown]
# ### Load Address

# %%
#Address
def Load_Calls_Address(row,cursor,table):
    address_list = [row['address_number_primary'],
               row['address_dir_primary'],
               row['address_road_primary'],
               row['address_sfx_primary'],
                    'San Diego CA'
                   ]
    
    def concatenate_elements(elements):
        result = ''
        for element in elements:
            if element is not None and not pd.isnull(element) and element != 0:
                result += str(element) + ' '
        return result.strip()
    
    
    address = concatenate_elements(address_list)
    
    # Create a new record
    sql = f"""INSERT INTO {table} ( incident_num,
                                    address_number_primary,
                                    address_dir_primary,
                                    address_road_primary,
                                    address_sfx_primary,
                                    address_dir_intersecting,
                                    address_road_intersecting,
                                    address_sfx_intersecting,
                                    address
                                    ) VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)"""

    # Execute the query
    cursor.execute(sql, (row['incident_num'],
                         row['address_number_primary'],
                         row['address_dir_primary'],
                         row['address_road_primary'],
                         row['address_sfx_primary'],
                         row['address_dir_intersecting'],
                         row['address_road_intersecting'],
                         row['address_sfx_intersecting'],
                         address
                        )
                  )
    cnx.commit()

# %%
#Load Address
for year in Years:
    yearly_data = Get_Data(year)
    yearly_data_dict = yearly_data.to_dict('records')
    for row in tqdm(yearly_data_dict):
        #Load Service Calls Address        
        Table = 'Address'
        Key = 'incident_num'
        #Verify if Data is in table
        Data_Found = Find_Data(row,cursor,Table,Key)
        if Data_Found is None:
            #If no data found load
            try:
                pass
                #Load_Calls_Address(row,cursor,Table)
            except:
                pass
                #print(row)
                
        else:
            pass
# Out:
# 100%|█████████████████████████████████| 567290/567290 [03:32<00:00, 2664.60it/s]
# 100%|█████████████████████████████████| 568947/568947 [03:34<00:00, 2655.00it/s]
# 100%|█████████████████████████████████| 499256/499256 [03:04<00:00, 2708.34it/s]
# 100%|███████████████████████████████████| 44927/44927 [00:16<00:00, 2764.51it/s]

# %% [markdown]
# ## Need to improve the address loading, droping to many

# %% [markdown]
# ### Lat and Long

# %%
#Connect to DB
engine = create_engine(f"mysql://{user}:{password}@{host}/{database}")
connection = engine.connect()

# %%
result = connection.execute(
    """
    SELECT incident_num,address from Address

    """)
column_names = result.keys()
rows = result.fetchall()
result_df = pd.DataFrame(rows, columns=column_names)
Address_Book = result_df.head(100)
Address_Book
# Out:
#     incident_num                                address
# 0   E20010000001              400 06TH AVE San Diego CA
# 1   E20010000002       5000 UNIVERSITY AVE San Diego CA
# 2   E20010000003          800 SAWTELLE AVE San Diego CA
# 3   E20010000004       5000 UNIVERSITY AVE San Diego CA
# 4   E20010000005  5200 CLAIREMONT MESA BLV San Diego CA
# ..           ...                                    ...
# 95  E20010000101                 2800 A ST San Diego CA
# 96  E20010000102              3500 AERO CT San Diego CA
# 97  E20010000104             CLAIREMONT DR San Diego CA
# 98  E20010000105                  INFO LOG San Diego CA
# 99  E20010000106         4100 MANZANITA DR San Diego CA
#
# [100 rows x 2 columns]

# %%
def Lat_Long(address):
    lat, lng  = None, None
    api_key = GOOGLE_API_KEY
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"
    endpoint = f"{base_url}?address={address}&key={api_key}"
    r = requests.get(endpoint)
    if r.status_code not in range(200, 299):
        #error
        return None, None
    try:
        #found
        results = r.json()['results'][0]
        lat = results['geometry']['location']['lat']
        lng = results['geometry']['location']['lng']
        
    except:
        pass
    return lat, lng

def DF_GeoCode(row):
    column_name = 'address'
    address_value = row[column_name]
    address_lat, address_lng = Lat_Long(address_value)
    row['lat'] = address_lat
    row['lng'] = address_lng
    
    return row

# %%
Address_Book = Address_Book.apply(DF_GeoCode, axis=1)
Address_Book
# Out:
#     incident_num                                address        lat         lng
# 0   E20010000001              400 06TH AVE San Diego CA  32.709558 -117.159488
# 1   E20010000002       5000 UNIVERSITY AVE San Diego CA  32.749684 -117.086831
# 2   E20010000003          800 SAWTELLE AVE San Diego CA  32.713182 -117.027953
# 3   E20010000004       5000 UNIVERSITY AVE San Diego CA  32.749684 -117.086831
# 4   E20010000005  5200 CLAIREMONT MESA BLV San Diego CA  32.834461 -117.178710
# ..           ...                                    ...        ...         ...
# 95  E20010000101                 2800 A ST San Diego CA  32.718980 -117.133865
# 96  E20010000102              3500 AERO CT San Diego CA  32.807117 -117.148494
# 97  E20010000104             CLAIREMONT DR San Diego CA  32.811799 -117.200921
# 98  E20010000105                  INFO LOG San Diego CA  32.715738 -117.161084
# 99  E20010000106         4100 MANZANITA DR San Diego CA  32.734972 -117.106891
#
# [100 rows x 4 columns]

# %%
#Lat and Long
def Load_LL(row,cursor,table):
    # Create a new record
    sql = f"""INSERT INTO {table} ( incident_num,
                                    lat,
                                    lng
                                    ) VALUES (%s,%s,%s)"""

    # Execute the query
    cursor.execute(sql, (row['incident_num'],
                         row['lat'],
                         row['lng']
                        )
                  )
    cnx.commit()

# %%
for row in tqdm(Address_Book.to_dict('records')):
    Data_Found = Find_Data(row,
                           cursor,
                           'GeoLocations',
                           'incident_num')

    if Data_Found is None:
        #If no data found load 
        Load_LL(row,
                  cursor,
                  'GeoLocations')
    else:
        pass
# Out:
# 100%|███████████████████████████████████████| 100/100 [00:00<00:00, 1491.81it/s]

# %% [markdown]
# ### ZipCode

# %%
from geopy.extra.rate_limiter import RateLimiter
from geopy.geocoders import Nominatim

# %%
result = connection.execute(
    """
    SELECT incident_num,lat,lng from GeoLocations

    """)
column_names = result.keys()
rows = result.fetchall()
ZipCode_Book = pd.DataFrame(rows, columns=column_names)
ZipCode_Book = ZipCode_Book.head(100)
ZipCode_Book
# Out:
#     incident_num        lat          lng
# 0   E20010000001  32.709558  -117.159488
# 1   E20010000002  32.749684  -117.086831
# 2   E20010000003  32.713182  -117.027953
# 3   E20010000004  32.749684  -117.086831
# 4   E20010000005  32.834461  -117.178710
# ..           ...        ...          ...
# 95  E20010000101  32.718980  -117.133865
# 96  E20010000102  32.807117  -117.148495
# 97  E20010000104  32.811799  -117.200921
# 98  E20010000105  32.715738  -117.161084
# 99  E20010000106  32.734972  -117.106891
#
# [100 rows x 3 columns]

# %%
def get_zipcode(df, geolocator, lat_field, lon_field):
    try:
        location = geolocator.reverse((df[lat_field], df[lon_field]))
        result = location.raw['address']['postcode']
    except:
        result = None
    return result

# %%
geolocator = Nominatim(user_agent = user_agent_name)
zipcodes = ZipCode_Book.apply(get_zipcode,
                            axis=1,
                            geolocator=geolocator,
                            lat_field='lat',
                            lon_field='lng'
                           )

# %%
ZipCode_Book['Zipcode'] = zipcodes
ZipCode_Book
# Out:
#     incident_num        lat          lng Zipcode
# 0   E20010000001  32.709558  -117.159488   92101
# 1   E20010000002  32.749684  -117.086831   92105
# 2   E20010000003  32.713182  -117.027953   92114
# 3   E20010000004  32.749684  -117.086831   92105
# 4   E20010000005  32.834461  -117.178710   92117
# ..           ...        ...          ...     ...
# 95  E20010000101  32.718980  -117.133865   92102
# 96  E20010000102  32.807117  -117.148495   92123
# 97  E20010000104  32.811799  -117.200921   92140
# 98  E20010000105  32.715738  -117.161084   92101
# 99  E20010000106  32.734972  -117.106891   92105
#
# [100 rows x 4 columns]

# %%
#Lat and Long
def Load_Zipcode(row,cursor,table):
    # Create a new record
    sql = f"""INSERT INTO {table} ( incident_num,
                                    Zipcode
                                    ) VALUES (%s,%s)"""

    # Execute the query
    cursor.execute(sql, (row['incident_num'],
                         row['Zipcode']
                        )
                  )
    cnx.commit()

# %%
for row in tqdm(ZipCode_Book.to_dict('records')):
    Data_Found = Find_Data(row,
                           cursor,
                           'Zipcodes',
                           'incident_num')

    if Data_Found is None:
        #If no data found load 
        Load_Zipcode(row,
                  cursor,
                  'Zipcodes')
    else:
        pass
# Out:
# 100%|███████████████████████████████████████| 100/100 [00:00<00:00, 1333.43it/s]
