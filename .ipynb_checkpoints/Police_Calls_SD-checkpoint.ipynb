# %% [markdown]
# ![USD](usd.png)

# %% [markdown]
# ### University of San Diego
#
# ### Master of Science, Applied Data Science
#
# #### Contributors
#
# - Ebad Akhter
# - Kevin Baum
# - Salvador Sanchez

# %% [markdown]
# ***

# %%
#Libraries
import pandas as pd
from datetime import datetime
import numpy as np
from geopy.extra.rate_limiter import RateLimiter
from geopy.geocoders import Nominatim
import requests
#from PasswordHolder import password

# %% [markdown]
# # Load Data

# %%
#function to download yearly data
def Get_Data(year):
    url = f"https://seshat.datasd.org/pd/pd_calls_for_service_{year}_datasd.csv"
    df = pd.read_csv(url)
    return df

# %%
url = f"http://seshat.datasd.org/pd/pd_cfs_calltypes_datasd.csv"
call_type = pd.read_csv(url).dropna(axis=1)
call_type['call_length'] = call_type['call_type'].str.len()
call_type['description_length'] = call_type['description'].str.len()
#call_type = call_type.sort_values(by=['call_length'])
call_type = call_type.sort_values(by=['description_length'])
call_type
# Out:
#     call_type                                    description  call_length  \
# 83        245                                            ADW            3
# 79      23152                                            DUI            5
# 41       1171                                           FIRE            4
# 210     COURT                                          COURT            5
# 59        187                                         MURDER            3
# ..        ...                                            ...          ...
# 250    MPSSTP          TRAFFIC STOP FROM THE MOBILE COMPUTER            6
# 78     23110R          THROWING OBJECTS AT AN OCC VEH REPORT            6
# 240     INFOT        INFO ON TRAFFIC,HIT & RUN-ADVISED EVENT            5
# 15    11-6SPT    DISCHARGING FIREARM SHOT SPOTTER ACTIVATION            7
# 241     INFOX  EXTRA PATROL INFO FOR FIELD SGT-ADVISED EVENT            5
#
#      description_length
# 83                    3
# 79                    3
# 41                    4
# 210                   5
# 59                    6
# ..                  ...
# 250                  37
# 78                   37
# 240                  39
# 15                   43
# 241                  45
#
# [289 rows x 4 columns]

# %%
url = f"http://seshat.datasd.org/pd/pd_dispo_codes_datasd.csv"
disposition = pd.read_csv(url).dropna(axis=1)
disposition['description_length'] = disposition['description'].str.len()
disposition = disposition.sort_values(by=['description_length'])
disposition
# Out:
#    dispo_code                                        description  \
# 8           O                                              OTHER
# 15        CAN                                             CANCEL
# 4           R                                             REPORT
# 13          U                                          UNFOUNDED
# 1           A                                        ARREST MADE
# 17          V                                     DUPLICATE CALL
# 10          K                                 NO REPORT REQUIRED
# 16        DUP                             DUPLICATE CALL, XREF'D
# 2          AB                      ARREST MADE, BOARD AND SECURE
# 5          RB                     REPORT TAKEN, BOARD AND SECURE
# 7           S                STOLEN VEHICLE OR RECOVERED VEHICLE
# 11         KB               NO REPORT REQUIRED, BOARD AND SECURE
# 9         OHR            OTHER, HIGH RISK (CRISIS RESPONSE TEAM)
# 6         RHR           REPORT, HIGH RISK (CRISIS RESPONSE TEAM)
# 3         AHR      ARREST MADE, HIGH RISK (CRISIS RESPONSE TEAM)
# 12        KHR  NO FURTHER ACTION, HIGH RISK (CRISIS RESPONSE ...
# 0           X  DISPATCHED ALARM CALL CANCELLED BEFORE UNIT ON...
# 14          W  NO DISPATCH OR INCIDENT CANCLLED PRIOR TO DISP...
#
#     description_length
# 8                    5
# 15                   6
# 4                    6
# 13                   9
# 1                   11
# 17                  14
# 10                  18
# 16                  22
# 2                   29
# 5                   30
# 7                   35
# 11                  36
# 9                   39
# 6                   40
# 3                   45
# 12                  51
# 0                   51
# 14                  60

# %%
beat = pd.read_csv('beat-neighborhood.csv').dropna(axis=1)
beat_split = beat['beat,neighborhood'].str.split(pat=",",
                                                 expand=True)
beat_split = beat_split.rename(columns={0: "beat",
                                        1: "neighborhood"})
beat_split['neighborhood_length'] = beat_split['neighborhood'].str.len()
beat_split = beat_split.sort_values(by=['neighborhood_length'])
beat_split
# Out:
#     beat           neighborhood  neighborhood_length
# 91   722                 Nestor                    6
# 89   714                 Border                    6
# 2    113                 Bay Ho                    6
# 60   522                 Marina                    6
# 111  834                 Castle                    6
# ..   ...                    ...                  ...
# 86   711   Tijuana River Valley                   20
# 1    112   Clairemont Mesa West                   20
# 124  937   Black Mountain Ranch                   20
# 74   615  Roseville/Fleet Ridge                   21
# 112  835  Azalea/Hollywood Park                   21
#
# [125 rows x 3 columns]

# %%
from tabula import read_pdf
url = f"http://seshat.datasd.org/pd/pd_cfs_priority_defs_datasd.pdf"
priority = read_pdf(url)
#priority
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.

# %%
#Current year
current_year = datetime.now().year

# %%
#Current Data
current_data = Get_Data(current_year)

#Last Year
last_year_data = Get_Data(current_year-1)

#Year - 2
yearM2_data = Get_Data(current_year-2)

current_data.tail()
# Out:
#        incident_num            date_time  day_of_week  address_number_primary  \
# 33391  E23010035780  2023-01-25 23:29:01            4                       0
# 33392  E23010035784  2023-01-25 23:37:22            4                     800
# 33393  E23010035785  2023-01-25 23:37:59            4                    4000
# 33394  E23010035786  2023-01-25 23:38:56            4                    3700
# 33395  E23010035789  2023-01-25 23:44:43            4                       0
#
#       address_dir_primary address_road_primary address_sfx_primary  \
# 33391                 NaN                 04TH                 AVE
# 33392                 NaN   HOTEL CIRCLE SOUTH                 NaN
# 33393                 NaN                 46TH                  ST
# 33394                 NaN                 05TH                 AVE
# 33395                 NaN             EL CAJON                 BLV
#
#        address_dir_intersecting address_road_intersecting  \
# 33391                       NaN                         E
# 33392                       NaN                       NaN
# 33393                       NaN                       NaN
# 33394                       NaN                       NaN
# 33395                       NaN                      40TH
#
#        address_sfx_intersecting call_type disposition  beat  priority
# 33391                       NaN       314         DUP   523         2
# 33392                       NaN      1130           K   623         1
# 33393                       NaN      1146           K   831         0
# 33394                       NaN      459A         CAN   627         3
# 33395                       NaN         T           K   832         2

# %% [markdown]
# # EDA

# %%
current_data.describe()
# Out:
#         day_of_week  address_number_primary  address_dir_intersecting  \
# count  33396.000000            33396.000000                       0.0
# mean       3.851689             3394.199605                       NaN
# std        1.903751             3393.516987                       NaN
# min        1.000000                0.000000                       NaN
# 25%        2.000000              600.000000                       NaN
# 50%        4.000000             2800.000000                       NaN
# 75%        5.000000             4800.000000                       NaN
# max        7.000000            53500.000000                       NaN
#
#        address_sfx_intersecting          beat      priority
# count                       0.0  33396.000000  33396.000000
# mean                        NaN    490.853845      2.116391
# std                         NaN    238.810582      1.210111
# min                         NaN     -1.000000      0.000000
# 25%                         NaN    313.000000      1.000000
# 50%                         NaN    521.000000      2.000000
# 75%                         NaN    627.000000      3.000000
# max                         NaN    937.000000      9.000000

# %%
last_year_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499256 entries, 0 to 499255
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   incident_num               499256 non-null  object
#  1   date_time                  499256 non-null  object
#  2   day_of_week                499256 non-null  int64
#  3   address_number_primary     499256 non-null  int64
#  4   address_dir_primary        23135 non-null   object
#  5   address_road_primary       499187 non-null  object
#  6   address_sfx_primary        455019 non-null  object
#  7   address_dir_intersecting   0 non-null       float64
#  8   address_road_intersecting  85382 non-null   object
#  9   address_sfx_intersecting   0 non-null       float64
#  10  call_type                  498640 non-null  object
#  11  disposition                497161 non-null  object
#  12  beat                       499256 non-null  int64
#  13  priority                   499256 non-null  int64
# dtypes: float64(2), int64(4), object(8)
# memory usage: 53.3+ MB

# %%
#Expore Data
def Explore_Data(df):
    #Clean Data
    df = df.dropna(how='all', axis=1)
    
    #Initial table
    freqDF = pd.DataFrame(columns=['Feature',
                                   'Mode',
                                   'Mode Freq.',
                                   'Mode %',
                                   '2nd Mode',
                                   '2nd Mode Freq.',
                                   '2nd Mode %'])
    for col in df.columns:
        freq = df[col].value_counts()
        freqdf = freq.to_frame()
        fRow = freqdf.iloc[0]
        secRow = freqdf.iloc[1]
        fPrct = fRow[0] / len(df[col])
        secPrct = secRow[0] / len(df[col])
        try:
            mode1 = int(fRow.name)
        except:
            mode1 = fRow.name
        try:
            mode2 = int(secRow.name)
        except:
            mode2 = secRow.name
        data = {'Feature':col,
                'Mode':mode1,
                'Mode Freq.':fRow[0],
                'Mode %':fPrct,\
                '2nd Mode':mode2,
                '2nd Mode Freq.':secRow[0],
                '2nd Mode %':secPrct}
        freqDF.loc[len(freqDF)] = data

    freqDF = freqDF.set_index('Feature')

    #Nulls, Counts, Cardinality
    NUllFeatures = round(df.isnull().sum() / df.shape[0],4)\
          .sort_values(ascending=False)
    Count = df.count()
    uni = df.nunique()

    #Formating
    NUllFeatures.to_frame(name="% Miss.")
    Count.to_frame(name="Count")
    uni.to_frame()
    result = pd.concat([Count, NUllFeatures,uni], axis=1)
    result.columns =["Count","% Miss.","Card."]
    result = pd.concat([result, freqDF], axis=1)
    result = result.style.format({'% Miss.': "{:.1%}",
                         'Mode %': "{:.0%}",
                         '2nd Mode %': "{:.0%}",
                         'Count': "{:,}",
                         'Card.': "{:,}",
                         'Mode Freq.': "{:,}",
                        '2nd Mode Freq.': "{:,}"})
    return result

# %%
Explore_Data(current_data)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b0079">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b0079_level0_col0" class="col_heading level0 col0" >Count</th>
#       <th id="T_b0079_level0_col1" class="col_heading level0 col1" >% Miss.</th>
#       <th id="T_b0079_level0_col2" class="col_heading level0 col2" >Card.</th>
#       <th id="T_b0079_level0_col3" class="col_heading level0 col3" >Mode</th>
#       <th id="T_b0079_level0_col4" class="col_heading level0 col4" >Mode Freq.</th>
#       <th id="T_b0079_level0_col5" class="col_heading level0 col5" >Mode %</th>
#       <th id="T_b0079_level0_col6" class="col_heading level0 col6" >2nd Mode</th>
#       <th id="T_b0079_level0_col7" class="col_heading level0 col7" >2nd Mode Freq.</th>
#       <th id="T_b0079_level0_col8" class="col_heading level0 col8" >2nd Mode %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0079_level0_row0" class="row_heading level0 row0" >incident_num</th>
#       <td id="T_b0079_row0_col0" class="data row0 col0" >33,396</td>
#       <td id="T_b0079_row0_col1" class="data row0 col1" >0.0%</td>
#       <td id="T_b0079_row0_col2" class="data row0 col2" >33,396</td>
#       <td id="T_b0079_row0_col3" class="data row0 col3" >E23010000001</td>
#       <td id="T_b0079_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_b0079_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_b0079_row0_col6" class="data row0 col6" >E23010023917</td>
#       <td id="T_b0079_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_b0079_row0_col8" class="data row0 col8" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_b0079_level0_row1" class="row_heading level0 row1" >date_time</th>
#       <td id="T_b0079_row1_col0" class="data row1 col0" >33,396</td>
#       <td id="T_b0079_row1_col1" class="data row1 col1" >0.0%</td>
#       <td id="T_b0079_row1_col2" class="data row1 col2" >33,125</td>
#       <td id="T_b0079_row1_col3" class="data row1 col3" >2023-01-03 20:39:51</td>
#       <td id="T_b0079_row1_col4" class="data row1 col4" >3</td>
#       <td id="T_b0079_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_b0079_row1_col6" class="data row1 col6" >2023-01-20 11:21:40</td>
#       <td id="T_b0079_row1_col7" class="data row1 col7" >3</td>
#       <td id="T_b0079_row1_col8" class="data row1 col8" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_b0079_level0_row2" class="row_heading level0 row2" >day_of_week</th>
#       <td id="T_b0079_row2_col0" class="data row2 col0" >33,396</td>
#       <td id="T_b0079_row2_col1" class="data row2 col1" >0.0%</td>
#       <td id="T_b0079_row2_col2" class="data row2 col2" >7</td>
#       <td id="T_b0079_row2_col3" class="data row2 col3" >4</td>
#       <td id="T_b0079_row2_col4" class="data row2 col4" >5,783</td>
#       <td id="T_b0079_row2_col5" class="data row2 col5" >17%</td>
#       <td id="T_b0079_row2_col6" class="data row2 col6" >3</td>
#       <td id="T_b0079_row2_col7" class="data row2 col7" >5,678</td>
#       <td id="T_b0079_row2_col8" class="data row2 col8" >17%</td>
#     </tr>
#     <tr>
#       <th id="T_b0079_level0_row3" class="row_heading level0 row3" >address_number_primary</th>
#       <td id="T_b0079_row3_col0" class="data row3 col0" >33,396</td>
#       <td id="T_b0079_row3_col1" class="data row3 col1" >0.0%</td>
#       <td id="T_b0079_row3_col2" class="data row3 col2" >201</td>
#       <td id="T_b0079_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_b0079_row3_col4" class="data row3 col4" >5,861</td>
#       <td id="T_b0079_row3_col5" class="data row3 col5" >18%</td>
#       <td id="T_b0079_row3_col6" class="data row3 col6" >1400</td>
#       <td id="T_b0079_row3_col7" class="data row3 col7" >781</td>
#       <td id="T_b0079_row3_col8" class="data row3 col8" >2%</td>
#     </tr>
#     <tr>
#       <th id="T_b0079_level0_row4" class="row_heading level0 row4" >address_dir_primary</th>
#       <td id="T_b0079_row4_col0" class="data row4 col0" >1,659</td>
#       <td id="T_b0079_row4_col1" class="data row4 col1" >95.0%</td>
#       <td id="T_b0079_row4_col2" class="data row4 col2" >8</td>
#       <td id="T_b0079_row4_col3" class="data row4 col3" >S</td>
#       <td id="T_b0079_row4_col4" class="data row4 col4" >555</td>
#       <td id="T_b0079_row4_col5" class="data row4 col5" >2%</td>
#       <td id="T_b0079_row4_col6" class="data row4 col6" >W</td>
#       <td id="T_b0079_row4_col7" class="data row4 col7" >517</td>
#       <td id="T_b0079_row4_col8" class="data row4 col8" >2%</td>
#     </tr>
#     <tr>
#       <th id="T_b0079_level0_row5" class="row_heading level0 row5" >address_road_primary</th>
#       <td id="T_b0079_row5_col0" class="data row5 col0" >33,392</td>
#       <td id="T_b0079_row5_col1" class="data row5 col1" >0.0%</td>
#       <td id="T_b0079_row5_col2" class="data row5 col2" >3,639</td>
#       <td id="T_b0079_row5_col3" class="data row5 col3" >IMPERIAL</td>
#       <td id="T_b0079_row5_col4" class="data row5 col4" >735</td>
#       <td id="T_b0079_row5_col5" class="data row5 col5" >2%</td>
#       <td id="T_b0079_row5_col6" class="data row5 col6" >BROADWAY</td>
#       <td id="T_b0079_row5_col7" class="data row5 col7" >501</td>
#       <td id="T_b0079_row5_col8" class="data row5 col8" >2%</td>
#     </tr>
#     <tr>
#       <th id="T_b0079_level0_row6" class="row_heading level0 row6" >address_sfx_primary</th>
#       <td id="T_b0079_row6_col0" class="data row6 col0" >30,497</td>
#       <td id="T_b0079_row6_col1" class="data row6 col1" >8.7%</td>
#       <td id="T_b0079_row6_col2" class="data row6 col2" >26</td>
#       <td id="T_b0079_row6_col3" class="data row6 col3" >ST</td>
#       <td id="T_b0079_row6_col4" class="data row6 col4" >9,853</td>
#       <td id="T_b0079_row6_col5" class="data row6 col5" >30%</td>
#       <td id="T_b0079_row6_col6" class="data row6 col6" >AVE</td>
#       <td id="T_b0079_row6_col7" class="data row6 col7" >7,789</td>
#       <td id="T_b0079_row6_col8" class="data row6 col8" >23%</td>
#     </tr>
#     <tr>
#       <th id="T_b0079_level0_row7" class="row_heading level0 row7" >address_road_intersecting</th>
#       <td id="T_b0079_row7_col0" class="data row7 col0" >5,431</td>
#       <td id="T_b0079_row7_col1" class="data row7 col1" >83.7%</td>
#       <td id="T_b0079_row7_col2" class="data row7 col2" >1,310</td>
#       <td id="T_b0079_row7_col3" class="data row7 col3" >MARKET</td>
#       <td id="T_b0079_row7_col4" class="data row7 col4" >131</td>
#       <td id="T_b0079_row7_col5" class="data row7 col5" >0%</td>
#       <td id="T_b0079_row7_col6" class="data row7 col6" >IMPERIAL</td>
#       <td id="T_b0079_row7_col7" class="data row7 col7" >124</td>
#       <td id="T_b0079_row7_col8" class="data row7 col8" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_b0079_level0_row8" class="row_heading level0 row8" >call_type</th>
#       <td id="T_b0079_row8_col0" class="data row8 col0" >33,371</td>
#       <td id="T_b0079_row8_col1" class="data row8 col1" >0.1%</td>
#       <td id="T_b0079_row8_col2" class="data row8 col2" >211</td>
#       <td id="T_b0079_row8_col3" class="data row8 col3" >415</td>
#       <td id="T_b0079_row8_col4" class="data row8 col4" >2,535</td>
#       <td id="T_b0079_row8_col5" class="data row8 col5" >8%</td>
#       <td id="T_b0079_row8_col6" class="data row8 col6" >SELENF</td>
#       <td id="T_b0079_row8_col7" class="data row8 col7" >2,097</td>
#       <td id="T_b0079_row8_col8" class="data row8 col8" >6%</td>
#     </tr>
#     <tr>
#       <th id="T_b0079_level0_row9" class="row_heading level0 row9" >disposition</th>
#       <td id="T_b0079_row9_col0" class="data row9 col0" >33,281</td>
#       <td id="T_b0079_row9_col1" class="data row9 col1" >0.3%</td>
#       <td id="T_b0079_row9_col2" class="data row9 col2" >14</td>
#       <td id="T_b0079_row9_col3" class="data row9 col3" >K</td>
#       <td id="T_b0079_row9_col4" class="data row9 col4" >17,536</td>
#       <td id="T_b0079_row9_col5" class="data row9 col5" >53%</td>
#       <td id="T_b0079_row9_col6" class="data row9 col6" >O</td>
#       <td id="T_b0079_row9_col7" class="data row9 col7" >4,869</td>
#       <td id="T_b0079_row9_col8" class="data row9 col8" >15%</td>

# %%
Explore_Date(last_year_data)
# Out:
# <style type="text/css">
# </style>
# <table id="T_168c0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_168c0_level0_col0" class="col_heading level0 col0" >Count</th>
#       <th id="T_168c0_level0_col1" class="col_heading level0 col1" >% Miss.</th>
#       <th id="T_168c0_level0_col2" class="col_heading level0 col2" >Card.</th>
#       <th id="T_168c0_level0_col3" class="col_heading level0 col3" >Mode</th>
#       <th id="T_168c0_level0_col4" class="col_heading level0 col4" >Mode Freq.</th>
#       <th id="T_168c0_level0_col5" class="col_heading level0 col5" >Mode %</th>
#       <th id="T_168c0_level0_col6" class="col_heading level0 col6" >2nd Mode</th>
#       <th id="T_168c0_level0_col7" class="col_heading level0 col7" >2nd Mode Freq.</th>
#       <th id="T_168c0_level0_col8" class="col_heading level0 col8" >2nd Mode %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_168c0_level0_row0" class="row_heading level0 row0" >incident_num</th>
#       <td id="T_168c0_row0_col0" class="data row0 col0" >499,256</td>
#       <td id="T_168c0_row0_col1" class="data row0 col1" >0.0%</td>
#       <td id="T_168c0_row0_col2" class="data row0 col2" >499,256</td>
#       <td id="T_168c0_row0_col3" class="data row0 col3" >E22010000001</td>
#       <td id="T_168c0_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_168c0_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_168c0_row0_col6" class="data row0 col6" >E22080042092</td>
#       <td id="T_168c0_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_168c0_row0_col8" class="data row0 col8" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_168c0_level0_row1" class="row_heading level0 row1" >date_time</th>
#       <td id="T_168c0_row1_col0" class="data row1 col0" >499,256</td>
#       <td id="T_168c0_row1_col1" class="data row1 col1" >0.0%</td>
#       <td id="T_168c0_row1_col2" class="data row1 col2" >495,214</td>
#       <td id="T_168c0_row1_col3" class="data row1 col3" >2022-10-25 10:09:39</td>
#       <td id="T_168c0_row1_col4" class="data row1 col4" >3</td>
#       <td id="T_168c0_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_168c0_row1_col6" class="data row1 col6" >2022-09-21 13:23:37</td>
#       <td id="T_168c0_row1_col7" class="data row1 col7" >3</td>
#       <td id="T_168c0_row1_col8" class="data row1 col8" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_168c0_level0_row2" class="row_heading level0 row2" >day_of_week</th>
#       <td id="T_168c0_row2_col0" class="data row2 col0" >499,256</td>
#       <td id="T_168c0_row2_col1" class="data row2 col1" >0.0%</td>
#       <td id="T_168c0_row2_col2" class="data row2 col2" >7</td>
#       <td id="T_168c0_row2_col3" class="data row2 col3" >5</td>
#       <td id="T_168c0_row2_col4" class="data row2 col4" >76,734</td>
#       <td id="T_168c0_row2_col5" class="data row2 col5" >15%</td>
#       <td id="T_168c0_row2_col6" class="data row2 col6" >6</td>
#       <td id="T_168c0_row2_col7" class="data row2 col7" >74,910</td>
#       <td id="T_168c0_row2_col8" class="data row2 col8" >15%</td>
#     </tr>
#     <tr>
#       <th id="T_168c0_level0_row3" class="row_heading level0 row3" >address_number_primary</th>
#       <td id="T_168c0_row3_col0" class="data row3 col0" >499,256</td>
#       <td id="T_168c0_row3_col1" class="data row3 col1" >0.0%</td>
#       <td id="T_168c0_row3_col2" class="data row3 col2" >233</td>
#       <td id="T_168c0_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_168c0_row3_col4" class="data row3 col4" >92,027</td>
#       <td id="T_168c0_row3_col5" class="data row3 col5" >18%</td>
#       <td id="T_168c0_row3_col6" class="data row3 col6" >1400</td>
#       <td id="T_168c0_row3_col7" class="data row3 col7" >11,347</td>
#       <td id="T_168c0_row3_col8" class="data row3 col8" >2%</td>
#     </tr>
#     <tr>
#       <th id="T_168c0_level0_row4" class="row_heading level0 row4" >address_dir_primary</th>
#       <td id="T_168c0_row4_col0" class="data row4 col0" >23,135</td>
#       <td id="T_168c0_row4_col1" class="data row4 col1" >95.4%</td>
#       <td id="T_168c0_row4_col2" class="data row4 col2" >8</td>
#       <td id="T_168c0_row4_col3" class="data row4 col3" >W</td>
#       <td id="T_168c0_row4_col4" class="data row4 col4" >8,001</td>
#       <td id="T_168c0_row4_col5" class="data row4 col5" >2%</td>
#       <td id="T_168c0_row4_col6" class="data row4 col6" >S</td>
#       <td id="T_168c0_row4_col7" class="data row4 col7" >7,227</td>
#       <td id="T_168c0_row4_col8" class="data row4 col8" >1%</td>
#     </tr>
#     <tr>
#       <th id="T_168c0_level0_row5" class="row_heading level0 row5" >address_road_primary</th>
#       <td id="T_168c0_row5_col0" class="data row5 col0" >499,187</td>
#       <td id="T_168c0_row5_col1" class="data row5 col1" >0.0%</td>
#       <td id="T_168c0_row5_col2" class="data row5 col2" >10,076</td>
#       <td id="T_168c0_row5_col3" class="data row5 col3" >IMPERIAL</td>
#       <td id="T_168c0_row5_col4" class="data row5 col4" >8,701</td>
#       <td id="T_168c0_row5_col5" class="data row5 col5" >2%</td>
#       <td id="T_168c0_row5_col6" class="data row5 col6" >05TH</td>
#       <td id="T_168c0_row5_col7" class="data row5 col7" >8,389</td>
#       <td id="T_168c0_row5_col8" class="data row5 col8" >2%</td>
#     </tr>
#     <tr>
#       <th id="T_168c0_level0_row6" class="row_heading level0 row6" >address_sfx_primary</th>
#       <td id="T_168c0_row6_col0" class="data row6 col0" >455,019</td>
#       <td id="T_168c0_row6_col1" class="data row6 col1" >8.9%</td>
#       <td id="T_168c0_row6_col2" class="data row6 col2" >40</td>
#       <td id="T_168c0_row6_col3" class="data row6 col3" >ST</td>
#       <td id="T_168c0_row6_col4" class="data row6 col4" >146,772</td>
#       <td id="T_168c0_row6_col5" class="data row6 col5" >29%</td>
#       <td id="T_168c0_row6_col6" class="data row6 col6" >AVE</td>
#       <td id="T_168c0_row6_col7" class="data row6 col7" >116,831</td>
#       <td id="T_168c0_row6_col8" class="data row6 col8" >23%</td>
#     </tr>
#     <tr>
#       <th id="T_168c0_level0_row7" class="row_heading level0 row7" >address_road_intersecting</th>
#       <td id="T_168c0_row7_col0" class="data row7 col0" >85,382</td>
#       <td id="T_168c0_row7_col1" class="data row7 col1" >82.9%</td>
#       <td id="T_168c0_row7_col2" class="data row7 col2" >4,556</td>
#       <td id="T_168c0_row7_col3" class="data row7 col3" >MARKET</td>
#       <td id="T_168c0_row7_col4" class="data row7 col4" >2,263</td>
#       <td id="T_168c0_row7_col5" class="data row7 col5" >0%</td>
#       <td id="T_168c0_row7_col6" class="data row7 col6" >UNIVERSITY</td>
#       <td id="T_168c0_row7_col7" class="data row7 col7" >2,213</td>
#       <td id="T_168c0_row7_col8" class="data row7 col8" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_168c0_level0_row8" class="row_heading level0 row8" >call_type</th>
#       <td id="T_168c0_row8_col0" class="data row8 col0" >498,640</td>
#       <td id="T_168c0_row8_col1" class="data row8 col1" >0.1%</td>
#       <td id="T_168c0_row8_col2" class="data row8 col2" >238</td>
#       <td id="T_168c0_row8_col3" class="data row8 col3" >415</td>
#       <td id="T_168c0_row8_col4" class="data row8 col4" >42,668</td>
#       <td id="T_168c0_row8_col5" class="data row8 col5" >9%</td>
#       <td id="T_168c0_row8_col6" class="data row8 col6" >CW</td>
#       <td id="T_168c0_row8_col7" class="data row8 col7" >24,684</td>
#       <td id="T_168c0_row8_col8" class="data row8 col8" >5%</td>
#     </tr>
#     <tr>
#       <th id="T_168c0_level0_row9" class="row_heading level0 row9" >disposition</th>
#       <td id="T_168c0_row9_col0" class="data row9 col0" >497,161</td>
#       <td id="T_168c0_row9_col1" class="data row9 col1" >0.4%</td>
#       <td id="T_168c0_row9_col2" class="data row9 col2" >19</td>
#       <td id="T_168c0_row9_col3" class="data row9 col3" >K</td>
#       <td id="T_168c0_row9_col4" class="data row9 col4" >259,055</td>
#       <td id="T_168c0_row9_col5" class="data row9 col5" >52%</td>
#       <td id="T_168c0_row9_col6" class="data row9 col6" >O</td>
#       <td id="T_168c0_row9_col7" class="data row9 col7" >71,580</td>
#       <td id="T_168c0_row9_col8" c

# %%
Explore_Date(yearM2_data)
# Out:
# <style type="text/css">
# </style>
# <table id="T_73013">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73013_level0_col0" class="col_heading level0 col0" >Count</th>
#       <th id="T_73013_level0_col1" class="col_heading level0 col1" >% Miss.</th>
#       <th id="T_73013_level0_col2" class="col_heading level0 col2" >Card.</th>
#       <th id="T_73013_level0_col3" class="col_heading level0 col3" >Mode</th>
#       <th id="T_73013_level0_col4" class="col_heading level0 col4" >Mode Freq.</th>
#       <th id="T_73013_level0_col5" class="col_heading level0 col5" >Mode %</th>
#       <th id="T_73013_level0_col6" class="col_heading level0 col6" >2nd Mode</th>
#       <th id="T_73013_level0_col7" class="col_heading level0 col7" >2nd Mode Freq.</th>
#       <th id="T_73013_level0_col8" class="col_heading level0 col8" >2nd Mode %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73013_level0_row0" class="row_heading level0 row0" >incident_num</th>
#       <td id="T_73013_row0_col0" class="data row0 col0" >568,947</td>
#       <td id="T_73013_row0_col1" class="data row0 col1" >0.0%</td>
#       <td id="T_73013_row0_col2" class="data row0 col2" >568,947</td>
#       <td id="T_73013_row0_col3" class="data row0 col3" >E21010000001</td>
#       <td id="T_73013_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_73013_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_73013_row0_col6" class="data row0 col6" >E21080040927</td>
#       <td id="T_73013_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_73013_row0_col8" class="data row0 col8" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_73013_level0_row1" class="row_heading level0 row1" >date_time</th>
#       <td id="T_73013_row1_col0" class="data row1 col0" >568,947</td>
#       <td id="T_73013_row1_col1" class="data row1 col1" >0.0%</td>
#       <td id="T_73013_row1_col2" class="data row1 col2" >563,769</td>
#       <td id="T_73013_row1_col3" class="data row1 col3" >2021-09-11 17:49:41</td>
#       <td id="T_73013_row1_col4" class="data row1 col4" >3</td>
#       <td id="T_73013_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_73013_row1_col6" class="data row1 col6" >2021-12-12 16:39:26</td>
#       <td id="T_73013_row1_col7" class="data row1 col7" >3</td>
#       <td id="T_73013_row1_col8" class="data row1 col8" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_73013_level0_row2" class="row_heading level0 row2" >day_of_week</th>
#       <td id="T_73013_row2_col0" class="data row2 col0" >568,947</td>
#       <td id="T_73013_row2_col1" class="data row2 col1" >0.0%</td>
#       <td id="T_73013_row2_col2" class="data row2 col2" >7</td>
#       <td id="T_73013_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_73013_row2_col4" class="data row2 col4" >84,636</td>
#       <td id="T_73013_row2_col5" class="data row2 col5" >15%</td>
#       <td id="T_73013_row2_col6" class="data row2 col6" >5</td>
#       <td id="T_73013_row2_col7" class="data row2 col7" >83,508</td>
#       <td id="T_73013_row2_col8" class="data row2 col8" >15%</td>
#     </tr>
#     <tr>
#       <th id="T_73013_level0_row3" class="row_heading level0 row3" >address_number_primary</th>
#       <td id="T_73013_row3_col0" class="data row3 col0" >568,947</td>
#       <td id="T_73013_row3_col1" class="data row3 col1" >0.0%</td>
#       <td id="T_73013_row3_col2" class="data row3 col2" >237</td>
#       <td id="T_73013_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_73013_row3_col4" class="data row3 col4" >102,341</td>
#       <td id="T_73013_row3_col5" class="data row3 col5" >18%</td>
#       <td id="T_73013_row3_col6" class="data row3 col6" >4000</td>
#       <td id="T_73013_row3_col7" class="data row3 col7" >10,980</td>
#       <td id="T_73013_row3_col8" class="data row3 col8" >2%</td>
#     </tr>
#     <tr>
#       <th id="T_73013_level0_row4" class="row_heading level0 row4" >address_dir_primary</th>
#       <td id="T_73013_row4_col0" class="data row4 col0" >27,114</td>
#       <td id="T_73013_row4_col1" class="data row4 col1" >95.2%</td>
#       <td id="T_73013_row4_col2" class="data row4 col2" >9</td>
#       <td id="T_73013_row4_col3" class="data row4 col3" >W</td>
#       <td id="T_73013_row4_col4" class="data row4 col4" >10,033</td>
#       <td id="T_73013_row4_col5" class="data row4 col5" >2%</td>
#       <td id="T_73013_row4_col6" class="data row4 col6" >S</td>
#       <td id="T_73013_row4_col7" class="data row4 col7" >8,669</td>
#       <td id="T_73013_row4_col8" class="data row4 col8" >2%</td>
#     </tr>
#     <tr>
#       <th id="T_73013_level0_row5" class="row_heading level0 row5" >address_road_primary</th>
#       <td id="T_73013_row5_col0" class="data row5 col0" >568,832</td>
#       <td id="T_73013_row5_col1" class="data row5 col1" >0.0%</td>
#       <td id="T_73013_row5_col2" class="data row5 col2" >10,353</td>
#       <td id="T_73013_row5_col3" class="data row5 col3" >IMPERIAL</td>
#       <td id="T_73013_row5_col4" class="data row5 col4" >10,651</td>
#       <td id="T_73013_row5_col5" class="data row5 col5" >2%</td>
#       <td id="T_73013_row5_col6" class="data row5 col6" >05TH</td>
#       <td id="T_73013_row5_col7" class="data row5 col7" >9,082</td>
#       <td id="T_73013_row5_col8" class="data row5 col8" >2%</td>
#     </tr>
#     <tr>
#       <th id="T_73013_level0_row6" class="row_heading level0 row6" >address_sfx_primary</th>
#       <td id="T_73013_row6_col0" class="data row6 col0" >521,939</td>
#       <td id="T_73013_row6_col1" class="data row6 col1" >8.3%</td>
#       <td id="T_73013_row6_col2" class="data row6 col2" >40</td>
#       <td id="T_73013_row6_col3" class="data row6 col3" >ST</td>
#       <td id="T_73013_row6_col4" class="data row6 col4" >171,706</td>
#       <td id="T_73013_row6_col5" class="data row6 col5" >30%</td>
#       <td id="T_73013_row6_col6" class="data row6 col6" >AVE</td>
#       <td id="T_73013_row6_col7" class="data row6 col7" >135,702</td>
#       <td id="T_73013_row6_col8" class="data row6 col8" >24%</td>
#     </tr>
#     <tr>
#       <th id="T_73013_level0_row7" class="row_heading level0 row7" >address_road_intersecting</th>
#       <td id="T_73013_row7_col0" class="data row7 col0" >95,028</td>
#       <td id="T_73013_row7_col1" class="data row7 col1" >83.3%</td>
#       <td id="T_73013_row7_col2" class="data row7 col2" >4,750</td>
#       <td id="T_73013_row7_col3" class="data row7 col3" >MARKET</td>
#       <td id="T_73013_row7_col4" class="data row7 col4" >2,686</td>
#       <td id="T_73013_row7_col5" class="data row7 col5" >0%</td>
#       <td id="T_73013_row7_col6" class="data row7 col6" >UNIVERSITY</td>
#       <td id="T_73013_row7_col7" class="data row7 col7" >2,500</td>
#       <td id="T_73013_row7_col8" class="data row7 col8" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_73013_level0_row8" class="row_heading level0 row8" >call_type</th>
#       <td id="T_73013_row8_col0" class="data row8 col0" >568,510</td>
#       <td id="T_73013_row8_col1" class="data row8 col1" >0.1%</td>
#       <td id="T_73013_row8_col2" class="data row8 col2" >243</td>
#       <td id="T_73013_row8_col3" class="data row8 col3" >415</td>
#       <td id="T_73013_row8_col4" class="data row8 col4" >51,777</td>
#       <td id="T_73013_row8_col5" class="data row8 col5" >9%</td>
#       <td id="T_73013_row8_col6" class="data row8 col6" >SELENF</td>
#       <td id="T_73013_row8_col7" class="data row8 col7" >37,704</td>
#       <td id="T_73013_row8_col8" class="data row8 col8" >7%</td>
#     </tr>
#     <tr>
#       <th id="T_73013_level0_row9" class="row_heading level0 row9" >disposition</th>
#       <td id="T_73013_row9_col0" class="data row9 col0" >567,355</td>
#       <td id="T_73013_row9_col1" class="data row9 col1" >0.3%</td>
#       <td id="T_73013_row9_col2" class="data row9 col2" >18</td>
#       <td id="T_73013_row9_col3" class="data row9 col3" >K</td>
#       <td id="T_73013_row9_col4" class="data row9 col4" >296,902</td>
#       <td id="T_73013_row9_col5" class="data row9 col5" >52%</td>
#       <td id="T_73013_row9_col6" class="data row9 col6" >O</td>
#       <td id="T_73013_row9_col7" class="data row9 col7" >86,013</td>
#       <td id="T_73013_row9_

# %% [markdown]
# # Data Prep

# %%
def AddressNumberStr(df):
    df['address_number_primary_str'] = df['address_number_primary'].astype(str)
    df.address_number_primary_str.replace('0', np.nan, inplace=True)
    return df

# %%
def AddressField(df,City,State):
    df['Address'] = df[['address_number_primary_str',
                        'address_dir_primary',
                        'address_road_primary',
                        'address_sfx_primary']].apply(lambda x: ' '.join(x.dropna()), axis=1)
    df['Address'] = df['Address'] + ' ' + City +', ' + State
    return df

# %%
Address_Data = AddressNumberStr(current_data)
Address_Data = AddressField(current_data,'San Diego','California')

# %%
Address_Data.tail()
# Out:
#        incident_num            date_time  day_of_week  address_number_primary  \
# 33391  E23010035780  2023-01-25 23:29:01            4                       0
# 33392  E23010035784  2023-01-25 23:37:22            4                     800
# 33393  E23010035785  2023-01-25 23:37:59            4                    4000
# 33394  E23010035786  2023-01-25 23:38:56            4                    3700
# 33395  E23010035789  2023-01-25 23:44:43            4                       0
#
#       address_dir_primary address_road_primary address_sfx_primary  \
# 33391                 NaN                 04TH                 AVE
# 33392                 NaN   HOTEL CIRCLE SOUTH                 NaN
# 33393                 NaN                 46TH                  ST
# 33394                 NaN                 05TH                 AVE
# 33395                 NaN             EL CAJON                 BLV
#
#        address_dir_intersecting address_road_intersecting  \
# 33391                       NaN                         E
# 33392                       NaN                       NaN
# 33393                       NaN                       NaN
# 33394                       NaN                       NaN
# 33395                       NaN                      40TH
#
#        address_sfx_intersecting call_type disposition  beat  priority  \
# 33391                       NaN       314         DUP   523         2
# 33392                       NaN      1130           K   623         1
# 33393                       NaN      1146           K   831         0
# 33394                       NaN      459A         CAN   627         3
# 33395                       NaN         T           K   832         2
#
#       address_number_primary_str                                       Address
# 33391                        NaN                04TH AVE San Diego, California
# 33392                        800  800 HOTEL CIRCLE SOUTH San Diego, California
# 33393                       4000            4000 46TH ST San Diego, California
# 33394                       3700           3700 05TH AVE San Diego, California
# 33395                        NaN            EL CAJON BLV San Diego, California

# %% [markdown]
# # Geo Location Data Google Lat and Long

# %%
def Lat_Long(address):
    lat, lng, zipcode  = None, None, None
    api_key = GOOGLE_API_KEY
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"
    endpoint = f"{base_url}?address={address}&key={api_key}"
    r = requests.get(endpoint)
    if r.status_code not in range(200, 299):
        #error
        return None, None
    try:
        #found
        results = r.json()['results'][0]
        lat = results['geometry']['location']['lat']
        lng = results['geometry']['location']['lng']
        zipcode = results['address_components'][-1]['long_name']
        
    except:
        pass
    return lat, lng, zipcode

def DF_GeoCode(row):
    column_name = 'Address'
    address_value = row[column_name]
    address_lat, address_lng, address_zip = Lat_Long(address_value)
    row['lat'] = address_lat
    row['lng'] = address_lng
    row['zipcode'] = address_zip
    
    return row

# %%
Last2000 = Address_Data.tail(10000)
Last10 = Address_Data.tail(10)

# %%
Last10_Geo = Last10.apply(DF_GeoCode, axis=1)

# %%
Last10_Geo
# Out:
#        incident_num            date_time  day_of_week  address_number_primary  \
# 33386  E23010035772  2023-01-25 23:23:53            4                    9400
# 33387  E23010035773  2023-01-25 23:24:05            4                     700
# 33388  E23010035776  2023-01-25 23:26:58            4                    1800
# 33389  E23010035777  2023-01-25 23:27:25            4                     900
# 33390  E23010035779  2023-01-25 23:29:00            4                    9400
# 33391  E23010035780  2023-01-25 23:29:01            4                       0
# 33392  E23010035784  2023-01-25 23:37:22            4                     800
# 33393  E23010035785  2023-01-25 23:37:59            4                    4000
# 33394  E23010035786  2023-01-25 23:38:56            4                    3700
# 33395  E23010035789  2023-01-25 23:44:43            4                       0
#
#       address_dir_primary address_road_primary address_sfx_primary  \
# 33386                 NaN            MIRA MESA                 BLV
# 33387                   W                  FIR                  ST
# 33388                 NaN   HOTEL CIRCLE SOUTH                 NaN
# 33389                 NaN                 05TH                 AVE
# 33390                 NaN            MIRA MESA                 BLV
# 33391                 NaN                 04TH                 AVE
# 33392                 NaN   HOTEL CIRCLE SOUTH                 NaN
# 33393                 NaN                 46TH                  ST
# 33394                 NaN                 05TH                 AVE
# 33395                 NaN             EL CAJON                 BLV
#
#        address_dir_intersecting address_road_intersecting  \
# 33386                       NaN                       NaN
# 33387                       NaN                       NaN
# 33388                       NaN                       NaN
# 33389                       NaN                       NaN
# 33390                       NaN                       NaN
# 33391                       NaN                         E
# 33392                       NaN                       NaN
# 33393                       NaN                       NaN
# 33394                       NaN                       NaN
# 33395                       NaN                      40TH
#
#        address_sfx_intersecting call_type disposition  beat  priority  \
# 33386                       NaN       415           K   242         2
# 33387                       NaN    SELENF           U   528         3
# 33388                       NaN      415N           K   623         3
# 33389                       NaN       911           K   523         1
# 33390                       NaN        FD           K   242         2
# 33391                       NaN       314         DUP   523         2
# 33392                       NaN      1130           K   623         1
# 33393                       NaN      1146           K   831         0
# 33394                       NaN      459A         CAN   627         3
# 33395                       NaN         T           K   832         2
#
#       address_number_primary_str  \
# 33386                       9400
# 33387                        700
# 33388                       1800
# 33389                        900
# 33390                       9400
# 33391                        NaN
# 33392                        800
# 33393                       4000
# 33394                       3700
# 33395                        NaN
#
#                                              Address        lat         lng  \
# 33386       9400 MIRA MESA BLV San Diego, California  32.917513 -117.122661
# 33387             700 W FIR ST San Diego, California  32.724368 -117.168719
# 33388  1800 HOTEL CIRCLE SOUTH San Diego, California  32.759330 -117.179314
# 33389             900 05TH AVE San Diego, California  32.714816 -117.160416
# 33390       9400 MIRA MESA BLV San Diego, California  32.917513 -117.122661
# 33391                 04TH AVE San Diego, California  32.731232 -117.161241
# 33392   800 HOTEL CIRCLE SOUTH San Diego, California  32.759391 -117.177008
# 33393             4000 46TH ST San Diego, California  32.749581 -117.095525
# 33394            3700 05TH AVE San Diego, California  32.745135 -117.160394
# 33395             EL CAJON BLV San Diego, California  32.757308 -117.083611
#
#              zipcode
# 33386           4846
# 33387          92101
# 33388          92108
# 33389          92101
# 33390           4846
# 33391  United States
# 33392          92108
# 33393          92105
# 33394           4224
# 33395  United States

# %%
Last10.to_csv('Last10.csv')

# %%
Last2000_Geo = Last2000.apply(DF_GeoCode, axis=1)

# %%
Last2000_Geo.to_csv('Last2000_Geo.csv')

# %%
Last2000_Geo
# Out:
#        incident_num            date_time  day_of_week  address_number_primary  \
# 23396  E23010025101  2023-01-18 17:00:02            4                    1600
# 23397  E23010025102  2023-01-18 17:00:17            4                       0
# 23398  E23010025103  2023-01-18 17:01:35            4                       0
# 23399  E23010025104  2023-01-18 17:01:52            4                     500
# 23400  E23010025106  2023-01-18 17:03:51            4                       0
# ...             ...                  ...          ...                     ...
# 33391  E23010035780  2023-01-25 23:29:01            4                       0
# 33392  E23010035784  2023-01-25 23:37:22            4                     800
# 33393  E23010035785  2023-01-25 23:37:59            4                    4000
# 33394  E23010035786  2023-01-25 23:38:56            4                    3700
# 33395  E23010035789  2023-01-25 23:44:43            4                       0
#
#       address_dir_primary address_road_primary address_sfx_primary  \
# 23396                 NaN                 06TH                 AVE
# 23397                 NaN              HILLTOP                  DR
# 23398                 NaN         SPORTS ARENA                 BLV
# 23399                   S                 38TH                  ST
# 23400                 NaN              HANCOCK                  ST
# ...                   ...                  ...                 ...
# 33391                 NaN                 04TH                 AVE
# 33392                 NaN   HOTEL CIRCLE SOUTH                 NaN
# 33393                 NaN                 46TH                  ST
# 33394                 NaN                 05TH                 AVE
# 33395                 NaN             EL CAJON                 BLV
#
#        address_dir_intersecting address_road_intersecting  \
# 23396                       NaN                       NaN
# 23397                       NaN                    COTTON
# 23398                       NaN   INTERSTATE 8 EB ON RAMP
# 23399                       NaN                       NaN
# 23400                       NaN                 GREENWOOD
# ...                         ...                       ...
# 33391                       NaN                         E
# 33392                       NaN                       NaN
# 33393                       NaN                       NaN
# 33394                       NaN                       NaN
# 33395                       NaN                      40TH
#
#        address_sfx_intersecting call_type disposition  beat  priority  \
# 23396                       NaN       415         CAN   526         2
# 23397                       NaN      1149           K   445         2
# 23398                       NaN       415           K   613         2
# 23399                       NaN      HZRD           K   441         2
# 23400                       NaN      1151           K   611         2
# ...                         ...       ...         ...   ...       ...
# 33391                       NaN       314         DUP   523         2
# 33392                       NaN      1130           K   623         1
# 33393                       NaN      1146           K   831         0
# 33394                       NaN      459A         CAN   627         3
# 33395                       NaN         T           K   832         2
#
#       address_number_primary_str  \
# 23396                       1600
# 23397                        NaN
# 23398                        NaN
# 23399                        500
# 23400                        NaN
# ...                          ...
# 33391                        NaN
# 33392                        800
# 33393                       4000
# 33394                       3700
# 33395                        NaN
#
#                                             Address        lat         lng  \
# 23396           1600 06TH AVE San Diego, California  32.722117 -117.159458
# 23397              HILLTOP DR San Diego, California  32.715075 -117.095691
# 23398        SPORTS ARENA BLV San Diego, California  32.753394 -117.210509
# 23399           500 S 38TH ST San Diego, California  32.701259 -117.112516
# 23400              HANCOCK ST San Diego, California  32.753068 -117.203168
# ...                                             ...        ...         ...
# 33391                04TH AVE San Diego, California  32.731232 -117.161241
# 33392  800 HOTEL CIRCLE SOUTH San Diego, California  32.759391 -117.177008
# 33393            4000 46TH ST San Diego, California  32.749581 -117.095525
# 33394           3700 05TH AVE San Diego, California  32.745135 -117.160394
# 33395            EL CAJON BLV San Diego, California  32.757308 -117.083611
#
#              zipcode
# 23396          92101
# 23397  United States
# 23398  United States
# 23399           2854
# 23400  United States
# ...              ...
# 33391  United States
# 33392          92108
# 33393          92105
# 33394           4224
# 33395  United States
#
# [10000 rows x 19 columns]

# %% [markdown]
# # Geo Location Data Zipcode

# %%
def get_zipcode(df, geolocator, lat_field, lon_field):
    try:
        location = geolocator.reverse((df[lat_field], df[lon_field]))
        result = location.raw['address']['postcode']
    except:
        result = None
    return result

# %%
zipcodes = Last10_Geo.apply(get_zipcode,
                            axis=1,
                            geolocator=locator,
                            lat_field='lat',
                            lon_field='lng'
                           )

# %%
zipcodes

# %%
Last2000_Geo['Zipcodes'] = Last2000_Geo.apply(get_zipcode,
                            axis=1,
                            geolocator=locator,
                            lat_field='lat',
                            lon_field='lng'
                           )

# %%
Last2000_Geo
# Out:
#        incident_num            date_time  day_of_week  address_number_primary  \
# 23396  E23010025101  2023-01-18 17:00:02            4                    1600
# 23397  E23010025102  2023-01-18 17:00:17            4                       0
# 23398  E23010025103  2023-01-18 17:01:35            4                       0
# 23399  E23010025104  2023-01-18 17:01:52            4                     500
# 23400  E23010025106  2023-01-18 17:03:51            4                       0
# ...             ...                  ...          ...                     ...
# 33391  E23010035780  2023-01-25 23:29:01            4                       0
# 33392  E23010035784  2023-01-25 23:37:22            4                     800
# 33393  E23010035785  2023-01-25 23:37:59            4                    4000
# 33394  E23010035786  2023-01-25 23:38:56            4                    3700
# 33395  E23010035789  2023-01-25 23:44:43            4                       0
#
#       address_dir_primary address_road_primary address_sfx_primary  \
# 23396                 NaN                 06TH                 AVE
# 23397                 NaN              HILLTOP                  DR
# 23398                 NaN         SPORTS ARENA                 BLV
# 23399                   S                 38TH                  ST
# 23400                 NaN              HANCOCK                  ST
# ...                   ...                  ...                 ...
# 33391                 NaN                 04TH                 AVE
# 33392                 NaN   HOTEL CIRCLE SOUTH                 NaN
# 33393                 NaN                 46TH                  ST
# 33394                 NaN                 05TH                 AVE
# 33395                 NaN             EL CAJON                 BLV
#
#        address_dir_intersecting address_road_intersecting  \
# 23396                       NaN                       NaN
# 23397                       NaN                    COTTON
# 23398                       NaN   INTERSTATE 8 EB ON RAMP
# 23399                       NaN                       NaN
# 23400                       NaN                 GREENWOOD
# ...                         ...                       ...
# 33391                       NaN                         E
# 33392                       NaN                       NaN
# 33393                       NaN                       NaN
# 33394                       NaN                       NaN
# 33395                       NaN                      40TH
#
#        address_sfx_intersecting call_type disposition  beat  priority  \
# 23396                       NaN       415         CAN   526         2
# 23397                       NaN      1149           K   445         2
# 23398                       NaN       415           K   613         2
# 23399                       NaN      HZRD           K   441         2
# 23400                       NaN      1151           K   611         2
# ...                         ...       ...         ...   ...       ...
# 33391                       NaN       314         DUP   523         2
# 33392                       NaN      1130           K   623         1
# 33393                       NaN      1146           K   831         0
# 33394                       NaN      459A         CAN   627         3
# 33395                       NaN         T           K   832         2
#
#       address_number_primary_str  \
# 23396                       1600
# 23397                        NaN
# 23398                        NaN
# 23399                        500
# 23400                        NaN
# ...                          ...
# 33391                        NaN
# 33392                        800
# 33393                       4000
# 33394                       3700
# 33395                        NaN
#
#                                             Address        lat         lng  \
# 23396           1600 06TH AVE San Diego, California  32.722117 -117.159458
# 23397              HILLTOP DR San Diego, California  32.715075 -117.095691
# 23398        SPORTS ARENA BLV San Diego, California  32.753394 -117.210509
# 23399           500 S 38TH ST San Diego, California  32.701259 -117.112516
# 23400              HANCOCK ST San Diego, California  32.753068 -117.203168
# ...                                             ...        ...         ...
# 33391                04TH AVE San Diego, California  32.731232 -117.161241
# 33392  800 HOTEL CIRCLE SOUTH San Diego, California  32.759391 -117.177008
# 33393            4000 46TH ST San Diego, California  32.749581 -117.095525
# 33394           3700 05TH AVE San Diego, California  32.745135 -117.160394
# 33395            EL CAJON BLV San Diego, California  32.757308 -117.083611
#
#              zipcode Zipcodes
# 23396          92101    92101
# 23397  United States    92102
# 23398  United States    92110
# 23399           2854    92113
# 23400  United States    92110
# ...              ...      ...
# 33391  United States    92101
# 33392          92108    92103
# 33393          92105    92105
# 33394           4224    92103
# 33395  United States    92115
#
# [10000 rows x 20 columns]

# %%
Last2000_Geo.to_csv('Last2000_Geo.csv')

# %%
test = pd.read_csv('Last2000_Geo.csv')
test
# Out:
#       Unnamed: 0  incident_num            date_time  day_of_week  \
# 0          23396  E23010025101  2023-01-18 17:00:02            4
# 1          23397  E23010025102  2023-01-18 17:00:17            4
# 2          23398  E23010025103  2023-01-18 17:01:35            4
# 3          23399  E23010025104  2023-01-18 17:01:52            4
# 4          23400  E23010025106  2023-01-18 17:03:51            4
# ...          ...           ...                  ...          ...
# 9995       33391  E23010035780  2023-01-25 23:29:01            4
# 9996       33392  E23010035784  2023-01-25 23:37:22            4
# 9997       33393  E23010035785  2023-01-25 23:37:59            4
# 9998       33394  E23010035786  2023-01-25 23:38:56            4
# 9999       33395  E23010035789  2023-01-25 23:44:43            4
#
#       address_number_primary address_dir_primary address_road_primary  \
# 0                       1600                 NaN                 06TH
# 1                          0                 NaN              HILLTOP
# 2                          0                 NaN         SPORTS ARENA
# 3                        500                   S                 38TH
# 4                          0                 NaN              HANCOCK
# ...                      ...                 ...                  ...
# 9995                       0                 NaN                 04TH
# 9996                     800                 NaN   HOTEL CIRCLE SOUTH
# 9997                    4000                 NaN                 46TH
# 9998                    3700                 NaN                 05TH
# 9999                       0                 NaN             EL CAJON
#
#      address_sfx_primary  address_dir_intersecting address_road_intersecting  \
# 0                    AVE                       NaN                       NaN
# 1                     DR                       NaN                    COTTON
# 2                    BLV                       NaN   INTERSTATE 8 EB ON RAMP
# 3                     ST                       NaN                       NaN
# 4                     ST                       NaN                 GREENWOOD
# ...                  ...                       ...                       ...
# 9995                 AVE                       NaN                         E
# 9996                 NaN                       NaN                       NaN
# 9997                  ST                       NaN                       NaN
# 9998                 AVE                       NaN                       NaN
# 9999                 BLV                       NaN                      40TH
#
#       ...  call_type disposition beat  priority  address_number_primary_str  \
# 0     ...        415         CAN  526         2                      1600.0
# 1     ...       1149           K  445         2                         NaN
# 2     ...        415           K  613         2                         NaN
# 3     ...       HZRD           K  441         2                       500.0
# 4     ...       1151           K  611         2                         NaN
# ...   ...        ...         ...  ...       ...                         ...
# 9995  ...        314         DUP  523         2                         NaN
# 9996  ...       1130           K  623         1                       800.0
# 9997  ...       1146           K  831         0                      4000.0
# 9998  ...       459A         CAN  627         3                      3700.0
# 9999  ...          T           K  832         2                         NaN
#
#                                            Address        lat         lng  \
# 0              1600 06TH AVE San Diego, California  32.722117 -117.159458
# 1                 HILLTOP DR San Diego, California  32.715075 -117.095691
# 2           SPORTS ARENA BLV San Diego, California  32.753394 -117.210509
# 3              500 S 38TH ST San Diego, California  32.701259 -117.112516
# 4                 HANCOCK ST San Diego, California  32.753068 -117.203168
# ...                                            ...        ...         ...
# 9995                04TH AVE San Diego, California  32.731232 -117.161241
# 9996  800 HOTEL CIRCLE SOUTH San Diego, California  32.759391 -117.177008
# 9997            4000 46TH ST San Diego, California  32.749581 -117.095525
# 9998           3700 05TH AVE San Diego, California  32.745135 -117.160394
# 9999            EL CAJON BLV San Diego, California  32.757308 -117.083611
#
#             zipcode Zipcodes
# 0             92101  92101.0
# 1     United States  92102.0
# 2     United States  92110.0
# 3              2854  92113.0
# 4     United States  92110.0
# ...             ...      ...
# 9995  United States  92101.0
# 9996          92108  92103.0
# 9997          92105  92105.0
# 9998           4224  92103.0
# 9999  United States  92115.0
#
# [10000 rows x 21 columns]

# %%
#Confirm Address Length
test['Address_length'] = test['Address'].str.len()
test = test.sort_values(by=['Address_length'])
test
# Out:
#       Unnamed: 0  incident_num            date_time  day_of_week  \
# 666        24062  E23010025807  2023-01-19 07:07:32            5
# 8799       32195  E23010034446  2023-01-25 06:37:14            4
# 9940       33336  E23010035694  2023-01-25 22:03:37            4
# 7029       30425  E23010032576  2023-01-24 00:02:41            3
# 7970       31366  E23010033556  2023-01-24 14:43:59            3
# ...          ...           ...                  ...          ...
# 7083       30479  E23010032632  2023-01-24 01:24:25            3
# 4706       28102  E23010030094  2023-01-22 05:14:24            1
# 723        24119  E23010025865  2023-01-19 07:50:29            5
# 7653       31049  E23010033223  2023-01-24 10:51:45            3
# 9005       32401  E23010034659  2023-01-25 08:56:40            4
#
#       address_number_primary address_dir_primary     address_road_primary  \
# 666                        0                 NaN                      I-8
# 8799                       0                 NaN                      I-5
# 9940                       0                 NaN                      I-5
# 7029                       0                 NaN                      LOG
# 7970                       0                 NaN                      I-5
# ...                      ...                 ...                      ...
# 7083                   13400                 NaN  PACIFIC HIGHLANDS RANCH
# 4706                   13400                 NaN  PACIFIC HIGHLANDS RANCH
# 723                    13600                 NaN  PACIFIC HIGHLANDS RANCH
# 7653                   13400                 NaN  PACIFIC HIGHLANDS RANCH
# 9005                   13500                 NaN  PACIFIC HIGHLANDS RANCH
#
#      address_sfx_primary  address_dir_intersecting address_road_intersecting  \
# 666                  NaN                       NaN                 FAIRMOUNT
# 8799                 NaN                       NaN                         J
# 9940                 NaN                       NaN                    GARNET
# 7029                 NaN                       NaN                       NaN
# 7970                 NaN                       NaN             CORONADO (SB)
# ...                  ...                       ...                       ...
# 7083                 PKY                       NaN                       NaN
# 4706                 PKY                       NaN                       NaN
# 723                  PKY                       NaN                       NaN
# 7653                 PKY                       NaN                       NaN
# 9005                 PKY                       NaN                       NaN
#
#       ...  disposition beat priority  address_number_primary_str  \
# 666   ...            W  321        1                         NaN
# 8799  ...            W  521        1                         NaN
# 9940  ...            K  122        2                         NaN
# 7029  ...            W   -1        2                         NaN
# 7970  ...          DUP  722        0                         NaN
# ...   ...          ...  ...      ...                         ...
# 7083  ...            K  934        3                     13400.0
# 4706  ...            K  934        2                     13400.0
# 723   ...            K  935        3                     13600.0
# 7653  ...            O  934        2                     13400.0
# 9005  ...            O  935        2                     13500.0
#
#                                                 Address        lat  \
# 666                           I-8 San Diego, California  32.779187
# 8799                          I-5 San Diego, California  32.804840
# 9940                          I-5 San Diego, California  32.804840
# 7029                          LOG San Diego, California  32.715738
# 7970                          I-5 San Diego, California  32.804840
# ...                                                 ...        ...
# 7083  13400 PACIFIC HIGHLANDS RANCH PKY San Diego, C...  32.962381
# 4706  13400 PACIFIC HIGHLANDS RANCH PKY San Diego, C...  32.962381
# 723   13600 PACIFIC HIGHLANDS RANCH PKY San Diego, C...  32.964125
# 7653  13400 PACIFIC HIGHLANDS RANCH PKY San Diego, C...  32.962381
# 9005  13500 PACIFIC HIGHLANDS RANCH PKY San Diego, C...  32.962984
#
#              lng        zipcode  Zipcodes Address_length
# 666  -117.071471  United States   92182.0             25
# 8799 -117.214120  United States   92140.0             25
# 9940 -117.214120  United States   92140.0             25
# 7029 -117.161084  United States   92101.0             25
# 7970 -117.214120  United States   92140.0             25
# ...          ...            ...       ...            ...
# 7083 -117.190208          92130   92130.0             55
# 4706 -117.190208          92130   92130.0             55
# 723  -117.191468          92130   92130.0             55
# 7653 -117.190208          92130   92130.0             55
# 9005 -117.190720          92130   92168.0             55
#
# [10000 rows x 22 columns]
