# %%
#Libraries
import mysql.connector
import pandas as pd
from datetime import datetime
from tqdm import tqdm
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

#from secrets import dbpassword

# %%
database = "SDPD"
user = 'Salvador'
password = 'renovatioA19!'
host = 'localhost'

# %%
#Initial Connection
cnx = mysql.connector.connect(user=user,
                              password=password,
                              host=host,
                              database=database
                              )
cursor = cnx.cursor()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 #Initial Connection
# ----> 2 cnx = mysql.connector.connect(user='root',
#       3                               password='xxxx',
#       4                               host='localhost',
#       5                               database="SDPD"
#       6                               )
#       7 cursor = cnx.cursor()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mysql/connector/pooling.py:294, in connect(*args, **kwargs)
#     292 if CMySQLConnection and not use_pure:
#     293     return CMySQLConnection(*args, **kwargs)
# --> 294 return MySQLConnection(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mysql/connector/connection.py:167, in MySQLConnection.__init__(self, **kwargs)
#     165 if kwargs:
#     166     try:
# --> 167         self.connect(**kwargs)
#     168     except Exception:
#     169         # Tidy-up underlying socket on failure
#     170         self.close()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mysql/connector/abstracts.py:1178, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1175     self.config(**kwargs)
#    1177 self.disconnect()
# -> 1178 self._open_connection()
#    1179 # Server does not allow to run any other statement different from ALTER
#    1180 # when user's password has been expired.
#    1181 if not self._client_flags & ClientFlag.CAN_HANDLE_EXPIRED_PASSWORDS:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mysql/connector/connection.py:573, in MySQLConnection._open_connection(self)
#     571 self._socket.open_connection()
#     572 self._do_handshake()
# --> 573 self._do_auth(
#     574     self._user,
#     575     self._password,
#     576     self._database,
#     577     self._client_flags,
#     578     self._charset_id,
#     579     self._ssl,
#     580     self._conn_attrs,
#     581 )
#     582 self.set_converter_class(self._converter_class)
#     583 if self._client_flags & ClientFlag.COMPRESS:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mysql/connector/connection.py:312, in MySQLConnection._do_auth(self, username, password, database, client_flags, charset, ssl_options, conn_attrs)
#     299 packet = self._protocol.make_auth(
#     300     handshake=self._handshake,
#     301     username=username,
#    (...)
#     309     auth_plugin_class=self._auth_plugin_class,
#     310 )
#     311 self._socket.send(packet)
# --> 312 self._auth_switch_request(username, password)
#     314 if not (client_flags & ClientFlag.CONNECT_WITH_DB) and database:
#     315     self.cmd_init_db(database)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mysql/connector/connection.py:369, in MySQLConnection._auth_switch_request(self, username, password)
#     367     return self._handle_mfa(packet)
#     368 if packet[4] == 255:
# --> 369     raise get_exception(packet)
#     370 return None
#
# ProgrammingError: 1045 (28000): Access denied for user 'root'@'localhost' (using password: YES)

# %% [markdown]
# # Load Call Variables

# %%
url = f"http://seshat.datasd.org/pd/pd_cfs_calltypes_datasd.csv"
call_type = pd.read_csv(url).dropna(axis=1)
# Out:
#     call_type                description
# 0        1016        PRISONER IN CUSTODY
# 1      1016PT   PTU (PRISONER TRANSPORT)
# 2      1016QC      SHOPLIFTER/QUICK CITE
# 3        1021         PHONE YOUR STATION
# 4       1021H            PHONE YOUR HOME
# ..        ...                        ...
# 284       TLO  TERRORISM LIAISON OFFICER
# 285        TP            TRAFFIC PURSUIT
# 286       TRO      TRO VIOLATION, REPORT
# 287     VARDA                VARDA ALARM
# 288   WARRANT                    WARRANT
#
# [289 rows x 2 columns]

# %%
url = f"http://seshat.datasd.org/pd/pd_dispo_codes_datasd.csv"
disposition = pd.read_csv(url).dropna(axis=1)
disposition.loc[len(disposition.index)] = ['DEF', 'DEF'] 
disposition.loc[len(disposition.index)] = ['SS-', 'SS-']
# Out:
#    dispo_code                                        description
# 0           X  DISPATCHED ALARM CALL CANCELLED BEFORE UNIT ON...
# 1           A                                        ARREST MADE
# 2          AB                      ARREST MADE, BOARD AND SECURE
# 3         AHR      ARREST MADE, HIGH RISK (CRISIS RESPONSE TEAM)
# 4           R                                             REPORT
# 5          RB                     REPORT TAKEN, BOARD AND SECURE
# 6         RHR           REPORT, HIGH RISK (CRISIS RESPONSE TEAM)
# 7           S                STOLEN VEHICLE OR RECOVERED VEHICLE
# 8           O                                              OTHER
# 9         OHR            OTHER, HIGH RISK (CRISIS RESPONSE TEAM)
# 10          K                                 NO REPORT REQUIRED
# 11         KB               NO REPORT REQUIRED, BOARD AND SECURE
# 12        KHR  NO FURTHER ACTION, HIGH RISK (CRISIS RESPONSE ...
# 13          U                                          UNFOUNDED
# 14          W  NO DISPATCH OR INCIDENT CANCLLED PRIOR TO DISP...
# 15        CAN                                             CANCEL
# 16        DUP                             DUPLICATE CALL, XREF'D
# 17          V                                     DUPLICATE CALL
# 18        DEF                                                DEF

# %%
beat = pd.read_csv('beat-neighborhood.csv').dropna(axis=1)
beat_split = beat['beat,neighborhood'].str.split(pat=",",
                                                 expand=True)
beat_split = beat_split.rename(columns={0: "beat",
                                        1: "neighborhood"})
beat_split.loc[len(beat_split.index)] = [-1, 'No Beat']
# Out:
#     beat          neighborhood
# 0    111  Clairemont Mesa East
# 1    112  Clairemont Mesa West
# 2    113                Bay Ho
# 3    114      North Clairemont
# 4    115       University City
# ..   ...                   ...
# 121  934         Carmel Valley
# 122  935            North City
# 123  936      Torrey Highlands
# 124  937  Black Mountain Ranch
# 125   -1               No Beat
#
# [126 rows x 2 columns]

# %%
# Create dataframe
days = pd.DataFrame({
    'day_of_week':list(range(1,8)),
    'day':['Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday'],
})
# Out:
#    day_of_week        day
# 0            1     Sunday
# 1            2     Monday
# 2            3    Tuesday
# 3            4  Wednesday
# 4            5   Thursday
# 5            6     Friday
# 6            7   Saturday

# %%
# df to dict
call_type_dict = call_type.to_dict('records')
disposition_dict = disposition.to_dict('records')
beat_dict = beat_split.to_dict('records')
days_dict = days.to_dict('records')
# Out:
# [{'beat': '111', 'neighborhood': 'Clairemont Mesa East'},
#  {'beat': '112', 'neighborhood': 'Clairemont Mesa West'},
#  {'beat': '113', 'neighborhood': 'Bay Ho'},
#  {'beat': '114', 'neighborhood': 'North Clairemont'},
#  {'beat': '115', 'neighborhood': 'University City'},
#  {'beat': '116', 'neighborhood': 'Bay Park'},
#  {'beat': '121', 'neighborhood': 'Mission Beach'},
#  {'beat': '122', 'neighborhood': 'Pacific Beach'},
#  {'beat': '123', 'neighborhood': 'Mission Bay Park'},
#  {'beat': '124', 'neighborhood': 'La Jolla'},
#  {'beat': '126', 'neighborhood': 'Torrey Pines'},
#  {'beat': '231', 'neighborhood': 'Sabre Springs'},
#  {'beat': '232', 'neighborhood': 'Carmel Mountain'},
#  {'beat': '233', 'neighborhood': 'Rancho Penasquitos'},
#  {'beat': '234', 'neighborhood': 'Rancho Bernardo'},
#  {'beat': '235', 'neighborhood': 'San Pasqual'},
#  {'beat': '241', 'neighborhood': 'Scripps Ranch'},
#  {'beat': '242', 'neighborhood': 'Mira Mesa'},
#  {'beat': '243', 'neighborhood': 'Miramar'},
#  {'beat': '245', 'neighborhood': 'Rancho Encantada'},
#  {'beat': '246', 'neighborhood': 'Miramar Ranch North'},
#  {'beat': '311', 'neighborhood': 'Serra Mesa'},
#  {'beat': '312', 'neighborhood': 'Tierrasanta'},
#  {'beat': '313', 'neighborhood': 'Kearny Mesa'},
#  {'beat': '314', 'neighborhood': 'Birdland'},
#  {'beat': '315', 'neighborhood': 'Mission Valley East'},
#  {'beat': '316', 'neighborhood': 'Qualcomm'},
#  {'beat': '321', 'neighborhood': 'Grantville'},
#  {'beat': '322', 'neighborhood': 'Allied Gardens'},
#  {'beat': '323', 'neighborhood': 'Del Cerro'},
#  {'beat': '324', 'neighborhood': 'Lake Murray'},
#  {'beat': '325', 'neighborhood': 'San Carlos'},
#  {'beat': '326', 'neighborhood': 'College West'},
#  {'beat': '327', 'neighborhood': 'College East'},
#  {'beat': '431', 'neighborhood': 'Emerald Hills'},
#  {'beat': '432', 'neighborhood': 'Valencia Park'},
#  {'beat': '433', 'neighborhood': 'Encanto'},
#  {'beat': '434', 'neighborhood': 'Jamacha/Lomita'},
#  {'beat': '435', 'neighborhood': 'Broadway Heights'},
#  {'beat': '436', 'neighborhood': 'Skyline'},
#  {'beat': '437', 'neighborhood': 'Bay Terraces'},
#  {'beat': '438', 'neighborhood': 'Paradise Hills'},
#  {'beat': '439', 'neighborhood': 'Alta Vista'},
#  {'beat': '441', 'neighborhood': 'Mountain View'},
#  {'beat': '442', 'neighborhood': 'Southcrest'},
#  {'beat': '443', 'neighborhood': 'Shelltown'},
#  {'beat': '444', 'neighborhood': 'Mt. Hope'},
#  {'beat': '445', 'neighborhood': 'Chollas View'},
#  {'beat': '446', 'neighborhood': 'Lincoln Park'},
#  {'beat': '447', 'neighborhood': 'Ridgeview/Webster'},
#  {'beat': '451', 'neighborhood': 'Oak Park'},
#  {'beat': '452', 'neighborhood': "O'Farrell"},
#  {'beat': '511', 'neighborhood': 'Barrio Logan'},
#  {'beat': '512', 'neighborhood': 'Logan Heights'},
#  {'beat': '514', 'neighborhood': 'Sherman Heights'},
#  {'beat': '515', 'neighborhood': 'Grant Hill'},
#  {'beat': '516', 'neighborhood': 'Stockton'},
#  {'beat': '517', 'neighborhood': 'Golden Hill'},
#  {'beat': '518', 'neighborhood': 'South Park'},
#  {'beat': '521', 'neighborhood': 'East Village'},
#  {'beat': '522', 'neighborhood': 'Marina'},
#  {'beat': '523', 'neighborhood': 'Gaslamp'},
#  {'beat': '524', 'neighborhood': 'Core-Columbia'},
#  {'beat': '525', 'neighborhood': 'Horton Plaza'},
#  {'beat': '526', 'neighborhood': 'Cortez'},
#  {'beat': '527', 'neighborhood': 'Harborview'},
#  {'beat': '528', 'neighborhood': 'Little Italy'},
#  {'beat': '529', 'neighborhood': 'Park West'},
#  {'beat': '531', 'neighborhood': 'Balboa Park'},
#  {'beat': '541', 'neighborhood': 'Petco Park'},
#  {'beat': '611', 'neighborhood': 'Midway District'},
#  {'beat': '612', 'neighborhood': 'Loma Portal'},
#  {'beat': '613', 'neighborhood': 'Point Loma Heights'},
#  {'beat': '614', 'neighborhood': 'Ocean Beach'},
#  {'beat': '615', 'neighborhood': 'Roseville/Fleet Ridge'},
#  {'beat': '616', 'neighborhood': 'La Playa'},
#  {'beat': '617', 'neighborhood': 'Wooded Area'},
#  {'beat': '618', 'neighborhood': 'Sunset Cliffs'},
#  {'beat': '621', 'neighborhood': 'Linda Vista'},
#  {'beat': '622', 'neighborhood': 'Morena'},
#  {'beat': '623', 'neighborhood': 'Mission Valley West'},
#  {'beat': '624', 'neighborhood': 'University Heights'},
#  {'beat': '625', 'neighborhood': 'Old Town'},
#  {'beat': '626', 'neighborhood': 'Mission Hills'},
#  {'beat': '627', 'neighborhood': 'Hillcrest'},
#  {'beat': '628', 'neighborhood': 'Midtown'},
#  {'beat': '711', 'neighborhood': 'Tijuana River Valley'},
#  {'beat': '712', 'neighborhood': 'San Ysidro'},
#  {'beat': '713', 'neighborhood': 'Otay Mesa'},
#  {'beat': '714', 'neighborhood': 'Border'},
#  {'beat': '721', 'neighborhood': 'Egger Highlands'},
#  {'beat': '722', 'neighborhood': 'Nestor'},
#  {'beat': '723', 'neighborhood': 'Otay Mesa West'},
#  {'beat': '724', 'neighborhood': 'Palm City'},
#  {'beat': '725', 'neighborhood': 'Ocean Crest'},
#  {'beat': '811', 'neighborhood': 'Normal Heights'},
#  {'beat': '812', 'neighborhood': 'Burlingame'},
#  {'beat': '813', 'neighborhood': 'North Park'},
#  {'beat': '814', 'neighborhood': 'Adams North'},
#  {'beat': '821', 'neighborhood': 'Rolando'},
#  {'beat': '822', 'neighborhood': 'El Cerrito'},
#  {'beat': '823', 'neighborhood': 'Redwood Village'},
#  {'beat': '824', 'neighborhood': 'Talmadge'},
#  {'beat': '825', 'neighborhood': 'Kensington'},
#  {'beat': '826', 'neighborhood': 'Colina del Sol'},
#  {'beat': '827', 'neighborhood': 'Chollas Creek'},
#  {'beat': '828', 'neighborhood': 'Fox Canyon'},
#  {'beat': '829', 'neighborhood': 'Islenair'},
#  {'beat': '831', 'neighborhood': 'Teralta East'},
#  {'beat': '832', 'neighborhood': 'Teralta West'},
#  {'beat': '833', 'neighborhood': 'Fairmount Village'},
#  {'beat': '834', 'neighborhood': 'Castle'},
#  {'beat': '835', 'neighborhood': 'Azalea/Hollywood Park'},
#  {'beat': '836', 'neighborhood': 'Swan Canyon'},
#  {'beat': '837', 'neighborhood': 'Fairmount Park'},
#  {'beat': '838', 'neighborhood': 'Corridor'},
#  {'beat': '839', 'neighborhood': 'Cherokee Point'},
#  {'beat': '841', 'neighborhood': 'Rolando Park'},
#  {'beat': '931', 'neighborhood': 'Sorrento Valley'},
#  {'beat': '932', 'neighborhood': 'Torrey Preserve'},
#  {'beat': '933', 'neighborhood': 'Del Mar Heights'},
#  {'beat': '934', 'neighborhood': 'Carmel Valley'},
#  {'beat': '935', 'neighborhood': 'North City'},
#  {'beat': '936', 'neighborhood': 'Torrey Highlands'},
#  {'beat': '937', 'neighborhood': 'Black Mountain Ranch'},
#  {'beat': -1, 'neighborhood': 'No Beat'}]

# %% [markdown]
# ***

# %%
def Find_Data(row,cursor,table, key):
    try:
        #print(f"SELECT * from {table} where {key} = '{row[key]}'")
        cursor.execute(f"SELECT * from {table} where {key} = '{row[key]}'")
        # Fetch a record
        result = cursor.fetchone()
    except:
        result = 0
    
    return result

# %%
#Call Type
def Load_Call_Type(row,cursor,table):
    # Create a new record
    sql = f"""INSERT INTO {table} (call_type,
                                    description
                                    ) VALUES (%s, %s)"""

    # Execute the query
    cursor.execute(sql, (row['call_type'],row['description']))
    cnx.commit()

# %%
#Disposition
def Load_Dispo(row,cursor,table):
    # Create a new record
    sql = f"""INSERT INTO {table} (dispo_code,
                                    description
                                    ) VALUES (%s, %s)"""

    # Execute the query
    cursor.execute(sql, (row['dispo_code'],row['description']))
    cnx.commit()

# %%
#beat
def Load_Beat(row,cursor,table):
    # Create a new record
    sql = f"""INSERT INTO {table} (beat,
                                    neighborhood
                                    ) VALUES (%s, %s)"""

    # Execute the query
    cursor.execute(sql, (row['beat'],row['neighborhood']))
    cnx.commit()

# %%
#Load Data
def Load_Data(row,cursor,table,Col1,Col2):
    # Create a new record
    sql = f"""INSERT INTO {table} ({Col1},
                                    {Col2}
                                    ) VALUES (%s, %s)"""

    # Execute the query
    cursor.execute(sql, (row[Col1],row[Col2]))
    cnx.commit()

# %%
for row in tqdm(call_type_dict):
    #Verify if Data is in table
    Data_Found = Find_Data(row,cursor,'Call_types','call_type')
    if Data_Found is None:
        #If no data found load 
        Load_Call_Type(row,cursor,'Call_types')
    else:
        pass
# Out:
# 100%|███████████████████████████████████████| 289/289 [00:00<00:00, 1682.08it/s]

# %%
for row in tqdm(disposition_dict):
    #Verify if Data is in table
    Data_Found = Find_Data(row,cursor,'Dispositions','dispo_code')
    if Data_Found is None:
        #If no data found load 
        Load_Dispo(row,cursor,'Dispositions')
    else:
        pass
# Out:
# 100%|██████████████████████████████████████████| 19/19 [00:00<00:00, 586.94it/s]

# %%
for row in tqdm(beat_dict):
    #Verify if Data is in table
    Data_Found = Find_Data(row,cursor,'Beats','beat')
    if Data_Found is None:
        #If no data found load 
        Load_Beat(row,cursor,'Beats')
    else:
        pass
# Out:
# 100%|███████████████████████████████████████| 126/126 [00:00<00:00, 1353.28it/s]

# %%
for row in tqdm(beat_dict):
    print(row)
# Out:
# 100%|██████████████████████████████████████| 126/126 [00:00<00:00, 17632.53it/s]
# {'beat': '111', 'neighborhood': 'Clairemont Mesa East'}
# {'beat': '112', 'neighborhood': 'Clairemont Mesa West'}
# {'beat': '113', 'neighborhood': 'Bay Ho'}
# {'beat': '114', 'neighborhood': 'North Clairemont'}
# {'beat': '115', 'neighborhood': 'University City'}
# {'beat': '116', 'neighborhood': 'Bay Park'}
# {'beat': '121', 'neighborhood': 'Mission Beach'}
# {'beat': '122', 'neighborhood': 'Pacific Beach'}
# {'beat': '123', 'neighborhood': 'Mission Bay Park'}
# {'beat': '124', 'neighborhood': 'La Jolla'}
# {'beat': '126', 'neighborhood': 'Torrey Pines'}
# {'beat': '231', 'neighborhood': 'Sabre Springs'}
# {'beat': '232', 'neighborhood': 'Carmel Mountain'}
# {'beat': '233', 'neighborhood': 'Rancho Penasquitos'}
# {'beat': '234', 'neighborhood': 'Rancho Bernardo'}
# {'beat': '235', 'neighborhood': 'San Pasqual'}
# {'beat': '241', 'neighborhood': 'Scripps Ranch'}
# {'beat': '242', 'neighborhood': 'Mira Mesa'}
# {'beat': '243', 'neighborhood': 'Miramar'}
# {'beat': '245', 'neighborhood': 'Rancho Encantada'}
# {'beat': '246', 'neighborhood': 'Miramar Ranch North'}
# {'beat': '311', 'neighborhood': 'Serra Mesa'}
# {'beat': '312', 'neighborhood': 'Tierrasanta'}
# {'beat': '313', 'neighborhood': 'Kearny Mesa'}
# {'beat': '314', 'neighborhood': 'Birdland'}
# {'beat': '315', 'neighborhood': 'Mission Valley East'}
# {'beat': '316', 'neighborhood': 'Qualcomm'}
# {'beat': '321', 'neighborhood': 'Grantville'}
# {'beat': '322', 'neighborhood': 'Allied Gardens'}
# {'beat': '323', 'neighborhood': 'Del Cerro'}
# {'beat': '324', 'neighborhood': 'Lake Murray'}
# {'beat': '325', 'neighborhood': 'San Carlos'}
# {'beat': '326', 'neighborhood': 'College West'}
# {'beat': '327', 'neighborhood': 'College East'}
# {'beat': '431', 'neighborhood': 'Emerald Hills'}
# {'beat': '432', 'neighborhood': 'Valencia Park'}
# {'beat': '433', 'neighborhood': 'Encanto'}
# {'beat': '434', 'neighborhood': 'Jamacha/Lomita'}
# {'beat': '435', 'neighborhood': 'Broadway Heights'}
# {'beat': '436', 'neighborhood': 'Skyline'}
# {'beat': '437', 'neighborhood': 'Bay Terraces'}
# {'beat': '438', 'neighborhood': 'Paradise Hills'}
# {'beat': '439', 'neighborhood': 'Alta Vista'}
# {'beat': '441', 'neighborhood': 'Mountain View'}
# {'beat': '442', 'neighborhood': 'Southcrest'}
# {'beat': '443', 'neighborhood': 'Shelltown'}
# {'beat': '444', 'neighborhood': 'Mt. Hope'}
# {'beat': '445', 'neighborhood': 'Chollas View'}
# {'beat': '446', 'neighborhood': 'Lincoln Park'}
# {'beat': '447', 'neighborhood': 'Ridgeview/Webster'}
# {'beat': '451', 'neighborhood': 'Oak Park'}
# {'beat': '452', 'neighborhood': "O'Farrell"}
# {'beat': '511', 'neighborhood': 'Barrio Logan'}
# {'beat': '512', 'neighborhood': 'Logan Heights'}
# {'beat': '514', 'neighborhood': 'Sherman Heights'}
# {'beat': '515', 'neighborhood': 'Grant Hill'}
# {'beat': '516', 'neighborhood': 'Stockton'}
# {'beat': '517', 'neighborhood': 'Golden Hill'}
# {'beat': '518', 'neighborhood': 'South Park'}
# {'beat': '521', 'neighborhood': 'East Village'}
# {'beat': '522', 'neighborhood': 'Marina'}
# {'beat': '523', 'neighborhood': 'Gaslamp'}
# {'beat': '524', 'neighborhood': 'Core-Columbia'}
# {'beat': '525', 'neighborhood': 'Horton Plaza'}
# {'beat': '526', 'neighborhood': 'Cortez'}
# {'beat': '527', 'neighborhood': 'Harborview'}
# {'beat': '528', 'neighborhood': 'Little Italy'}
# {'beat': '529', 'neighborhood': 'Park West'}
# {'beat': '531', 'neighborhood': 'Balboa Park'}
# {'beat': '541', 'neighborhood': 'Petco Park'}
# {'beat': '611', 'neighborhood': 'Midway District'}
# {'beat': '612', 'neighborhood': 'Loma Portal'}
# {'beat': '613', 'neighborhood': 'Point Loma Heights'}
# {'beat': '614', 'neighborhood': 'Ocean Beach'}
# {'beat': '615', 'neighborhood': 'Roseville/Fleet Ridge'}
# {'beat': '616', 'neighborhood': 'La Playa'}
# {'beat': '617', 'neighborhood': 'Wooded Area'}
# {'beat': '618', 'neighborhood': 'Sunset Cliffs'}
# {'beat': '621', 'neighborhood': 'Linda Vista'}
# {'beat': '622', 'neighborhood': 'Morena'}
# {'beat': '623', 'neighborhood': 'Mission Valley West'}
# {'beat': '624', 'neighborhood': 'University Heights'}
# {'beat': '625', 'neighborhood': 'Old Town'}
# {'beat': '626', 'neighborhood': 'Mission Hills'}
# {'beat': '627', 'neighborhood': 'Hillcrest'}
# {'beat': '628', 'neighborhood': 'Midtown'}
# {'beat': '711', 'neighborhood': 'Tijuana River Valley'}
# {'beat': '712', 'neighborhood': 'San Ysidro'}
# {'beat': '713', 'neighborhood': 'Otay Mesa'}
# {'beat': '714', 'neighborhood': 'Border'}
# {'beat': '721', 'neighborhood': 'Egger Highlands'}
# {'beat': '722', 'neighborhood': 'Nestor'}
# {'beat': '723', 'neighborhood': 'Otay Mesa West'}
# {'beat': '724', 'neighborhood': 'Palm City'}
# {'beat': '725', 'neighborhood': 'Ocean Crest'}
# {'beat': '811', 'neighborhood': 'Normal Heights'}
# {'beat': '812', 'neighborhood': 'Burlingame'}
# {'beat': '813', 'neighborhood': 'North Park'}
# {'beat': '814', 'neighborhood': 'Adams North'}
# {'beat': '821', 'neighborhood': 'Rolando'}
# {'beat': '822', 'neighborhood': 'El Cerrito'}
# {'beat': '823', 'neighborhood': 'Redwood Village'}
# {'beat': '824', 'neighborhood': 'Talmadge'}
# {'beat': '825', 'neighborhood': 'Kensington'}
# {'beat': '826', 'neighborhood': 'Colina del Sol'}
# {'beat': '827', 'neighborhood': 'Chollas Creek'}
# {'beat': '828', 'neighborhood': 'Fox Canyon'}
# {'beat': '829', 'neighborhood': 'Islenair'}
# {'beat': '831', 'neighborhood': 'Teralta East'}
# {'beat': '832', 'neighborhood': 'Teralta West'}
# {'beat': '833', 'neighborhood': 'Fairmount Village'}
# {'beat': '834', 'neighborhood': 'Castle'}
# {'beat': '835', 'neighborhood': 'Azalea/Hollywood Park'}
# {'beat': '836', 'neighborhood': 'Swan Canyon'}
# {'beat': '837', 'neighborhood': 'Fairmount Park'}
# {'beat': '838', 'neighborhood': 'Corridor'}
# {'beat': '839', 'neighborhood': 'Cherokee Point'}
# {'beat': '841', 'neighborhood': 'Rolando Park'}
# {'beat': '931', 'neighborhood': 'Sorrento Valley'}
# {'beat': '932', 'neighborhood': 'Torrey Preserve'}
# {'beat': '933', 'neighborhood': 'Del Mar Heights'}
# {'beat': '934', 'neighborhood': 'Carmel Valley'}
# {'beat': '935', 'neighborhood': 'North City'}
# {'beat': '936', 'neighborhood': 'Torrey Highlands'}
# {'beat': '937', 'neighborhood': 'Black Mountain Ranch'}
# {'beat': -1, 'neighborhood': 'No Beat'}

# %%
# SQL Variable Tables
SQL_Tables = pd.DataFrame({
    'Table':['Call_types','Dispositions','Beats'],
    'Key':['call_type','dispo_code','beat'],
    'Col2':['description','description','neighborhood'],
    'dict':[call_type_dict,disposition_dict,beat_dict]
})
SQL_Tables_dict = SQL_Tables.to_dict('records')
SQL_Tables_dict
# Out:
# [{'Table': 'Call_types',
#   'Key': 'call_type',
#   'Col2': 'description',
#   'dict': [{'call_type': '1016', 'description': 'PRISONER IN CUSTODY'},
#    {'call_type': '1016PT', 'description': 'PTU (PRISONER TRANSPORT)'},
#    {'call_type': '1016QC', 'description': 'SHOPLIFTER/QUICK CITE'},
#    {'call_type': '1021', 'description': 'PHONE YOUR STATION'},
#    {'call_type': '1021H', 'description': 'PHONE YOUR HOME'},
#    {'call_type': '10851', 'description': 'AUTO THEFT'},
#    {'call_type': '10851E', 'description': 'EVAL-POSS UNREPORTED CAR THEFT'},
#    {'call_type': '10851R', 'description': 'CAR THEFT REPORT'},
#    {'call_type': '10851RR', 'description': 'CAR THEFT RECOVERY REPORT'},
#    {'call_type': '10852', 'description': 'TAMPERING W/VEH IN PROGRESS'},
#    {'call_type': '10852A', 'description': 'VEHICLE ALARM/AUDIBLE'},
#    {'call_type': '10852C', 'description': 'VEHICLE CASER'},
#    {'call_type': '10852R', 'description': 'TAMPERING W/VEH REPORT'},
#    {'call_type': '1087', 'description': 'MEET OFFICER NON URGENT'},
#    {'call_type': '11-6', 'description': 'DISCHARGING FIREARMS'},
#    {'call_type': '11-6SPT',
#     'description': 'DISCHARGING FIREARM SHOT SPOTTER ACTIVATION'},
#    {'call_type': '11-7', 'description': 'PROWLER'},
#    {'call_type': '11-8', 'description': 'PERSON DOWN'},
#    {'call_type': '1110M', 'description': 'REPORT OF CRIME OCCD MEXICO'},
#    {'call_type': '1111', 'description': 'CHECK THE AREA'},
#    {'call_type': '1111', 'description': 'CHECK THE AREA'},
#    {'call_type': '1115', 'description': 'BALL GAME IN STREET(83 03MC)'},
#    {'call_type': '1115', 'description': 'BALL GAME IN STREET(83 03MC)'},
#    {'call_type': '1130', 'description': 'INCOMPLETE PHONE CALL'},
#    {'call_type': '1130', 'description': 'INCOMPLETE PHONE CALL'},
#    {'call_type': '1131', 'description': 'CALLING FOR HELP'},
#    {'call_type': '1131', 'description': 'CALLING FOR HELP'},
#    {'call_type': '1131A', 'description': 'CALLING FOR HELP-PANIC ALARM'},
#    {'call_type': '1140OD', 'description': 'AMBULANCE CALL, OVERDOSE'},
#    {'call_type': '1141', 'description': 'AMBULANCE NEEDED'},
#    {'call_type': '1144', 'description': "CORONER'S CASE"},
#    {'call_type': '1146', 'description': 'REPORT OF DEATH'},
#    {'call_type': '1147', 'description': 'INJURED PERSON'},
#    {'call_type': '1148', 'description': 'FURNISH TRANSPORTATION'},
#    {'call_type': '1149', 'description': 'TRAFFIC STOP/NO LICENSE'},
#    {'call_type': '1150', 'description': 'TRAFFIC STOP/WITH LICENSE'},
#    {'call_type': '1151', 'description': 'PED STOP/FIELD INTERVIEW'},
#    {'call_type': '1153', 'description': 'SECURITY CHECK'},
#    {'call_type': '1155', 'description': 'HAZARDOUS/CHEMICAL SPILL'},
#    {'call_type': '1160', 'description': 'INVESTIGATE WATER LEAK'},
#    {'call_type': '1166', 'description': 'SIGNALS OUT OF ORDER'},
#    {'call_type': '1171', 'description': 'FIRE'},
#    {'call_type': '1180', 'description': 'SERIOUS INJURY ACCIDENT'},
#    {'call_type': '1180-CR',
#     'description': 'SERIOUS INJ ACCIDENT-COST RECOVERY'},
#    {'call_type': '1181', 'description': 'MINOR INJURY ACCIDENT'},
#    {'call_type': '1181-CR',
#     'description': 'MINOR INJURY ACCIDENT-COST RECOVERY'},
#    {'call_type': '1181R', 'description': 'MINOR TRAFFIC INJURY, REPORT'},
#    {'call_type': '1182', 'description': 'NON-INJURY ACCIDENT'},
#    {'call_type': '1182-CR',
#     'description': 'NON-INJURY ACCIDENT-COST RECOVERY'},
#    {'call_type': '1183', 'description': 'NO DETAIL ACCIDENT'},
#    {'call_type': '1184', 'description': 'TRAFFIC CONTROL'},
#    {'call_type': '1184-CR', 'description': 'TRAFFIC CONTROL-COST RECOVERY'},
#    {'call_type': '1185', 'description': 'REQUEST FOR TOW TRUCK'},
#    {'call_type': '1186', 'description': 'SPECIAL DETAIL'},
#    {'call_type': '1188', 'description': 'ASSIST DISABLED MOTORIST'},
#    {'call_type': '1199', 'description': 'OFFICER NEEDS HELP'},
#    {'call_type': '136', 'description': 'INTIMIDATION OF WITNESS'},
#    {'call_type': '146', 'description': 'IMPERSONATING AN OFFICER'},
#    {'call_type': '146R', 'description': 'IMPERSONATING AN OFFICER,RPT'},
#    {'call_type': '187', 'description': 'MURDER'},
#    {'call_type': '187-SUSP', 'description': '187 SUSPECT THERE NOW'},
#    {'call_type': '20001', 'description': 'FELONY HIT&RUN'},
#    {'call_type': '20001-CR', 'description': 'FELONY HIT/RUN-COST RECOVERY'},
#    {'call_type': '20002', 'description': 'MISD HIT/RUN'},
#    {'call_type': '20002-CR', 'description': 'MISD HIT/RUN-COST RECOVERY'},
#    {'call_type': '20002R', 'description': 'HIT AND RUN REPORT'},
#    {'call_type': '207', 'description': 'KIDNAPPING IN PROGRESS'},
#    {'call_type': '207R', 'description': 'KIDNAPPING REPORT'},
#    {'call_type': '211', 'description': 'ROBBERY'},
#    {'call_type': '211-SUSP', 'description': '211 SUSPECT THERE NOW'},
#    {'call_type': '211A', 'description': 'ROBBERY ALARM'},
#    {'call_type': '211C', 'description': 'ROBBERY CASER'},
#    {'call_type': '211R', 'description': 'ROBBERY REPORT'},
#    {'call_type': '211SPEC', 'description': 'ROBBERY-GPS DEVICE'},
#    {'call_type': '215', 'description': 'CAR JACKING'},
#    {'call_type': '215R', 'description': 'CARJACKING REPORT'},
#    {'call_type': '23103', 'description': 'RECKLESS DRIVING'},
#    {'call_type': '23110', 'description': 'THROWING OBJECTS AT AN OCC VEH'},
#    {'call_type': '23110R',
#     'description': 'THROWING OBJECTS AT AN OCC VEH REPORT'},
#    {'call_type': '23152', 'description': 'DUI'},
#    {'call_type': '23152-CR', 'description': 'DUI-COST RECOVERY'},
#    {'call_type': '242', 'description': 'BATTERY'},
#    {'call_type': '242R', 'description': 'BATTERY REPORT'},
#    {'call_type': '245', 'description': 'ADW'},
#    {'call_type': '245-CR', 'description': 'ADW-COST RECOVERY'},
#    {'call_type': '245-SUSP', 'description': '245 SUSPECT THERE NOW'},
#    {'call_type': '245DV', 'description': 'ADW DOMESTIC VIOLENCE RELATED'},
#    {'call_type': '245R', 'description': 'ADW REPORT'},
#    {'call_type': '246', 'description': "FIRING AT OCCP'D HSE/VEH"},
#    {'call_type': '246R', 'description': "FIRING AT OCCP'D HSE/VEH 1110"},
#    {'call_type': '247', 'description': 'FIRING AT UNOCCUPIED VEH'},
#    {'call_type': '247R', 'description': 'FIRING AT UNOCCPD VEH/HSE 1110'},
#    {'call_type': '271', 'description': 'CHILD DESERTION'},
#    {'call_type': '272', 'description': 'CONTRIBUTING DELINQ MINOR'},
#    {'call_type': '278', 'description': 'CHILD STEALING'},
#    {'call_type': '278', 'description': 'CHILD STEALING'},
#    {'call_type': '278R', 'description': 'CHILD STEALING REPORT'},
#    {'call_type': '314', 'description': 'INDECENT EXPOSURE'},
#    {'call_type': '314R', 'description': 'INDECENT EXPOSURE REPORT'},
#    {'call_type': '330', 'description': 'GAMBLING'},
#    {'call_type': '368', 'description': 'ABUSE OF ELDER ADULT'},
#    {'call_type': '374', 'description': 'LITTERING'},
#    {'call_type': '402B', 'description': 'ABANDONED REFRIGERATOR'},
#    {'call_type': '415', 'description': 'DISTURBING PEACE'},
#    {'call_type': '415', 'description': 'DISTURBING PEACE'},
#    {'call_type': '415CAPP', 'description': 'DIST PEACE-CAPP HOUSE'},
#    {'call_type': '415CN', 'description': 'CONSTRUCTION NOISE COMPLAINT'},
#    {'call_type': '415DV', 'description': 'DOMESTIC VIOL/OCCURRING NOW'},
#    {'call_type': '415N', 'description': 'DISTURBING PEACE NOISE ONLY'},
#    {'call_type': '415N-CR',
#     'description': 'DISTURB PEACE/NOISE-COST RECOVERY'},
#    {'call_type': '415PP', 'description': 'PRESERVE THE PEACE'},
#    {'call_type': '415SH-CR', 'description': 'SOCIAL HOST-COST RECOVERY'},
#    {'call_type': '415TOW', 'description': 'DISTURBING PEACE RE: TOWING'},
#    {'call_type': '415V', 'description': 'DISTURBING PEACE W/VIOLENCE'},
#    {'call_type': '415W', 'description': 'DISTURBING PEACE UNCONC WEAPON'},
#    {'call_type': '417', 'description': 'THREATENING W/WEAPON'},
#    {'call_type': '417R', 'description': 'THREATENING W/WEAPON REPORT'},
#    {'call_type': '422', 'description': 'CRIMINAL THREATS'},
#    {'call_type': '422R', 'description': 'CRIMINAL THREATS REPORT'},
#    {'call_type': '451', 'description': 'ARSON IN PROGRESS'},
#    {'call_type': '451R', 'description': 'ARSON REPORT'},
#    {'call_type': '459', 'description': 'BURGLARY IN PROGRESS'},
#    {'call_type': '459-SUSP', 'description': '459 SUSPECT THERE NOW'},
#    {'call_type': '459A', 'description': 'BURGLARY ALARM'},
#    {'call_type': '459C', 'description': 'BURGLARY CASER'},
#    {'call_type': '459HP', 'description': 'BURGLARY HOT PROWL'},
#    {'call_type': '459R', 'description': 'BURGLARY REPORT'},
#    {'call_type': '459SPEC', 'description': 'BURGLARY-GPS DEVICE'},
#    {'call_type': '470', 'description': 'FORGERY IN PROGRESS'},
#    {'call_type': '470R', 'description': 'FORGERY REPORT'},
#    {'call_type': '470RX', 'description': 'FORGERY OF RX-SUSP THERE NOW'},
#    {'call_type': '487', 'description': 'GRAND THEFT $950+'},
#    {'call_type': '487R', 'description': 'GRAND THEFT/REPORT $950+'},
#    {'call_type': '488', 'description': 'PETTY THEFT/UNDER $950'},
#    {'call_type': '488R', 'description': 'PETTY THEFT REPORT/UNDER $950'},
#    {'call_type': '496', 'description': 'RECEIVE/SELL STOLEN PROP'},
#    {'call_type': '498', 'description': 'THEFT OF UTILITIES IN PROGRESS'},
#    {'call_type': '498R', 'description': 'THEFT OF UTILITIES REPORT'},
#    {'call_type': '502', 'description': 'COMPUTER CRIMES - TRU USE ONLY'},
#    {'call_type': '503CAR', 'description': 'STOLEN VEHICLE LOG'},
#    {'call_type': '508R', 'description': 'EMBEZZLEMENT, REPORT'},
#    {'call_type': '5150', 'description': 'MENTAL CASE'},
#    {'call_type': '5150V', 'description': 'MENTAL CASE-VIOLENT OR URGENT'},
#    {'call_type': '518R', 'description': 'EXTORTION, REPORT'},
#    {'call_type': '530', 'description': 'FALSE USE OF ANOTHERS IDENTITY'},
#    {'call_type': '532', 'description': 'FRAUD SOLICITATION/CHARITIES'},
#    {'call_type': '532', 'description': 'FRAUD SOLICITATION/CHARITIES'},
#    {'call_type': '537', 'description': 'DEFRAUDING INNKEEPER, IN PROGR'},
#    {'call_type': '537R', 'description': 'DEFRAUDING INNKEEPER REPORT'},
#    {'call_type': '586', 'description': 'ILLEGAL PARKING'},
#    {'call_type': '586H', 'description': 'ILLEGAL PARKING-HANDICAPPED'},
#    {'call_type': '586O', 'description': 'ILLEGAL OVO PARKING'},
#    {'call_type': '594', 'description': 'VANDALISM, IN PROGRESS'},
#    {'call_type': '594GR', 'description': 'GRAFFITI VANDALISM REPORT'},
#    {'call_type': '594R', 'description': 'VANDALISM, REPORT'},
#    {'call_type': '594VARDA', 'description': 'VANDALISM,ALARM'},
#    {'call_type': '595', 'description': 'RUNAWAY VEHICLE'},
#    {'call_type': '597', 'description': 'CRUELTY TO ANIMALS, IN PROGRES'},
#    {'call_type': '597R', 'description': 'CRUELTY TO ANIMALS, REPORT'},
#    {'call_type': '602', 'description': 'TRESPASSING'},
#    {'call_type': '646', 'description': 'STALKING'},
#    {'call_type': '646R', 'description': 'STALKING REPORT'},
#    {'call_type': '647B', 'description': 'PROSTITUTION'},
#    {'call_type': '647F', 'description': 'DRUNK - DRUGS/ALCOHOL'},
#    {'call_type': '653M', 'description': 'THREATENING PHONE CALL, REPORT'},
#    {'call_type': '72HR', 'description': 'VEH VIOLATING 72HR PARKING RES'},
#    {'call_type': '911', 'description': 'UNK EMERG, HANG UP/OPEN LINE'},
#    {'call_type': '911P', 'description': 'UNK EMER,HANGUP/OPEN,PAYFONE'},
#    {'call_type': 'ALERT2', 'description': 'AIRPLANE PROBLEM'},
#    {'call_type': 'ALERT3', 'description': 'AIRPLANE CRASH'},
#    {'call_type': 'ALERT4', 'description': 'BOMB/HIJACK THREAT'},
#    {'call_type': 'AMBER', 'description': 'AMBER ALERT INFO'},
#    {'call_type': 'ANIMAL', 'description': 'VICIOUS ANIMAL'},
#    {'call_type': 'APPT', 'description': 'APPOINTMENT'},
#    {'call_type': 'ASST', 'description': 'ASSIST THE INVALID'},
#    {'call_type': 'AU-MP', 'description': 'MISSING PERSON ALL UNITS INFO'},
#    {'call_type': 'AU1', 'description': 'ALL UNITS INFORMATION-PRI 1'},
#    {'call_type': 'AU10851', 'description': 'AUTO THEFT ALL UNITS INFO'},
#    {'call_type': 'AU1171', 'description': 'ALL UNITS FIRE INFO-PRI 1'},
#    {'call_type': 'AU187', 'description': 'MURDER-ALL UNITS INFORMATION'},
#    {'call_type': 'AU2', 'description': 'ALL UNITS INFORMATION-PRI 2'},
#    {'call_type': 'AU211', 'description': 'ROBBERY-ALL UNITS INFORMATION'},
#    {'call_type': 'AU215', 'description': 'CAR JACK-ALL UNITS INFORMATION'},
#    {'call_type': 'AU23103', 'description': 'RECKLESS DRIVING-ALL UNITS'},
#    {'call_type': 'AU23152', 'description': 'DUI-ALL UNITS INFORMATION'},
#    {'call_type': 'AU245', 'description': 'ADW-ALL UNITS INFORMATION'},
#    {'call_type': 'AUHATE', 'description': 'HATE INCIDENT ALL UNITS INF'},
#    {'call_type': 'BIKE', 'description': 'DOCKLESS BIKE COMPLAINT'},
#    {'call_type': 'BIO', 'description': 'BIOHAZARD-DESK CALL'},
#    {'call_type': 'BIOALARM', 'description': '((ANTHRAX ALARM)))'},
#    {'call_type': 'BLOOD', 'description': 'BLOOD RUN'},
#    {'call_type': 'BLUE', 'description': 'TAXI OR BUS NEEDS HELP'},
#    {'call_type': 'BOL', 'description': 'AU INFO/USED BY DESK OR RADIO'},
#    {'call_type': 'BOMB', 'description': 'BOMB THREAT, DESK CALL'},
#    {'call_type': 'BOMB-S', 'description': 'BOMB THREAT, DESK CALL (SCHOOL)'},
#    {'call_type': 'C10', 'description': 'SWAT STAGING'},
#    {'call_type': 'C100', 'description': 'ATTACK ON PD FACILITY'},
#    {'call_type': 'C11', 'description': 'SWAT STAGING'},
#    {'call_type': 'C11-CR', 'description': 'SWAT STAGING-COST RECOVERY'},
#    {'call_type': 'C12', 'description': 'SWAT EMERGENCY RESPONSE'},
#    {'call_type': 'C5', 'description': 'STAKEOUT'},
#    {'call_type': 'C6', 'description': 'STAYOUT OF AREA/NO RADIO TRANS'},
#    {'call_type': 'CC', 'description': 'CITIZEN CONTACT'},
#    {'call_type': 'CCCC', 'description': 'CHRONIC COMM CALLER CONTROL'},
#    {'call_type': 'CCF', 'description': "CITIZEN'S COMPLAINT INVESTIGAT"},
#    {'call_type': 'CCF-EVNT', 'description': "CITIZEN'S COMPLAINT SPEC EVENT"},
#    {'call_type': 'CCF-PBBP', 'description': 'CCF-PB BLOCK PARTY'},
#    {'call_type': 'CCF-RRM', 'description': 'CCF-ROCK N ROLL MARATHON'},
#    {'call_type': 'CCW', 'description': 'CARRYING CONCEALED WEAPON'},
#    {'call_type': 'CITE', 'description': 'ISSUE CITATION'},
#    {'call_type': 'COURT', 'description': 'COURT'},
#    {'call_type': 'COVER', 'description': 'COVER NOW'},
#    {'call_type': 'COVER-CR', 'description': 'COVER NOW-COST RECOVERY'},
#    {'call_type': 'CW', 'description': 'CHECK THE WELFARE'},
#    {'call_type': 'DC', 'description': 'DESK CALL'},
#    {'call_type': 'DC-S', 'description': 'DESK CALL (SCHOOL)'},
#    {'call_type': 'DEMO', 'description': 'DEMONSTRATION CALLS'},
#    {'call_type': 'DRAGNET', 'description': 'ILLEGAL STREET RACING'},
#    {'call_type': 'DRUN', 'description': 'HOMELAND SECURITY CHECKS'},
#    {'call_type': 'EJECT', 'description': 'EJECTED FROM AN EVENT'},
#    {'call_type': 'ESCAPE', 'description': 'ESCAPE/ESCAPEE'},
#    {'call_type': 'EVAC', 'description': 'EVACUATE CITIZENS'},
#    {'call_type': 'EVID', 'description': 'PICK UP EVIDENCE'},
#    {'call_type': 'EXPLO', 'description': 'EXPLOSION'},
#    {'call_type': 'FC', 'description': 'FRONT COUNTER CLOSURES'},
#    {'call_type': 'FD', 'description': 'FLAG DOWN/FIELD INITIATED'},
#    {'call_type': 'FIREHZRD', 'description': 'FIREWORK HAZARD'},
#    {'call_type': 'FIREWORK', 'description': 'ALL UNITS INFORMATION'},
#    {'call_type': 'FJ', 'description': 'FOUND JUVENILE'},
#    {'call_type': 'FOOT', 'description': 'FOOT PATROL/FIELD INITIATED'},
#    {'call_type': 'FOUND', 'description': 'FOUND PROPERTY'},
#    {'call_type': 'FP', 'description': 'FOOT PURSUIT'},
#    {'call_type': 'FP', 'description': 'WARRANT'},
#    {'call_type': 'FS', 'description': 'FOUND SENILE'},
#    {'call_type': 'FU', 'description': 'FOLLOW-UP BY FIELD UNIT'},
#    {'call_type': 'GPSPAL', 'description': 'GPS PAROLE VIOLATION'},
#    {'call_type': 'HATEINV', 'description': 'HATE CRIME INVESTIGATION'},
#    {'call_type': 'HZRD', 'description': 'HAZARDOUS CONDITION'},
#    {'call_type': 'INFO', 'description': 'INFORMATION FOR DISPATCHERS'},
#    {'call_type': 'INFOCHP', 'description': 'INFORMATION FOR CHP'},
#    {'call_type': 'INFOT',
#     'description': 'INFO ON TRAFFIC,HIT & RUN-ADVISED EVENT'},
#    {'call_type': 'INFOX',
#     'description': 'EXTRA PATROL INFO FOR FIELD SGT-ADVISED EVENT'},
#    {'call_type': 'JST', 'description': 'JUVENILE SERVICE TEAM HOTLINE'},
#    {'call_type': 'LASER', 'description': 'ILLEGAL USE OF LASER '},
#    {'call_type': 'LOJACK', 'description': 'STOLEN VEH-LOJACK'},
#    {'call_type': 'LOST', 'description': 'REPORT OF LOST PROPERTY/PLATE'},
#    {'call_type': 'MEXICO', 'description': 'LIAISON UNITS VISITING MEXICO'},
#    {'call_type': 'MFF', 'description': 'MOBILE FIELD FORCE ACTIVATION'},
#    {'call_type': 'MJ', 'description': 'MISSING JUV OF TENDER YEARS'},
#    {'call_type': 'MP', 'description': 'MISSING PERSON, REPORT EVAL'},
#    {'call_type': 'MPSSTP',
#     'description': 'TRAFFIC STOP FROM THE MOBILE COMPUTER'},
#    {'call_type': 'MS', 'description': 'MISSING SENILE'},
#    {'call_type': 'MTG', 'description': 'IN A MEETING/OUT OF SERVICE'},
#    {'call_type': 'MUTAID', 'description': 'INTERAGAENCY MUTUAL AID'},
#    {'call_type': 'NARC', 'description': 'NARCOTICS ACTIVITY'},
#    {'call_type': 'NONU', 'description': 'REQUEST FOR NON URGENT COVER'},
#    {'call_type': 'NONU-CR', 'description': 'NON URGENT COVER-COST RECOVERY'},
#    {'call_type': 'OVO', 'description': 'OVERSIZED VEHICLE ORDINANCE'},
#    {'call_type': 'PAPER', 'description': 'FINISH 1110/FIELD INITIATED'},
#    {'call_type': 'PARTY', 'description': 'LOUD PARTY'},
#    {'call_type': 'PARTY-CR', 'description': 'LOUD PARTY-COST RECOVERY'},
#    {'call_type': 'PLATE', 'description': 'LOST/STOLEN PLATE '},
#    {'call_type': 'POP', 'description': 'PROBLEM ORIENTED POLICING'},
#    {'call_type': 'PORT', 'description': 'BORDER/PORT RUNNER A/U'},
#    {'call_type': 'PRT', 'description': 'PRT ASSIST'},
#    {'call_type': 'REPORT', 'description': 'CRIME CASE NUMBER REQUEST'},
#    {'call_type': 'RESCUE', 'description': 'RESCUE CITIZENS'},
#    {'call_type': 'RJ', 'description': 'RUNAWAY JUVENILE, REPORT'},
#    {'call_type': 'ROUTE', 'description': 'ROUTE SLIP (FLD INVESTIGATION)'},
#    {'call_type': 'RRM', 'description': 'ROCK N ROLL MARATHON'},
#    {'call_type': 'RRM-1185', 'description': 'ROCK N ROLL 1185'},
#    {'call_type': 'RRM-CCF', 'description': 'ROCK N ROLL CCF'},
#    {'call_type': 'RRM-TOWS', 'description': 'VEHICLES TOWED DUE TO RRM'},
#    {'call_type': 'SCALP', 'description': 'TICKET SCALPER'},
#    {'call_type': 'SCHOOL', 'description': 'SCHOOL DETAIL'},
#    {'call_type': 'SELENF', 'description': 'SELECTIVE ENFORCEMENT'},
#    {'call_type': 'SHOPS', 'description': 'INFORMATION FOR SHOPS'},
#    {'call_type': 'SIG', 'description': 'SIGALERT'},
#    {'call_type': 'SKATE', 'description': 'SKATEBOARDERS'},
#    {'call_type': 'SLEEPER', 'description': 'SLEEPER'},
#    {'call_type': 'STREET', 'description': 'STREET INFORMATION'},
#    {'call_type': 'T', 'description': 'TRAFFIC STOP WITH PLATE'},
#    {'call_type': 'TAGGER', 'description': 'TAGGER VANDALISM, IN PROGRESS'},
#    {'call_type': 'TARASOFF', 'description': 'TARASOFF REPORT'},
#    {'call_type': 'TLO', 'description': 'TERRORISM LIAISON OFFICER'},
#    {'call_type': 'TP', 'description': 'TRAFFIC PURSUIT'},
#    {'call_type': 'TRO', 'description': 'TRO VIOLATION, REPORT'},
#    {'call_type': 'VARDA', 'description': 'VARDA ALARM'},
#    {'call_type': 'WARRANT', 'description': 'WARRANT'}]},
#  {'Table': 'Dispositions',
#   'Key': 'dispo_code',
#   'Col2': 'description',
#   'dict': [{'dispo_code': 'X',
#     'description': 'DISPATCHED ALARM CALL CANCELLED BEFORE UNIT ONSCENE'},
#    {'dispo_code': 'A', 'description': 'ARREST MADE'},
#    {'dispo_code': 'AB', 'description': 'ARREST MADE, BOARD AND SECURE'},
#    {'dispo_code': 'AHR',
#     'description': 'ARREST MADE, HIGH RISK (CRISIS RESPONSE TEAM)'},
#    {'dispo_code': 'R', 'description': 'REPORT'},
#    {'dispo_code': 'RB', 'description': 'REPORT TAKEN, BOARD AND SECURE'},
#    {'dispo_code': 'RHR',
#     'description': 'REPORT, HIGH RISK (CRISIS RESPONSE TEAM)'},
#    {'dispo_code': 'S', 'description': 'STOLEN VEHICLE OR RECOVERED VEHICLE'},
#    {'dispo_code': 'O', 'description': 'OTHER'},
#    {'dispo_code': 'OHR',
#     'description': 'OTHER, HIGH RISK (CRISIS RESPONSE TEAM)'},
#    {'dispo_code': 'K', 'description': 'NO REPORT REQUIRED'},
#    {'dispo_code': 'KB', 'description': 'NO REPORT REQUIRED, BOARD AND SECURE'},
#    {'dispo_code': 'KHR',
#     'description': 'NO FURTHER ACTION, HIGH RISK (CRISIS RESPONSE TEAM)'},
#    {'dispo_code': 'U', 'description': 'UNFOUNDED'},
#    {'dispo_code': 'W',
#     'description': 'NO DISPATCH OR INCIDENT CANCLLED PRIOR TO DISPATCHING A UNIT'},
#    {'dispo_code': 'CAN', 'description': 'CANCEL'},
#    {'dispo_code': 'DUP', 'description': "DUPLICATE CALL, XREF'D"},
#    {'dispo_code': 'V', 'description': 'DUPLICATE CALL'},
#    {'dispo_code': 'DEF', 'description': 'DEF'}]},
#  {'Table': 'Beats',
#   'Key': 'beat',
#   'Col2': 'neighborhood',
#   'dict': [{'beat': '111', 'neighborhood': 'Clairemont Mesa East'},
#    {'beat': '112', 'neighborhood': 'Clairemont Mesa West'},
#    {'beat': '113', 'neighborhood': 'Bay Ho'},
#    {'beat': '114', 'neighborhood': 'North Clairemont'},
#    {'beat': '115', 'neighborhood': 'University City'},
#    {'beat': '116', 'neighborhood': 'Bay Park'},
#    {'beat': '121', 'neighborhood': 'Mission Beach'},
#    {'beat': '122', 'neighborhood': 'Pacific Beach'},
#    {'beat': '123', 'neighborhood': 'Mission Bay Park'},
#    {'beat': '124', 'neighborhood': 'La Jolla'},
#    {'beat': '126', 'neighborhood': 'Torrey Pines'},
#    {'beat': '231', 'neighborhood': 'Sabre Springs'},
#    {'beat': '232', 'neighborhood': 'Carmel Mountain'},
#    {'beat': '233', 'neighborhood': 'Rancho Penasquitos'},
#    {'beat': '234', 'neighborhood': 'Rancho Bernardo'},
#    {'beat': '235', 'neighborhood': 'San Pasqual'},
#    {'beat': '241', 'neighborhood': 'Scripps Ranch'},
#    {'beat': '242', 'neighborhood': 'Mira Mesa'},
#    {'beat': '243', 'neighborhood': 'Miramar'},
#    {'beat': '245', 'neighborhood': 'Rancho Encantada'},
#    {'beat': '246', 'neighborhood': 'Miramar Ranch North'},
#    {'beat': '311', 'neighborhood': 'Serra Mesa'},
#    {'beat': '312', 'neighborhood': 'Tierrasanta'},
#    {'beat': '313', 'neighborhood': 'Kearny Mesa'},
#    {'beat': '314', 'neighborhood': 'Birdland'},
#    {'beat': '315', 'neighborhood': 'Mission Valley East'},
#    {'beat': '316', 'neighborhood': 'Qualcomm'},
#    {'beat': '321', 'neighborhood': 'Grantville'},
#    {'beat': '322', 'neighborhood': 'Allied Gardens'},
#    {'beat': '323', 'neighborhood': 'Del Cerro'},
#    {'beat': '324', 'neighborhood': 'Lake Murray'},
#    {'beat': '325', 'neighborhood': 'San Carlos'},
#    {'beat': '326', 'neighborhood': 'College West'},
#    {'beat': '327', 'neighborhood': 'College East'},
#    {'beat': '431', 'neighborhood': 'Emerald Hills'},
#    {'beat': '432', 'neighborhood': 'Valencia Park'},
#    {'beat': '433', 'neighborhood': 'Encanto'},
#    {'beat': '434', 'neighborhood': 'Jamacha/Lomita'},
#    {'beat': '435', 'neighborhood': 'Broadway Heights'},
#    {'beat': '436', 'neighborhood': 'Skyline'},
#    {'beat': '437', 'neighborhood': 'Bay Terraces'},
#    {'beat': '438', 'neighborhood': 'Paradise Hills'},
#    {'beat': '439', 'neighborhood': 'Alta Vista'},
#    {'beat': '441', 'neighborhood': 'Mountain View'},
#    {'beat': '442', 'neighborhood': 'Southcrest'},
#    {'beat': '443', 'neighborhood': 'Shelltown'},
#    {'beat': '444', 'neighborhood': 'Mt. Hope'},
#    {'beat': '445', 'neighborhood': 'Chollas View'},
#    {'beat': '446', 'neighborhood': 'Lincoln Park'},
#    {'beat': '447', 'neighborhood': 'Ridgeview/Webster'},
#    {'beat': '451', 'neighborhood': 'Oak Park'},
#    {'beat': '452', 'neighborhood': "O'Farrell"},
#    {'beat': '511', 'neighborhood': 'Barrio Logan'},
#    {'beat': '512', 'neighborhood': 'Logan Heights'},
#    {'beat': '514', 'neighborhood': 'Sherman Heights'},
#    {'beat': '515', 'neighborhood': 'Grant Hill'},
#    {'beat': '516', 'neighborhood': 'Stockton'},
#    {'beat': '517', 'neighborhood': 'Golden Hill'},
#    {'beat': '518', 'neighborhood': 'South Park'},
#    {'beat': '521', 'neighborhood': 'East Village'},
#    {'beat': '522', 'neighborhood': 'Marina'},
#    {'beat': '523', 'neighborhood': 'Gaslamp'},
#    {'beat': '524', 'neighborhood': 'Core-Columbia'},
#    {'beat': '525', 'neighborhood': 'Horton Plaza'},
#    {'beat': '526', 'neighborhood': 'Cortez'},
#    {'beat': '527', 'neighborhood': 'Harborview'},
#    {'beat': '528', 'neighborhood': 'Little Italy'},
#    {'beat': '529', 'neighborhood': 'Park West'},
#    {'beat': '531', 'neighborhood': 'Balboa Park'},
#    {'beat': '541', 'neighborhood': 'Petco Park'},
#    {'beat': '611', 'neighborhood': 'Midway District'},
#    {'beat': '612', 'neighborhood': 'Loma Portal'},
#    {'beat': '613', 'neighborhood': 'Point Loma Heights'},
#    {'beat': '614', 'neighborhood': 'Ocean Beach'},
#    {'beat': '615', 'neighborhood': 'Roseville/Fleet Ridge'},
#    {'beat': '616', 'neighborhood': 'La Playa'},
#    {'beat': '617', 'neighborhood': 'Wooded Area'},
#    {'beat': '618', 'neighborhood': 'Sunset Cliffs'},
#    {'beat': '621', 'neighborhood': 'Linda Vista'},
#    {'beat': '622', 'neighborhood': 'Morena'},
#    {'beat': '623', 'neighborhood': 'Mission Valley West'},
#    {'beat': '624', 'neighborhood': 'University Heights'},
#    {'beat': '625', 'neighborhood': 'Old Town'},
#    {'beat': '626', 'neighborhood': 'Mission Hills'},
#    {'beat': '627', 'neighborhood': 'Hillcrest'},
#    {'beat': '628', 'neighborhood': 'Midtown'},
#    {'beat': '711', 'neighborhood': 'Tijuana River Valley'},
#    {'beat': '712', 'neighborhood': 'San Ysidro'},
#    {'beat': '713', 'neighborhood': 'Otay Mesa'},
#    {'beat': '714', 'neighborhood': 'Border'},
#    {'beat': '721', 'neighborhood': 'Egger Highlands'},
#    {'beat': '722', 'neighborhood': 'Nestor'},
#    {'beat': '723', 'neighborhood': 'Otay Mesa West'},
#    {'beat': '724', 'neighborhood': 'Palm City'},
#    {'beat': '725', 'neighborhood': 'Ocean Crest'},
#    {'beat': '811', 'neighborhood': 'Normal Heights'},
#    {'beat': '812', 'neighborhood': 'Burlingame'},
#    {'beat': '813', 'neighborhood': 'North Park'},
#    {'beat': '814', 'neighborhood': 'Adams North'},
#    {'beat': '821', 'neighborhood': 'Rolando'},
#    {'beat': '822', 'neighborhood': 'El Cerrito'},
#    {'beat': '823', 'neighborhood': 'Redwood Village'},
#    {'beat': '824', 'neighborhood': 'Talmadge'},
#    {'beat': '825', 'neighborhood': 'Kensington'},
#    {'beat': '826', 'neighborhood': 'Colina del Sol'},
#    {'beat': '827', 'neighborhood': 'Chollas Creek'},
#    {'beat': '828', 'neighborhood': 'Fox Canyon'},
#    {'beat': '829', 'neighborhood': 'Islenair'},
#    {'beat': '831', 'neighborhood': 'Teralta East'},
#    {'beat': '832', 'neighborhood': 'Teralta West'},
#    {'beat': '833', 'neighborhood': 'Fairmount Village'},
#    {'beat': '834', 'neighborhood': 'Castle'},
#    {'beat': '835', 'neighborhood': 'Azalea/Hollywood Park'},
#    {'beat': '836', 'neighborhood': 'Swan Canyon'},
#    {'beat': '837', 'neighborhood': 'Fairmount Park'},
#    {'beat': '838', 'neighborhood': 'Corridor'},
#    {'beat': '839', 'neighborhood': 'Cherokee Point'},
#    {'beat': '841', 'neighborhood': 'Rolando Park'},
#    {'beat': '931', 'neighborhood': 'Sorrento Valley'},
#    {'beat': '932', 'neighborhood': 'Torrey Preserve'},
#    {'beat': '933', 'neighborhood': 'Del Mar Heights'},
#    {'beat': '934', 'neighborhood': 'Carmel Valley'},
#    {'beat': '935', 'neighborhood': 'North City'},
#    {'beat': '936', 'neighborhood': 'Torrey Highlands'},
#    {'beat': '937', 'neighborhood': 'Black Mountain Ranch'},
#    {'beat': -1, 'neighborhood': 'No Beat'}]}]

# %%
for row in tqdm(days_dict):
    Table = 'Days'
    Key = 'day_of_week'
    Col2 = 'day'
    #Verify if Data is in table
    Data_Found = Find_Data(row,cursor,Table,Key)
    if Data_Found is None:
        #If no data found load 
        Load_Data(row,cursor,Table,Key,Col2)
    else:
        pass

# %%
for upper_row in tqdm(SQL_Tables_dict):
    for row in upper_row['dict']:
        Data_Found = Find_Data(row,cursor,
                               upper_row['Table'],
                               upper_row['Key'])
        if Data_Found is None:
            #If no data found load 
            Load_Data(row,
                      cursor,
                      upper_row['Table'],
                      upper_row['Key'],
                      upper_row['Col2'])
        else:
            pass
# Out:
# {'call_type': '1016', 'description': 'PRISONER IN CUSTODY'}
# {'call_type': '1016PT', 'description': 'PTU (PRISONER TRANSPORT)'}
# {'call_type': '1016QC', 'description': 'SHOPLIFTER/QUICK CITE'}
# {'call_type': '1021', 'description': 'PHONE YOUR STATION'}
# {'call_type': '1021H', 'description': 'PHONE YOUR HOME'}
# {'call_type': '10851', 'description': 'AUTO THEFT'}
# {'call_type': '10851E', 'description': 'EVAL-POSS UNREPORTED CAR THEFT'}
# {'call_type': '10851R', 'description': 'CAR THEFT REPORT'}
# {'call_type': '10851RR', 'description': 'CAR THEFT RECOVERY REPORT'}
# {'call_type': '10852', 'description': 'TAMPERING W/VEH IN PROGRESS'}
# {'call_type': '10852A', 'description': 'VEHICLE ALARM/AUDIBLE'}
# {'call_type': '10852C', 'description': 'VEHICLE CASER'}
# {'call_type': '10852R', 'description': 'TAMPERING W/VEH REPORT'}
# {'call_type': '1087', 'description': 'MEET OFFICER NON URGENT'}
# {'call_type': '11-6', 'description': 'DISCHARGING FIREARMS'}
# {'call_type': '11-6SPT', 'description': 'DISCHARGING FIREARM SHOT SPOTTER ACTIVATION'}
# {'call_type': '11-7', 'description': 'PROWLER'}
# {'call_type': '11-8', 'description': 'PERSON DOWN'}
# {'call_type': '1110M', 'description': 'REPORT OF CRIME OCCD MEXICO'}
# {'call_type': '1111', 'description': 'CHECK THE AREA'}
# {'call_type': '1111', 'description': 'CHECK THE AREA'}
# {'call_type': '1115', 'description': 'BALL GAME IN STREET(83 03MC)'}
# {'call_type': '1115', 'description': 'BALL GAME IN STREET(83 03MC)'}
# {'call_type': '1130', 'description': 'INCOMPLETE PHONE CALL'}
# {'call_type': '1130', 'description': 'INCOMPLETE PHONE CALL'}
# {'call_type': '1131', 'description': 'CALLING FOR HELP'}
# {'call_type': '1131', 'description': 'CALLING FOR HELP'}
# {'call_type': '1131A', 'description': 'CALLING FOR HELP-PANIC ALARM'}
# {'call_type': '1140OD', 'description': 'AMBULANCE CALL, OVERDOSE'}
# {'call_type': '1141', 'description': 'AMBULANCE NEEDED'}
# {'call_type': '1144', 'description': "CORONER'S CASE"}
# {'call_type': '1146', 'description': 'REPORT OF DEATH'}
# {'call_type': '1147', 'description': 'INJURED PERSON'}
# {'call_type': '1148', 'description': 'FURNISH TRANSPORTATION'}
# {'call_type': '1149', 'description': 'TRAFFIC STOP/NO LICENSE'}
# {'call_type': '1150', 'description': 'TRAFFIC STOP/WITH LICENSE'}
# {'call_type': '1151', 'description': 'PED STOP/FIELD INTERVIEW'}
# {'call_type': '1153', 'description': 'SECURITY CHECK'}
# {'call_type': '1155', 'description': 'HAZARDOUS/CHEMICAL SPILL'}
# {'call_type': '1160', 'description': 'INVESTIGATE WATER LEAK'}
# {'call_type': '1166', 'description': 'SIGNALS OUT OF ORDER'}
# {'call_type': '1171', 'description': 'FIRE'}
# {'call_type': '1180', 'description': 'SERIOUS INJURY ACCIDENT'}
# {'call_type': '1180-CR', 'description': 'SERIOUS INJ ACCIDENT-COST RECOVERY'}
# {'call_type': '1181', 'description': 'MINOR INJURY ACCIDENT'}
# {'call_type': '1181-CR', 'description': 'MINOR INJURY ACCIDENT-COST RECOVERY'}
# {'call_type': '1181R', 'description': 'MINOR TRAFFIC INJURY, REPORT'}
# {'call_type': '1182', 'description': 'NON-INJURY ACCIDENT'}
# {'call_type': '1182-CR', 'description': 'NON-INJURY ACCIDENT-COST RECOVERY'}
# {'call_type': '1183', 'description': 'NO DETAIL ACCIDENT'}
# {'call_type': '1184', 'description': 'TRAFFIC CONTROL'}
# {'call_type': '1184-CR', 'description': 'TRAFFIC CONTROL-COST RECOVERY'}
# {'call_type': '1185', 'description': 'REQUEST FOR TOW TRUCK'}
# {'call_type': '1186', 'description': 'SPECIAL DETAIL'}
# {'call_type': '1188', 'description': 'ASSIST DISABLED MOTORIST'}
# {'call_type': '1199', 'description': 'OFFICER NEEDS HELP'}
# {'call_type': '136', 'description': 'INTIMIDATION OF WITNESS'}
# {'call_type': '146', 'description': 'IMPERSONATING AN OFFICER'}
# {'call_type': '146R', 'description': 'IMPERSONATING AN OFFICER,RPT'}
# {'call_type': '187', 'description': 'MURDER'}
# {'call_type': '187-SUSP', 'description': '187 SUSPECT THERE NOW'}
# {'call_type': '20001', 'description': 'FELONY HIT&RUN'}
# {'call_type': '20001-CR', 'description': 'FELONY HIT/RUN-COST RECOVERY'}
# {'call_type': '20002', 'description': 'MISD HIT/RUN'}
# {'call_type': '20002-CR', 'description': 'MISD HIT/RUN-COST RECOVERY'}
# {'call_type': '20002R', 'description': 'HIT AND RUN REPORT'}
# {'call_type': '207', 'description': 'KIDNAPPING IN PROGRESS'}
# {'call_type': '207R', 'description': 'KIDNAPPING REPORT'}
# {'call_type': '211', 'description': 'ROBBERY'}
# {'call_type': '211-SUSP', 'description': '211 SUSPECT THERE NOW'}
# {'call_type': '211A', 'description': 'ROBBERY ALARM'}
# {'call_type': '211C', 'description': 'ROBBERY CASER'}
# {'call_type': '211R', 'description': 'ROBBERY REPORT'}
# {'call_type': '211SPEC', 'description': 'ROBBERY-GPS DEVICE'}
# {'call_type': '215', 'description': 'CAR JACKING'}
# {'call_type': '215R', 'description': 'CARJACKING REPORT'}
# {'call_type': '23103', 'description': 'RECKLESS DRIVING'}
# {'call_type': '23110', 'description': 'THROWING OBJECTS AT AN OCC VEH'}
# {'call_type': '23110R', 'description': 'THROWING OBJECTS AT AN OCC VEH REPORT'}
# {'call_type': '23152', 'description': 'DUI'}
# {'call_type': '23152-CR', 'description': 'DUI-COST RECOVERY'}
# {'call_type': '242', 'description': 'BATTERY'}
# {'call_type': '242R', 'description': 'BATTERY REPORT'}
# {'call_type': '245', 'description': 'ADW'}
# {'call_type': '245-CR', 'description': 'ADW-COST RECOVERY'}
# {'call_type': '245-SUSP', 'description': '245 SUSPECT THERE NOW'}
# {'call_type': '245DV', 'description': 'ADW DOMESTIC VIOLENCE RELATED'}
# {'call_type': '245R', 'description': 'ADW REPORT'}
# {'call_type': '246', 'description': "FIRING AT OCCP'D HSE/VEH"}
# {'call_type': '246R', 'description': "FIRING AT OCCP'D HSE/VEH 1110"}
# {'call_type': '247', 'description': 'FIRING AT UNOCCUPIED VEH'}
# {'call_type': '247R', 'description': 'FIRING AT UNOCCPD VEH/HSE 1110'}
# {'call_type': '271', 'description': 'CHILD DESERTION'}
# {'call_type': '272', 'description': 'CONTRIBUTING DELINQ MINOR'}
# {'call_type': '278', 'description': 'CHILD STEALING'}
# {'call_type': '278', 'description': 'CHILD STEALING'}
# {'call_type': '278R', 'description': 'CHILD STEALING REPORT'}
# {'call_type': '314', 'description': 'INDECENT EXPOSURE'}
# {'call_type': '314R', 'description': 'INDECENT EXPOSURE REPORT'}
# {'call_type': '330', 'description': 'GAMBLING'}
# {'call_type': '368', 'description': 'ABUSE OF ELDER ADULT'}
# {'call_type': '374', 'description': 'LITTERING'}
# {'call_type': '402B', 'description': 'ABANDONED REFRIGERATOR'}
# {'call_type': '415', 'description': 'DISTURBING PEACE'}
# {'call_type': '415', 'description': 'DISTURBING PEACE'}
# {'call_type': '415CAPP', 'description': 'DIST PEACE-CAPP HOUSE'}
# {'call_type': '415CN', 'description': 'CONSTRUCTION NOISE COMPLAINT'}
# {'call_type': '415DV', 'description': 'DOMESTIC VIOL/OCCURRING NOW'}
# {'call_type': '415N', 'description': 'DISTURBING PEACE NOISE ONLY'}
# {'call_type': '415N-CR', 'description': 'DISTURB PEACE/NOISE-COST RECOVERY'}
# {'call_type': '415PP', 'description': 'PRESERVE THE PEACE'}
# {'call_type': '415SH-CR', 'description': 'SOCIAL HOST-COST RECOVERY'}
# {'call_type': '415TOW', 'description': 'DISTURBING PEACE RE: TOWING'}
# {'call_type': '415V', 'description': 'DISTURBING PEACE W/VIOLENCE'}
# {'call_type': '415W', 'description': 'DISTURBING PEACE UNCONC WEAPON'}
# {'call_type': '417', 'description': 'THREATENING W/WEAPON'}
# {'call_type': '417R', 'description': 'THREATENING W/WEAPON REPORT'}
# {'call_type': '422', 'description': 'CRIMINAL THREATS'}
# {'call_type': '422R', 'description': 'CRIMINAL THREATS REPORT'}
# {'call_type': '451', 'description': 'ARSON IN PROGRESS'}
# {'call_type': '451R', 'description': 'ARSON REPORT'}
# {'call_type': '459', 'description': 'BURGLARY IN PROGRESS'}
# {'call_type': '459-SUSP', 'description': '459 SUSPECT THERE NOW'}
# {'call_type': '459A', 'description': 'BURGLARY ALARM'}
# {'call_type': '459C', 'description': 'BURGLARY CASER'}
# {'call_type': '459HP', 'description': 'BURGLARY HOT PROWL'}
# {'call_type': '459R', 'description': 'BURGLARY REPORT'}
# {'call_type': '459SPEC', 'description': 'BURGLARY-GPS DEVICE'}
# {'call_type': '470', 'description': 'FORGERY IN PROGRESS'}
# {'call_type': '470R', 'description': 'FORGERY REPORT'}
# {'call_type': '470RX', 'description': 'FORGERY OF RX-SUSP THERE NOW'}
# {'call_type': '487', 'description': 'GRAND THEFT $950+'}
# {'call_type': '487R', 'description': 'GRAND THEFT/REPORT $950+'}
# {'call_type': '488', 'description': 'PETTY THEFT/UNDER $950'}
# {'call_type': '488R', 'description': 'PETTY THEFT REPORT/UNDER $950'}
# {'call_type': '496', 'description': 'RECEIVE/SELL STOLEN PROP'}
# {'call_type': '498', 'description': 'THEFT OF UTILITIES IN PROGRESS'}
# {'call_type': '498R', 'description': 'THEFT OF UTILITIES REPORT'}
# {'call_type': '502', 'description': 'COMPUTER CRIMES - TRU USE ONLY'}
# {'call_type': '503CAR', 'description': 'STOLEN VEHICLE LOG'}
# {'call_type': '508R', 'description': 'EMBEZZLEMENT, REPORT'}
# {'call_type': '5150', 'description': 'MENTAL CASE'}
# {'call_type': '5150V', 'description': 'MENTAL CASE-VIOLENT OR URGENT'}
# {'call_type': '518R', 'description': 'EXTORTION, REPORT'}
# {'call_type': '530', 'description': 'FALSE USE OF ANOTHERS IDENTITY'}
# {'call_type': '532', 'description': 'FRAUD SOLICITATION/CHARITIES'}
# {'call_type': '532', 'description': 'FRAUD SOLICITATION/CHARITIES'}
# {'call_type': '537', 'description': 'DEFRAUDING INNKEEPER, IN PROGR'}
# {'call_type': '537R', 'description': 'DEFRAUDING INNKEEPER REPORT'}
# {'call_type': '586', 'description': 'ILLEGAL PARKING'}
# {'call_type': '586H', 'description': 'ILLEGAL PARKING-HANDICAPPED'}
# {'call_type': '586O', 'description': 'ILLEGAL OVO PARKING'}
# {'call_type': '594', 'description': 'VANDALISM, IN PROGRESS'}
# {'call_type': '594GR', 'description': 'GRAFFITI VANDALISM REPORT'}
# {'call_type': '594R', 'description': 'VANDALISM, REPORT'}
# {'call_type': '594VARDA', 'description': 'VANDALISM,ALARM'}
# {'call_type': '595', 'description': 'RUNAWAY VEHICLE'}
# {'call_type': '597', 'description': 'CRUELTY TO ANIMALS, IN PROGRES'}
# {'call_type': '597R', 'description': 'CRUELTY TO ANIMALS, REPORT'}
# {'call_type': '602', 'description': 'TRESPASSING'}
# {'call_type': '646', 'description': 'STALKING'}
# {'call_type': '646R', 'description': 'STALKING REPORT'}
# {'call_type': '647B', 'description': 'PROSTITUTION'}
# {'call_type': '647F', 'description': 'DRUNK - DRUGS/ALCOHOL'}
# {'call_type': '653M', 'description': 'THREATENING PHONE CALL, REPORT'}
# {'call_type': '72HR', 'description': 'VEH VIOLATING 72HR PARKING RES'}
# {'call_type': '911', 'description': 'UNK EMERG, HANG UP/OPEN LINE'}
# {'call_type': '911P', 'description': 'UNK EMER,HANGUP/OPEN,PAYFONE'}
# {'call_type': 'ALERT2', 'description': 'AIRPLANE PROBLEM'}
# {'call_type': 'ALERT3', 'description': 'AIRPLANE CRASH'}
# {'call_type': 'ALERT4', 'description': 'BOMB/HIJACK THREAT'}
# {'call_type': 'AMBER', 'description': 'AMBER ALERT INFO'}
# {'call_type': 'ANIMAL', 'description': 'VICIOUS ANIMAL'}
# {'call_type': 'APPT', 'description': 'APPOINTMENT'}
# {'call_type': 'ASST', 'description': 'ASSIST THE INVALID'}
# {'call_type': 'AU-MP', 'description': 'MISSING PERSON ALL UNITS INFO'}
# {'call_type': 'AU1', 'description': 'ALL UNITS INFORMATION-PRI 1'}
# {'call_type': 'AU10851', 'description': 'AUTO THEFT ALL UNITS INFO'}
# {'call_type': 'AU1171', 'description': 'ALL UNITS FIRE INFO-PRI 1'}
# {'call_type': 'AU187', 'description': 'MURDER-ALL UNITS INFORMATION'}
# {'call_type': 'AU2', 'description': 'ALL UNITS INFORMATION-PRI 2'}
# {'call_type': 'AU211', 'description': 'ROBBERY-ALL UNITS INFORMATION'}
# {'call_type': 'AU215', 'description': 'CAR JACK-ALL UNITS INFORMATION'}
# {'call_type': 'AU23103', 'description': 'RECKLESS DRIVING-ALL UNITS'}
# {'call_type': 'AU23152', 'description': 'DUI-ALL UNITS INFORMATION'}
# {'call_type': 'AU245', 'description': 'ADW-ALL UNITS INFORMATION'}
# {'call_type': 'AUHATE', 'description': 'HATE INCIDENT ALL UNITS INF'}
# {'call_type': 'BIKE', 'description': 'DOCKLESS BIKE COMPLAINT'}
# {'call_type': 'BIO', 'description': 'BIOHAZARD-DESK CALL'}
# {'call_type': 'BIOALARM', 'description': '((ANTHRAX ALARM)))'}
# {'call_type': 'BLOOD', 'description': 'BLOOD RUN'}
# {'call_type': 'BLUE', 'description': 'TAXI OR BUS NEEDS HELP'}
# {'call_type': 'BOL', 'description': 'AU INFO/USED BY DESK OR RADIO'}
# {'call_type': 'BOMB', 'description': 'BOMB THREAT, DESK CALL'}
# {'call_type': 'BOMB-S', 'description': 'BOMB THREAT, DESK CALL (SCHOOL)'}
# {'call_type': 'C10', 'description': 'SWAT STAGING'}
# {'call_type': 'C100', 'description': 'ATTACK ON PD FACILITY'}
# {'call_type': 'C11', 'description': 'SWAT STAGING'}
# {'call_type': 'C11-CR', 'description': 'SWAT STAGING-COST RECOVERY'}
# {'call_type': 'C12', 'description': 'SWAT EMERGENCY RESPONSE'}
# {'call_type': 'C5', 'description': 'STAKEOUT'}
# {'call_type': 'C6', 'description': 'STAYOUT OF AREA/NO RADIO TRANS'}
# {'call_type': 'CC', 'description': 'CITIZEN CONTACT'}
# {'call_type': 'CCCC', 'description': 'CHRONIC COMM CALLER CONTROL'}
# {'call_type': 'CCF', 'description': "CITIZEN'S COMPLAINT INVESTIGAT"}
# {'call_type': 'CCF-EVNT', 'description': "CITIZEN'S COMPLAINT SPEC EVENT"}
# {'call_type': 'CCF-PBBP', 'description': 'CCF-PB BLOCK PARTY'}
# {'call_type': 'CCF-RRM', 'description': 'CCF-ROCK N ROLL MARATHON'}
# {'call_type': 'CCW', 'description': 'CARRYING CONCEALED WEAPON'}
# {'call_type': 'CITE', 'description': 'ISSUE CITATION'}
# {'call_type': 'COURT', 'description': 'COURT'}
# {'call_type': 'COVER', 'description': 'COVER NOW'}
# {'call_type': 'COVER-CR', 'description': 'COVER NOW-COST RECOVERY'}
# {'call_type': 'CW', 'description': 'CHECK THE WELFARE'}
# {'call_type': 'DC', 'description': 'DESK CALL'}
# {'call_type': 'DC-S', 'description': 'DESK CALL (SCHOOL)'}
# {'call_type': 'DEMO', 'description': 'DEMONSTRATION CALLS'}
# {'call_type': 'DRAGNET', 'description': 'ILLEGAL STREET RACING'}
# {'call_type': 'DRUN', 'description': 'HOMELAND SECURITY CHECKS'}
# {'call_type': 'EJECT', 'description': 'EJECTED FROM AN EVENT'}
# {'call_type': 'ESCAPE', 'description': 'ESCAPE/ESCAPEE'}
# {'call_type': 'EVAC', 'description': 'EVACUATE CITIZENS'}
# {'call_type': 'EVID', 'description': 'PICK UP EVIDENCE'}
# {'call_type': 'EXPLO', 'description': 'EXPLOSION'}
# {'call_type': 'FC', 'description': 'FRONT COUNTER CLOSURES'}
# {'call_type': 'FD', 'description': 'FLAG DOWN/FIELD INITIATED'}
# {'call_type': 'FIREHZRD', 'description': 'FIREWORK HAZARD'}
# {'call_type': 'FIREWORK', 'description': 'ALL UNITS INFORMATION'}
# {'call_type': 'FJ', 'description': 'FOUND JUVENILE'}
# {'call_type': 'FOOT', 'description': 'FOOT PATROL/FIELD INITIATED'}
# {'call_type': 'FOUND', 'description': 'FOUND PROPERTY'}
# {'call_type': 'FP', 'description': 'FOOT PURSUIT'}
# {'call_type': 'FP', 'description': 'WARRANT'}
# {'call_type': 'FS', 'description': 'FOUND SENILE'}
# {'call_type': 'FU', 'description': 'FOLLOW-UP BY FIELD UNIT'}
# {'call_type': 'GPSPAL', 'description': 'GPS PAROLE VIOLATION'}
# {'call_type': 'HATEINV', 'description': 'HATE CRIME INVESTIGATION'}
# {'call_type': 'HZRD', 'description': 'HAZARDOUS CONDITION'}
# {'call_type': 'INFO', 'description': 'INFORMATION FOR DISPATCHERS'}
# {'call_type': 'INFOCHP', 'description': 'INFORMATION FOR CHP'}
# {'call_type': 'INFOT', 'description': 'INFO ON TRAFFIC,HIT & RUN-ADVISED EVENT'}
# {'call_type': 'INFOX', 'description': 'EXTRA PATROL INFO FOR FIELD SGT-ADVISED EVENT'}
# {'call_type': 'JST', 'description': 'JUVENILE SERVICE TEAM HOTLINE'}
# {'call_type': 'LASER', 'description': 'ILLEGAL USE OF LASER '}
# {'call_type': 'LOJACK', 'description': 'STOLEN VEH-LOJACK'}
# {'call_type': 'LOST', 'description': 'REPORT OF LOST PROPERTY/PLATE'}
# {'call_type': 'MEXICO', 'description': 'LIAISON UNITS VISITING MEXICO'}
# {'call_type': 'MFF', 'description': 'MOBILE FIELD FORCE ACTIVATION'}
# {'call_type': 'MJ', 'description': 'MISSING JUV OF TENDER YEARS'}
# {'call_type': 'MP', 'description': 'MISSING PERSON, REPORT EVAL'}
# {'call_type': 'MPSSTP', 'description': 'TRAFFIC STOP FROM THE MOBILE COMPUTER'}
# {'call_type': 'MS', 'description': 'MISSING SENILE'}
# {'call_type': 'MTG', 'description': 'IN A MEETING/OUT OF SERVICE'}
# {'call_type': 'MUTAID', 'description': 'INTERAGAENCY MUTUAL AID'}
# {'call_type': 'NARC', 'description': 'NARCOTICS ACTIVITY'}
# {'call_type': 'NONU', 'description': 'REQUEST FOR NON URGENT COVER'}
# {'call_type': 'NONU-CR', 'description': 'NON URGENT COVER-COST RECOVERY'}
# {'call_type': 'OVO', 'description': 'OVERSIZED VEHICLE ORDINANCE'}
# {'call_type': 'PAPER', 'description': 'FINISH 1110/FIELD INITIATED'}
# {'call_type': 'PARTY', 'description': 'LOUD PARTY'}
# {'call_type': 'PARTY-CR', 'description': 'LOUD PARTY-COST RECOVERY'}
# {'call_type': 'PLATE', 'description': 'LOST/STOLEN PLATE '}
# {'call_type': 'POP', 'description': 'PROBLEM ORIENTED POLICING'}
# {'call_type': 'PORT', 'description': 'BORDER/PORT RUNNER A/U'}
# {'call_type': 'PRT', 'description': 'PRT ASSIST'}
# {'call_type': 'REPORT', 'description': 'CRIME CASE NUMBER REQUEST'}
# {'call_type': 'RESCUE', 'description': 'RESCUE CITIZENS'}
# {'call_type': 'RJ', 'description': 'RUNAWAY JUVENILE, REPORT'}
# {'call_type': 'ROUTE', 'description': 'ROUTE SLIP (FLD INVESTIGATION)'}
# {'call_type': 'RRM', 'description': 'ROCK N ROLL MARATHON'}
# {'call_type': 'RRM-1185', 'description': 'ROCK N ROLL 1185'}
# {'call_type': 'RRM-CCF', 'description': 'ROCK N ROLL CCF'}
# {'call_type': 'RRM-TOWS', 'description': 'VEHICLES TOWED DUE TO RRM'}
# {'call_type': 'SCALP', 'description': 'TICKET SCALPER'}
# {'call_type': 'SCHOOL', 'description': 'SCHOOL DETAIL'}
# {'call_type': 'SELENF', 'description': 'SELECTIVE ENFORCEMENT'}
# {'call_type': 'SHOPS', 'description': 'INFORMATION FOR SHOPS'}
# {'call_type': 'SIG', 'description': 'SIGALERT'}
# {'call_type': 'SKATE', 'description': 'SKATEBOARDERS'}
# {'call_type': 'SLEEPER', 'description': 'SLEEPER'}
# {'call_type': 'STREET', 'description': 'STREET INFORMATION'}
# {'call_type': 'T', 'description': 'TRAFFIC STOP WITH PLATE'}
# {'call_type': 'TAGGER', 'description': 'TAGGER VANDALISM, IN PROGRESS'}
# {'call_type': 'TARASOFF', 'description': 'TARASOFF REPORT'}
# {'call_type': 'TLO', 'description': 'TERRORISM LIAISON OFFICER'}
# {'call_type': 'TP', 'description': 'TRAFFIC PURSUIT'}
# {'call_type': 'TRO', 'description': 'TRO VIOLATION, REPORT'}
# {'call_type': 'VARDA', 'description': 'VARDA ALARM'}
# {'call_type': 'WARRANT', 'description': 'WARRANT'}
# {'dispo_code': 'X', 'description': 'DISPATCHED ALARM CALL CANCELLED BEFORE UNIT ONSCENE'}
# {'dispo_code': 'A', 'description': 'ARREST MADE'}
# {'dispo_code': 'AB', 'description': 'ARREST MADE, BOARD AND SECURE'}
# {'dispo_code': 'AHR', 'description': 'ARREST MADE, HIGH RISK (CRISIS RESPONSE TEAM)'}
# {'dispo_code': 'R', 'description': 'REPORT'}
# {'dispo_code': 'RB', 'description': 'REPORT TAKEN, BOARD AND SECURE'}
# {'dispo_code': 'RHR', 'description': 'REPORT, HIGH RISK (CRISIS RESPONSE TEAM)'}
# {'dispo_code': 'S', 'description': 'STOLEN VEHICLE OR RECOVERED VEHICLE'}
# {'dispo_code': 'O', 'description': 'OTHER'}
# {'dispo_code': 'OHR', 'description': 'OTHER, HIGH RISK (CRISIS RESPONSE TEAM)'}
# {'dispo_code': 'K', 'description': 'NO REPORT REQUIRED'}
# {'dispo_code': 'KB', 'description': 'NO REPORT REQUIRED, BOARD AND SECURE'}
# {'dispo_code': 'KHR', 'description': 'NO FURTHER ACTION, HIGH RISK (CRISIS RESPONSE TEAM)'}
# {'dispo_code': 'U', 'description': 'UNFOUNDED'}
# {'dispo_code': 'W', 'description': 'NO DISPATCH OR INCIDENT CANCLLED PRIOR TO DISPATCHING A UNIT'}
# {'dispo_code': 'CAN', 'description': 'CANCEL'}
# {'dispo_code': 'DUP', 'description': "DUPLICATE CALL, XREF'D"}
# {'dispo_code': 'V', 'description': 'DUPLICATE CALL'}
# {'dispo_code': 'DEF', 'description': 'DEF'}
# {'beat': '111', 'neighborhood': 'Clairemont Mesa East'}
# {'beat': '112', 'neighborhood': 'Clairemont Mesa West'}
# {'beat': '113', 'neighborhood': 'Bay Ho'}
# {'beat': '114', 'neighborhood': 'North Clairemont'}
# {'beat': '115', 'neighborhood': 'University City'}
# {'beat': '116', 'neighborhood': 'Bay Park'}
# {'beat': '121', 'neighborhood': 'Mission Beach'}
# {'beat': '122', 'neighborhood': 'Pacific Beach'}
# {'beat': '123', 'neighborhood': 'Mission Bay Park'}
# {'beat': '124', 'neighborhood': 'La Jolla'}
# {'beat': '126', 'neighborhood': 'Torrey Pines'}
# {'beat': '231', 'neighborhood': 'Sabre Springs'}
# {'beat': '232', 'neighborhood': 'Carmel Mountain'}
# {'beat': '233', 'neighborhood': 'Rancho Penasquitos'}
# {'beat': '234', 'neighborhood': 'Rancho Bernardo'}
# {'beat': '235', 'neighborhood': 'San Pasqual'}
# {'beat': '241', 'neighborhood': 'Scripps Ranch'}
# {'beat': '242', 'neighborhood': 'Mira Mesa'}
# {'beat': '243', 'neighborhood': 'Miramar'}
# {'beat': '245', 'neighborhood': 'Rancho Encantada'}
# {'beat': '246', 'neighborhood': 'Miramar Ranch North'}
# {'beat': '311', 'neighborhood': 'Serra Mesa'}
# {'beat': '312', 'neighborhood': 'Tierrasanta'}
# {'beat': '313', 'neighborhood': 'Kearny Mesa'}
# {'beat': '314', 'neighborhood': 'Birdland'}
# {'beat': '315', 'neighborhood': 'Mission Valley East'}
# {'beat': '316', 'neighborhood': 'Qualcomm'}
# {'beat': '321', 'neighborhood': 'Grantville'}
# {'beat': '322', 'neighborhood': 'Allied Gardens'}
# {'beat': '323', 'neighborhood': 'Del Cerro'}
# {'beat': '324', 'neighborhood': 'Lake Murray'}
# {'beat': '325', 'neighborhood': 'San Carlos'}
# {'beat': '326', 'neighborhood': 'College West'}
# {'beat': '327', 'neighborhood': 'College East'}
# {'beat': '431', 'neighborhood': 'Emerald Hills'}
# {'beat': '432', 'neighborhood': 'Valencia Park'}
# {'beat': '433', 'neighborhood': 'Encanto'}
# {'beat': '434', 'neighborhood': 'Jamacha/Lomita'}
# {'beat': '435', 'neighborhood': 'Broadway Heights'}
# {'beat': '436', 'neighborhood': 'Skyline'}
# {'beat': '437', 'neighborhood': 'Bay Terraces'}
# {'beat': '438', 'neighborhood': 'Paradise Hills'}
# {'beat': '439', 'neighborhood': 'Alta Vista'}
# {'beat': '441', 'neighborhood': 'Mountain View'}
# {'beat': '442', 'neighborhood': 'Southcrest'}
# {'beat': '443', 'neighborhood': 'Shelltown'}
# {'beat': '444', 'neighborhood': 'Mt. Hope'}
# {'beat': '445', 'neighborhood': 'Chollas View'}
# {'beat': '446', 'neighborhood': 'Lincoln Park'}
# {'beat': '447', 'neighborhood': 'Ridgeview/Webster'}
# {'beat': '451', 'neighborhood': 'Oak Park'}
# {'beat': '452', 'neighborhood': "O'Farrell"}
# {'beat': '511', 'neighborhood': 'Barrio Logan'}
# {'beat': '512', 'neighborhood': 'Logan Heights'}
# {'beat': '514', 'neighborhood': 'Sherman Heights'}
# {'beat': '515', 'neighborhood': 'Grant Hill'}
# {'beat': '516', 'neighborhood': 'Stockton'}
# {'beat': '517', 'neighborhood': 'Golden Hill'}
# {'beat': '518', 'neighborhood': 'South Park'}
# {'beat': '521', 'neighborhood': 'East Village'}
# {'beat': '522', 'neighborhood': 'Marina'}
# {'beat': '523', 'neighborhood': 'Gaslamp'}
# {'beat': '524', 'neighborhood': 'Core-Columbia'}
# {'beat': '525', 'neighborhood': 'Horton Plaza'}
# {'beat': '526', 'neighborhood': 'Cortez'}
# {'beat': '527', 'neighborhood': 'Harborview'}
# {'beat': '528', 'neighborhood': 'Little Italy'}
# {'beat': '529', 'neighborhood': 'Park West'}
# {'beat': '531', 'neighborhood': 'Balboa Park'}
# {'beat': '541', 'neighborhood': 'Petco Park'}
# {'beat': '611', 'neighborhood': 'Midway District'}
# {'beat': '612', 'neighborhood': 'Loma Portal'}
# {'beat': '613', 'neighborhood': 'Point Loma Heights'}
# {'beat': '614', 'neighborhood': 'Ocean Beach'}
# {'beat': '615', 'neighborhood': 'Roseville/Fleet Ridge'}
# {'beat': '616', 'neighborhood': 'La Playa'}
# {'beat': '617', 'neighborhood': 'Wooded Area'}
# {'beat': '618', 'neighborhood': 'Sunset Cliffs'}
# {'beat': '621', 'neighborhood': 'Linda Vista'}
# {'beat': '622', 'neighborhood': 'Morena'}
# {'beat': '623', 'neighborhood': 'Mission Valley West'}
# {'beat': '624', 'neighborhood': 'University Heights'}
# {'beat': '625', 'neighborhood': 'Old Town'}
# {'beat': '626', 'neighborhood': 'Mission Hills'}
# {'beat': '627', 'neighborhood': 'Hillcrest'}
# {'beat': '628', 'neighborhood': 'Midtown'}
# {'beat': '711', 'neighborhood': 'Tijuana River Valley'}
# {'beat': '712', 'neighborhood': 'San Ysidro'}
# {'beat': '713', 'neighborhood': 'Otay Mesa'}
# {'beat': '714', 'neighborhood': 'Border'}
# {'beat': '721', 'neighborhood': 'Egger Highlands'}
# {'beat': '722', 'neighborhood': 'Nestor'}
# {'beat': '723', 'neighborhood': 'Otay Mesa West'}
# {'beat': '724', 'neighborhood': 'Palm City'}
# {'beat': '725', 'neighborhood': 'Ocean Crest'}
# {'beat': '811', 'neighborhood': 'Normal Heights'}
# {'beat': '812', 'neighborhood': 'Burlingame'}
# {'beat': '813', 'neighborhood': 'North Park'}
# {'beat': '814', 'neighborhood': 'Adams North'}
# {'beat': '821', 'neighborhood': 'Rolando'}
# {'beat': '822', 'neighborhood': 'El Cerrito'}
# {'beat': '823', 'neighborhood': 'Redwood Village'}
# {'beat': '824', 'neighborhood': 'Talmadge'}
# {'beat': '825', 'neighborhood': 'Kensington'}
# {'beat': '826', 'neighborhood': 'Colina del Sol'}
# {'beat': '827', 'neighborhood': 'Chollas Creek'}
# {'beat': '828', 'neighborhood': 'Fox Canyon'}
# {'beat': '829', 'neighborhood': 'Islenair'}
# {'beat': '831', 'neighborhood': 'Teralta East'}
# {'beat': '832', 'neighborhood': 'Teralta West'}
# {'beat': '833', 'neighborhood': 'Fairmount Village'}
# {'beat': '834', 'neighborhood': 'Castle'}
# {'beat': '835', 'neighborhood': 'Azalea/Hollywood Park'}
# {'beat': '836', 'neighborhood': 'Swan Canyon'}
# {'beat': '837', 'neighborhood': 'Fairmount Park'}
# {'beat': '838', 'neighborhood': 'Corridor'}
# {'beat': '839', 'neighborhood': 'Cherokee Point'}
# {'beat': '841', 'neighborhood': 'Rolando Park'}
# {'beat': '931', 'neighborhood': 'Sorrento Valley'}
# {'beat': '932', 'neighborhood': 'Torrey Preserve'}
# {'beat': '933', 'neighborhood': 'Del Mar Heights'}
# {'beat': '934', 'neighborhood': 'Carmel Valley'}
# {'beat': '935', 'neighborhood': 'North City'}
# {'beat': '936', 'neighborhood': 'Torrey Highlands'}
# {'beat': '937', 'neighborhood': 'Black Mountain Ranch'}
# {'beat': -1, 'neighborhood': 'No Beat'}

# %%
for row in tqdm(days_dict):
    Table = 'Days'
    Key = 'day_of_week'
    Col2 = 'day'
    #Verify if Data is in table

# %% [markdown]
# ***

# %% [markdown]
# # Load Historical Calls

# %% [markdown]
# # 1. Incidents

# %%
#function to download yearly data
def Get_Data(year):
    url = f"https://seshat.datasd.org/pd/pd_calls_for_service_{year}_datasd.csv"
    df = pd.read_csv(url)
    return df

# %%
#Calls
def Load_Calls(row,cursor,table,year):
    # Create a new record
    sql = f"""INSERT INTO {table} ( incident_num,
                                    incident_date_time,
                                    day_of_week,
                                    call_type,
                                    dispo_code,
                                    beat,
                                    priority,
                                    incident_year
                                    ) VALUES (%s,%s,%s,%s,%s,%s,%s,%s)"""

    # Execute the query
    cursor.execute(sql, (row['incident_num'],
                         row['date_time'],
                         row['day_of_week'],
                         row['call_type'],
                         row['disposition'],
                         row['beat'],
                         row['priority'],
                         year,
                        )
                  )
    cnx.commit()

# %%
#Calls
def Load_Calls_Address(row,cursor,table,year):
    
    address = row['address_number_primary_str'] + ' ' + \
    row['address_dir_primary'] + ' ' + \
    row['address_road_primary'] + ' ' + \
    row['address_sfx_primary'] + ' San Diego CA'
    
    
    
    # Create a new record
    sql = f"""INSERT INTO {table} ( incident_num,
                                    address_number_primary,
                                    address_dir_primary,
                                    address_road_primary,
                                    address_sfx_primary,
                                    address_dir_intersecting,
                                    address_road_intersecting,
                                    address_sfx_intersecting,
                                    address
                                    ) VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)"""

    # Execute the query
    cursor.execute(sql, (row['incident_num'],
                         row['address_number_primary'],
                         row['address_dir_primary'],
                         row['address_road_primary'],
                         row['address_sfx_primary'],
                         row['address_dir_intersecting'],
                         row['address_road_intersecting'],
                         row['address_sfx_intersecting'],
                         row['address_road_intersecting']
                         address
                        )
                  )
    cnx.commit()

# %%
'',
                        '',
                        '',
                        ''

# %%
Years = list(range(2022,datetime.now().year +1))
Years
# Out:
# [2022, 2023]

# %%
Years = [2021]
Years
# Out:
# [2021]

# %%
for year in Years:
    yearly_data = Get_Data(year)
    yearly_data_dict = yearly_data.to_dict('records')
    for row in tqdm(yearly_data_dict):
        Table = 'Service_calls'
        Key = 'incident_num'
        #Verify if Data is in table
        Data_Found = Find_Data(row,cursor,Table,Key)
        if Data_Found is None:
            #If no data found load
            try:
                Load_Calls(row,cursor,Table,year)
            except:
                print(row)
                

        else:
            print('error')
            print(row)
# Out:
#   0%|▏                                  | 2342/568947 [00:01<05:32, 1702.46it/s]
# {'incident_num': 'E21010002172', 'date_time': '2021-01-02 12:18:55', 'day_of_week': 7, 'address_number_primary': 1600, 'address_dir_primary': nan, 'address_road_primary': 'PAC', 'address_sfx_primary': 'HWY', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'DEMO', 'disposition': 'K', 'beat': 700, 'priority': 2}
#   7%|██▌                               | 41855/568947 [00:24<05:12, 1687.33it/s]
# {'incident_num': 'E21010044301', 'date_time': '2021-01-28 03:58:32', 'day_of_week': 5, 'address_number_primary': 5400, 'address_dir_primary': nan, 'address_road_primary': 'CASINO', 'address_sfx_primary': 'WY', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'FU', 'disposition': 'K', 'beat': 300, 'priority': 2}
#  12%|████▏                             | 69570/568947 [00:40<04:57, 1676.60it/s]
# {'incident_num': 'E21020022897', 'date_time': '2021-02-14 13:05:11', 'day_of_week': 1, 'address_number_primary': 0, 'address_dir_primary': nan, 'address_road_primary': 'M 01ST ST W', 'address_sfx_primary': nan, 'address_dir_intersecting': nan, 'address_road_intersecting': 'UNNAMED MILITARY', 'address_sfx_intersecting': nan, 'call_type': 'AU1', 'disposition': 'W', 'beat': 0, 'priority': 1}
#  26%|████████▍                        | 145826/568947 [01:25<04:06, 1719.04it/s]
# {'incident_num': 'E21040003371', 'date_time': '2021-04-02 20:44:13', 'day_of_week': 6, 'address_number_primary': 1600, 'address_dir_primary': nan, 'address_road_primary': 'PAC', 'address_sfx_primary': 'HWY', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '1150', 'disposition': 'K', 'beat': 700, 'priority': 2}
#  34%|███████████▏                     | 193526/568947 [01:52<03:39, 1711.75it/s]
# {'incident_num': 'E21050003116', 'date_time': '2021-05-02 22:05:09', 'day_of_week': 1, 'address_number_primary': 1600, 'address_dir_primary': nan, 'address_road_primary': 'PAC', 'address_sfx_primary': 'HWY', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'CW', 'disposition': 'DUP', 'beat': 700, 'priority': 1}
#  46%|███████████████▏                 | 261644/568947 [02:32<03:00, 1706.42it/s]
# {'incident_num': 'E21060021831', 'date_time': '2021-06-13 12:13:27', 'day_of_week': 1, 'address_number_primary': 2800, 'address_dir_primary': nan, 'address_road_primary': 'EMERSON', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '10852R', 'disposition': 'CAN', 'beat': 0, 'priority': 3}
#  61%|████████████████████▏            | 347491/568947 [03:22<02:09, 1711.17it/s]
# {'incident_num': 'E21080006741', 'date_time': '2021-08-04 21:29:04', 'day_of_week': 4, 'address_number_primary': 2800, 'address_dir_primary': nan, 'address_road_primary': 'EMERSON', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '10851R', 'disposition': 'W', 'beat': 0, 'priority': 2}
#  62%|████████████████████▌            | 353690/568947 [03:26<02:05, 1714.95it/s]
# {'incident_num': 'E21080013325', 'date_time': '2021-08-08 21:06:01', 'day_of_week': 1, 'address_number_primary': 1700, 'address_dir_primary': nan, 'address_road_primary': 'PACIFIC', 'address_sfx_primary': 'HWY', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '1131A', 'disposition': 'K', 'beat': 700, 'priority': 1}
#  63%|████████████████████▋            | 355930/568947 [03:27<02:04, 1716.51it/s]
# {'incident_num': 'E21080015774', 'date_time': '2021-08-10 11:02:19', 'day_of_week': 3, 'address_number_primary': 5400, 'address_dir_primary': nan, 'address_road_primary': 'CASINO', 'address_sfx_primary': 'WY', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'AU1', 'disposition': 'W', 'beat': 300, 'priority': 1}
#  76%|████████████████████████▉        | 429834/568947 [04:10<01:22, 1693.90it/s]
# {'incident_num': 'E21090042734', 'date_time': '2021-09-25 17:47:50', 'day_of_week': 7, 'address_number_primary': 1600, 'address_dir_primary': nan, 'address_road_primary': 'PAC', 'address_sfx_primary': 'HWY', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'FD', 'disposition': 'O', 'beat': 700, 'priority': 2}
#  76%|█████████████████████████        | 431027/568947 [04:11<01:21, 1701.86it/s]
# {'incident_num': 'E21090044042', 'date_time': '2021-09-26 12:40:31', 'day_of_week': 1, 'address_number_primary': 1700, 'address_dir_primary': nan, 'address_road_primary': 'PACIFIC', 'address_sfx_primary': 'HWY', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'AU1', 'disposition': 'W', 'beat': 700, 'priority': 1}
#  76%|█████████████████████████▏       | 433590/568947 [04:13<01:19, 1700.21it/s]
# {'incident_num': 'E21090046894', 'date_time': '2021-09-28 08:31:33', 'day_of_week': 3, 'address_number_primary': 0, 'address_dir_primary': nan, 'address_road_primary': '01ST', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': 'BROADWAY', 'address_sfx_intersecting': nan, 'call_type': '10851R', 'disposition': 'SS-', 'beat': 525, 'priority': 2}
# {'incident_num': 'E21090047020', 'date_time': '2021-09-28 09:51:03', 'day_of_week': 3, 'address_number_primary': 11200, 'address_dir_primary': nan, 'address_road_primary': 'SPITFIRE', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '10851R', 'disposition': 'SS-', 'beat': 242, 'priority': 2}
#  76%|█████████████████████████▏       | 434104/568947 [04:13<01:19, 1705.13it/s]
# {'incident_num': 'E21090047322', 'date_time': '2021-09-28 12:48:25', 'day_of_week': 3, 'address_number_primary': 11200, 'address_dir_primary': nan, 'address_road_primary': 'LEE', 'address_sfx_primary': 'WAY', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '10851R', 'disposition': 'SS-', 'beat': 242, 'priority': 2}
#  76%|█████████████████████████▏       | 435132/568947 [04:14<01:18, 1706.33it/s]
# {'incident_num': 'E21090048446', 'date_time': '2021-09-29 05:51:21', 'day_of_week': 4, 'address_number_primary': 1200, 'address_dir_primary': nan, 'address_road_primary': '09TH', 'address_sfx_primary': 'AVE', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '10851R', 'disposition': 'SS-', 'beat': 524, 'priority': 2}
# {'incident_num': 'E21090048610', 'date_time': '2021-09-29 07:57:38', 'day_of_week': 4, 'address_number_primary': 2700, 'address_dir_primary': nan, 'address_road_primary': 'TREAT', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '10851R', 'disposition': 'SS-', 'beat': 517, 'priority': 2}
#  77%|█████████████████████████▎       | 436679/568947 [04:14<01:17, 1716.07it/s]
# {'incident_num': 'E21090050150', 'date_time': '2021-09-30 06:13:43', 'day_of_week': 5, 'address_number_primary': 2500, 'address_dir_primary': nan, 'address_road_primary': 'OLD QUARRY', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '10851R', 'disposition': 'SS-', 'beat': 315, 'priority': 2}
#  77%|█████████████████████████▎       | 437365/568947 [04:15<01:17, 1700.16it/s]
# {'incident_num': 'E21090050808', 'date_time': '2021-09-30 12:58:10', 'day_of_week': 5, 'address_number_primary': 3800, 'address_dir_primary': nan, 'address_road_primary': 'PENDIENTE', 'address_sfx_primary': 'CT', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '10851R', 'disposition': 'SS-', 'beat': 312, 'priority': 2}
#  78%|█████████████████████████▋       | 443007/568947 [04:18<01:13, 1708.06it/s]
# {'incident_num': 'E21100005344', 'date_time': '2021-10-04 08:32:21', 'day_of_week': 2, 'address_number_primary': 9400, 'address_dir_primary': nan, 'address_road_primary': 'CUSTOMHOUSE', 'address_sfx_primary': 'PLZ', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '10851R', 'disposition': 'SS-', 'beat': 713, 'priority': 2}
#  78%|█████████████████████████▉       | 446108/568947 [04:20<01:11, 1716.52it/s]
# {'incident_num': 'E21100008682', 'date_time': '2021-10-06 07:03:09', 'day_of_week': 4, 'address_number_primary': 9300, 'address_dir_primary': nan, 'address_road_primary': 'HILLERY', 'address_sfx_primary': 'DR', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '10851R', 'disposition': 'SS-', 'beat': 242, 'priority': 2}
#  81%|██████████████████████████▋      | 459448/568947 [04:28<01:03, 1717.77it/s]
# {'incident_num': 'E21100022916', 'date_time': '2021-10-14 16:57:45', 'day_of_week': 5, 'address_number_primary': 1600, 'address_dir_primary': nan, 'address_road_primary': 'PAC', 'address_sfx_primary': 'HWY', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '10851R', 'disposition': 'R', 'beat': 700, 'priority': 2}
#  82%|███████████████████████████      | 466852/568947 [04:32<00:59, 1714.06it/s]
# {'incident_num': 'E21100030681', 'date_time': '2021-10-19 13:03:05', 'day_of_week': 3, 'address_number_primary': 4100, 'address_dir_primary': nan, 'address_road_primary': 'CAMINO DE LA PLAZA', 'address_sfx_primary': nan, 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '10851R', 'disposition': 'SS-', 'beat': 712, 'priority': 2}
#  86%|████████████████████████████▍    | 489949/568947 [04:46<00:46, 1712.57it/s]
# {'incident_num': 'E21110006716', 'date_time': '2021-11-05 07:08:06', 'day_of_week': 6, 'address_number_primary': 400, 'address_dir_primary': nan, 'address_road_primary': 'UNIVERSITY', 'address_sfx_primary': 'PL', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '586', 'disposition': 'SS-', 'beat': 627, 'priority': 4}
#  86%|████████████████████████████▍    | 491325/568947 [04:47<00:45, 1709.85it/s]
# {'incident_num': 'E21110008154', 'date_time': '2021-11-06 01:00:11', 'day_of_week': 7, 'address_number_primary': 2100, 'address_dir_primary': nan, 'address_road_primary': 'WUESTE', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'CC', 'disposition': 'W', 'beat': 9, 'priority': 1}
#  87%|████████████████████████████▊    | 496136/568947 [04:49<00:42, 1713.21it/s]
# {'incident_num': 'E21110013337', 'date_time': '2021-11-09 09:15:51', 'day_of_week': 3, 'address_number_primary': 10600, 'address_dir_primary': nan, 'address_road_primary': 'WEXFORD', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '10851R', 'disposition': 'SS-', 'beat': 246, 'priority': 2}
#  93%|██████████████████████████████▊  | 530954/568947 [05:10<00:22, 1720.35it/s]
# {'incident_num': 'E21120004041', 'date_time': '2021-12-03 14:27:34', 'day_of_week': 6, 'address_number_primary': 8100, 'address_dir_primary': nan, 'address_road_primary': 'ROYAL GORGE', 'address_sfx_primary': 'DR', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'CC', 'disposition': 'SS-', 'beat': 325, 'priority': 3}
#  96%|███████████████████████████████▌ | 544208/568947 [05:17<00:14, 1718.05it/s]
# {'incident_num': 'E21120018335', 'date_time': '2021-12-13 00:53:35', 'day_of_week': 2, 'address_number_primary': 1700, 'address_dir_primary': nan, 'address_road_primary': 'PACIFIC', 'address_sfx_primary': 'HWY', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '1151', 'disposition': 'O', 'beat': 700, 'priority': 2}
#  96%|███████████████████████████████▊ | 548858/568947 [05:20<00:11, 1712.42it/s]
# {'incident_num': 'E21120023320', 'date_time': '2021-12-16 10:58:42', 'day_of_week': 5, 'address_number_primary': 1600, 'address_dir_primary': nan, 'address_road_primary': 'PAC', 'address_sfx_primary': 'HWY', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'FD', 'disposition': 'K', 'beat': 700, 'priority': 2}
#  97%|███████████████████████████████▉ | 551606/568947 [05:22<00:10, 1709.49it/s]
# {'incident_num': 'E21120026273', 'date_time': '2021-12-18 09:13:37', 'day_of_week': 7, 'address_number_primary': 0, 'address_dir_primary': nan, 'address_road_primary': nan, 'address_sfx_primary': nan, 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': 'INFO', 'disposition': 'W', 'beat': 0, 'priority': 2}
#  98%|████████████████████████████████▏| 555925/568947 [05:24<00:07, 1721.01it/s]
# {'incident_num': 'E21120030811', 'date_time': '2021-12-21 11:00:39', 'day_of_week': 3, 'address_number_primary': 2800, 'address_dir_primary': nan, 'address_road_primary': 'COMMERCIAL', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '10851RR', 'disposition': 'SS-', 'beat': 512, 'priority': 3}
#  98%|████████████████████████████████▍| 559709/568947 [05:26<00:05, 1706.63it/s]
# {'incident_num': 'E21120034745', 'date_time': '2021-12-24 07:39:01', 'day_of_week': 6, 'address_number_primary': 2200, 'address_dir_primary': nan, 'address_road_primary': 'WUESTE', 'address_sfx_primary': 'RD', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '10851', 'disposition': 'O', 'beat': 9, 'priority': 0}
#  99%|████████████████████████████████▋| 562806/568947 [05:28<00:03, 1709.34it/s]
# {'incident_num': 'E21120038161', 'date_time': '2021-12-26 23:39:41', 'day_of_week': 1, 'address_number_primary': 1600, 'address_dir_primary': nan, 'address_road_primary': 'PAC', 'address_sfx_primary': 'HWY', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '1151', 'disposition': 'O', 'beat': 700, 'priority': 2}
#  99%|████████████████████████████████▋| 563491/568947 [05:29<00:03, 1704.55it/s]
# {'incident_num': 'E21120038900', 'date_time': '2021-12-27 13:05:40', 'day_of_week': 2, 'address_number_primary': 3700, 'address_dir_primary': nan, 'address_road_primary': 'ALABAMA', 'address_sfx_primary': 'ST', 'address_dir_intersecting': nan, 'address_road_intersecting': nan, 'address_sfx_intersecting': nan, 'call_type': '10851RR', 'disposition': 'SS-', 'beat': 813, 'priority': 3}
# 100%|█████████████████████████████████| 568947/568947 [05:32<00:00, 1711.90it/s]

# %% [markdown]
# ## Call Long and Lat

# %%
def Lat_Long(address):
    lat, lng  = None, None, None
    api_key = GOOGLE_API_KEY
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"
    endpoint = f"{base_url}?address={address}&key={api_key}"
    r = requests.get(endpoint)
    if r.status_code not in range(200, 299):
        #error
        return None, None
    try:
        #found
        results = r.json()['results'][0]
        lat = results['geometry']['location']['lat']
        lng = results['geometry']['location']['lng']
    except:
        pass
    return lat, lng

def DF_GeoCode(row):
    column_name = 'Address'
    address_value = row[column_name]
    address_lat, address_lng = Lat_Long(address_value)
    row['lat'] = address_lat
    row['lng'] = address_lng
    
    return row

# %%
engine = create_engine(f"mysql://{user}:{password}@{host}/{database}")
connection = engine.connect()

# %%
Last10_Geo = Last10.apply(DF_GeoCode, axis=1)

# %% [markdown]
# ## Call Zipcode

# %%
result = connection.execute(
    """
    SELECT * from beats
    """)
column_names = result.keys()
rows = result.fetchall()
result_df = pd.DataFrame(rows, columns=column_names)

# print(column_names)

# %%
result_df
# Out:
#      beat           neighborhood
# 0     814            Adams North
# 1     322         Allied Gardens
# 2     439             Alta Vista
# 3     835  Azalea/Hollywood Park
# 4     531            Balboa Park
# ..    ...                    ...
# 121   932        Torrey Preserve
# 122   115        University City
# 123   624     University Heights
# 124   432          Valencia Park
# 125   617            Wooded Area
#
# [126 rows x 2 columns]

# %%
import dash
from dash.dependencies import Input, Output
import dash_core_components as dcc
import dash_html_components as html
# Out:
# /var/folders/06/rkc92dl925n9zc06g826mq2m0000gn/T/ipykernel_5516/3697956674.py:3: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# /var/folders/06/rkc92dl925n9zc06g826mq2m0000gn/T/ipykernel_5516/3697956674.py:4: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html

# %%
app = dash.Dash()
app.layout = html.Div(children=[
    html.H1('Police Activity Dashboard', style={'text-align': 'center'}),
    dcc.Dropdown(id="slct_year",
                options=[
                    {"label":"2023", "value": 2023},
                    {"label":"2022", "value": 2022},
                    {"label":"2021", "value": 2021}
                ],
                multi=False,
                value=2023,
                style={'width': "40%"})
])

# %%
if __name__ == '__main__':
    app.run_server(port=8055)
# Out:
# Dash is running on http://127.0.0.1:8055/
#
# Dash is running on http://127.0.0.1:8055/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8055/ (Press CTRL+C to quit)
# 127.0.0.1 - - [03/Feb/2023 08:39:23] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2023 08:39:24] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2023 08:39:24] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2023 08:39:24] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 304 -
