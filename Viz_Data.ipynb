# %%
#import mysql.connector
import sqlalchemy as sql
import pandas as pd

# %%
cnx = mysql.connector.connect(user='root',
                              password='renovatio',
                              host='localhost',
                              database="SDPD"
                              )

# %%
query = """Select * from Service_calls

"""

# %%
result_dataFrame = pd.read_sql(query, cnx)
result_dataFrame
# Out:
# /Users/salvadorsanchez/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#          incident_num  incident_date_time day_of_week call_type dispo_code  \
# 0        E21010000001 2021-01-01 00:00:11           6       AU1          W
# 1        E21010000002 2021-01-01 00:00:14           6      1186        CAN
# 2        E21010000003 2021-01-01 00:00:26           6       AU1        DUP
# 3        E21010000004 2021-01-01 00:00:31           6       AU1          W
# 4        E21010000006 2021-01-01 00:01:20           6      INFO          W
# ...               ...                 ...         ...       ...        ...
# 1109929  E23010044748 2023-01-31 23:05:42           3    AU1171          K
# 1109930  E23010044756 2023-01-31 23:18:26           3      11-8          K
# ...

# %%
result_dataFrame.to_csv('All.csv')
